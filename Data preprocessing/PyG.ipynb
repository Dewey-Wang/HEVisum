# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.patches as patches

# %% [markdown]
# # Training data preparation

# %%
with h5py.File("../elucidata_ai_challenge_data.h5", "r") as h5file:
    train_images = h5file["images/Train"]
    train_spots = h5file["spots/Train"]
    
    sample = 'S_1'
    image = np.array(train_images[sample])
    spots = np.array(train_spots[sample])
    x, y = spots["x"], spots["y"]
    
    plt.figure(figsize=(6,6))
    plt.imshow(image, aspect="auto")
    plt.scatter(x, y, color="red", s=1, alpha=0.4)
    plt.axis('off')
    plt.title(sample)
    plt.show()

# %%
image.shape
# Out:
# (2000, 1974, 3)

# %%
# Load and display (x,y) spot locations and cell type annotation table for Train slides
with h5py.File("../elucidata_ai_challenge_data.h5", "r") as f:
    train_spots = f["spots/Train"]
    
    # Dictionary to store DataFrames for each slide
    train_spot_tables = {}
    
    for slide_name in train_spots.keys():
        # Load dataset as NumPy structured array
        spot_array = np.array(train_spots[slide_name])
        
        # Convert to DataFrame
        df = pd.DataFrame(spot_array)
        
        # Store in dictionary
        train_spot_tables[slide_name] = df
        print(slide_name)

# Example: Display the spots table for slide 'S_1'
train_spot_tables['S_1']
# Out:
# S_1
# S_2
# S_3
# S_4
# S_5
# S_6
#          x     y        C1        C2        C3        C4        C5        C6  \
# 0     1554  1297  0.014401  0.057499  0.022033  0.001704  0.533992  1.511707
# 1      462  1502  0.116196  0.197176  0.110600  0.042614  5.587681  0.006885
# 2     1488  1548  0.133284  0.035880  0.061352  0.003073  1.104479  0.009174
# 3     1725  1182  0.087715  0.235223  0.090382  0.013902  8.760482  0.140912
# 4      581  1113  0.128468  0.066399  0.098982  0.047022  3.425771  0.001009
# ...    ...   ...       ...       ...       ...       ...       ...       ...
# 2192  1055   701  0.047236  0.112721  0.052490  0.002092  0.000913  0.393805
# 2193  1225   862  0.070764  0.119310  0.193938  0.001239  0.003851  0.588956
# 2194   765  1479  0.194491  0.048068  0.150061  0.002978  0.119206  0.000213
# 2195   607  1525  0.002968  0.151899  0.015931  0.000071  1.354983  0.000152
# 2196   568  1181  0.000232  0.004759  0.001376  0.003225  0.874639  0.000026
#
#             C7        C8  ...           C26       C27       C28       C29  \
# 0     0.015313  0.020029  ...  1.009572e-03  2.068237  0.121361  0.007344
# 1     0.096346  0.001711  ...  6.918171e-04  0.014442  0.000238  0.024071
# 2     0.009175  0.000114  ...  9.577447e-05  0.149792  0.001401  0.000699
# 3     0.188859  0.010154  ...  1.964150e-03  0.142549  0.002036  0.047165
# 4     0.026881  0.000468  ...  7.189078e-05  0.005920  0.000048  0.006359
# ...        ...       ...  ...           ...       ...       ...       ...
# 2192  0.045220  0.013414  ...  7.530558e-03  0.559967  0.154793  0.133587
# 2193  0.037731  0.004072  ...  3.219223e-02  0.667076  0.094247  0.136623
# 2194  0.005332  0.000078  ...  2.628421e-04  0.000273  0.000022  0.000027
# 2195  0.019254  0.001267  ...  1.377452e-03  0.003754  0.001420  0.088000
# 2196  0.003913  0.000003  ...  8.989834e-07  0.001573  0.000002  0.000239
#
#            C30       C31       C32       C33       C34       C35
# 0     0.000017  0.036891  0.035934  0.118937  0.001472  0.050057
# 1     0.000023  0.217589  0.100662  0.004027  0.004122  0.049491
# 2     0.000009  0.024491  0.018810  0.004171  0.000425  0.015348
# 3     0.000022  0.180372  0.202981  0.003709  0.001845  0.116022
# 4     0.000585  0.052661  0.032168  0.000107  0.000107  0.013103
# ...        ...       ...       ...       ...       ...       ...
# 2192  0.000013  0.051041  0.113100  0.003147  0.004971  0.128265
# 2193  0.000009  0.050518  0.119685  0.027743  0.016413  0.287171
# 2194  0.000042  0.029386  0.019977  0.000039  0.000119  0.006778
# 2195  0.000536  0.073240  0.113631  0.009040  0.000090  0.025716
# 2196  0.003375  0.002501  0.001325  0.000003  0.000001  0.000468
#
# [2197 rows x 37 columns]

# %%
import h5py
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import torch
import torch_geometric
from scipy.spatial import KDTree
import matplotlib.pyplot as plt
# 用來儲存每個 slide 的 edge_index
def compute_edge_index(coords, radius=128):
    """
    計算每個 batch 的 edge_index（鄰接關係）
    同時顯示每個點的鄰居數量
    """
    kdtree = KDTree(coords)
    edge_list = []
    
    # 用來統計每個點的鄰居數量
    neighbor_counts = []
    
    for i, coord in enumerate(coords):
        neighbors = kdtree.query_ball_point(coord, r=radius)  # 查找半徑為 radius 的鄰居
        
        # 計算當前點的鄰居數量
        neighbor_counts.append(len(neighbors))
        
        # 將所有鄰居添加到 edge_list 中
        for j in neighbors:
            if i != j:
                edge_list.append([i, j])

    # 顯示每個點的鄰居數量
    for i, count in enumerate(neighbor_counts):
        print(f"Point {i} has {count} neighbors.")
            # 將邊列表轉換為 PyG 格式
    edge_index = torch.tensor(edge_list, dtype=torch.long).t().contiguous()
    
    return edge_index

normal_coords = []
slide_edge_indices = {}

# 預先計算每個 slide 的 edge_index 並儲存
with h5py.File("../elucidata_ai_challenge_data.h5", "r") as h5file:
    train_images = h5file["images/Train"]
    slide_ids = list(train_spot_tables.keys())

    for slide_id in slide_ids:
        if slide_id not in train_images:
            print(f"⚠️ Slide {slide_id} not found in HDF5, skipping.")
            continue
        
        # 讀取這個 slide 的 DataFrame
        df = train_spot_tables[slide_id]
        
        # 提取 (x, y) 座標並進行標準化
        coords = df[['x', 'y']].values
        scaler = MinMaxScaler()
        coords_normalized = scaler.fit_transform(coords)  # 將座標標準化到 [0, 1] 範圍內
                # 儲存標準化後的 (x, y) 座標
        df[['x_normalized', 'y_normalized']] = coords_normalized
        normal_coords.append((coords_normalized))  # Wrap the values in a tuple

        # 計算原始座標的半徑
        original_radius = 64  # 原始的 radius 值（像素）

        # 計算標準化後的 radius
        # 假設你的 x, y 範圍分別是 [min_x, max_x] 和 [min_y, max_y]
        min_x, max_x = np.min(coords[:, 0]), np.max(coords[:, 0])
        print(f"min_x: {min_x}, max_x: {max_x}")
        min_y, max_y = np.min(coords[:, 1]), np.max(coords[:, 1])
        print(f"min_y: {min_y}, max_y: {max_y}")
        # 計算標準化後的半徑
        normalized_radius_x = original_radius / (max_x - min_x)
        normalized_radius_y = original_radius / (max_y - min_y)
        print(f"normalized_radius_x: {normalized_radius_x}, normalized_radius_y: {normalized_radius_y}")
        # 你可以選擇平均這兩個來得到一個統一的標準化半徑
        normalized_radius = (normalized_radius_x + normalized_radius_y) / 2

        # 計算 `edge_index` 並儲存
        edge_index = compute_edge_index(coords_normalized, radius=normalized_radius)
        slide_edge_indices[slide_id] = edge_index
        
        # 更新 `train_spot_tables`，儲存標準化後的 DataFrame
        train_spot_tables[slide_id] = df

# 顯示更新後的 `train_spot_tables`
for slide_id in slide_ids:
    print(f"Updated table for slide {slide_id}:")
    print(train_spot_tables[slide_id].head())
# Out:
# min_x: 331, max_x: 1830
# min_y: 587, max_y: 1800
# normalized_radius_x: 0.04269513008672448, normalized_radius_y: 0.05276174773289365
# Point 0 has 19 neighbors.
# Point 1 has 9 neighbors.
# Point 2 has 19 neighbors.
# Point 3 has 20 neighbors.
# Point 4 has 20 neighbors.
# Point 5 has 21 neighbors.
# Point 6 has 22 neighbors.
# Point 7 has 21 neighbors.
# Point 8 has 21 neighbors.
# Point 9 has 16 neighbors.
# Point 10 has 19 neighbors.
# Point 11 has 21 neighbors.
# Point 12 has 11 neighbors.
# Point 13 has 19 neighbors.
# Point 14 has 22 neighbors.
# Point 15 has 22 neighbors.
# Point 16 has 19 neighbors.
# Point 17 has 19 neighbors.
# Point 18 has 21 neighbors.
# Point 19 has 18 neighbors.
# Point 20 has 20 neighbors.
# Point 21 has 21 neighbors.
# Point 22 has 20 neighbors.
# Point 23 has 19 neighbors.
# Point 24 has 21 neighbors.
# Point 25 has 17 neighbors.
# Point 26 has 16 neighbors.
# Point 27 has 21 neighbors.
# Point 28 has 21 neighbors.
# Point 29 has 20 neighbors.
# Point 30 has 20 neighbors.
# Point 31 has 19 neighbors.
# Point 32 has 21 neighbors.
# Point 33 has 22 neighbors.
# Point 34 has 18 neighbors.
# Point 35 has 20 neighbors.
# Point 36 has 22 neighbors.
# Point 37 has 13 neighbors.
# Point 38 has 18 neighbors.
# Point 39 has 21 neighbors.
# Point 40 has 20 neighbors.
# Point 41 has 11 neighbors.
# Point 42 has 22 neighbors.
# Point 43 has 21 neighbors.
# Point 44 has 19 neighbors.
# Point 45 has 21 neighbors.
# Point 46 has 21 neighbors.
# Point 47 has 16 neighbors.
# Point 48 has 21 neighbors.
# Point 49 has 21 neighbors.
# Point 50 has 21 neighbors.
# Point 51 has 22 neighbors.
# Point 52 has 21 neighbors.
# Point 53 has 19 neighbors.
# Point 54 has 9 neighbors.
# Point 55 has 19 neighbors.
# Point 56 has 21 neighbors.
# Point 57 has 22 neighbors.
# Point 58 has 22 neighbors.
# Point 59 has 20 neighbors.
# Point 60 has 19 neighbors.
# Point 61 has 22 neighbors.
# Point 62 has 16 neighbors.
# Point 63 has 21 neighbors.
# Point 64 has 19 neighbors.
# Point 65 has 9 neighbors.
# Point 66 has 21 neighbors.
# Point 67 has 19 neighbors.
# Point 68 has 19 neighbors.
# Point 69 has 21 neighbors.
# Point 70 has 19 neighbors.
# Point 71 has 21 neighbors.
# Point 72 has 21 neighbors.
# Point 73 has 19 neighbors.
# Point 74 has 20 neighbors.
# Point 75 has 21 neighbors.
# Point 76 has 21 neighbors.
# Point 77 has 19 neighbors.
# Point 78 has 22 neighbors.
# Point 79 has 20 neighbors.
# Point 80 has 19 neighbors.
# Point 81 has 19 neighbors.
# Point 82 has 21 neighbors.
# Point 83 has 19 neighbors.
# Point 84 has 20 neighbors.
# Point 85 has 12 neighbors.
# Point 86 has 17 neighbors.
# Point 87 has 21 neighbors.
# Point 88 has 21 neighbors.
# Point 89 has 19 neighbors.
# Point 90 has 19 neighbors.
# Point 91 has 21 neighbors.
# Point 92 has 22 neighbors.
# Point 93 has 21 neighbors.
# Point 94 has 21 neighbors.
# Point 95 has 20 neighbors.
# Point 96 has 21 neighbors.
# Point 97 has 19 neighbors.
# Point 98 has 22 neighbors.
# Point 99 has 20 neighbors.
# Point 100 has 21 neighbors.
# Point 101 has 21 neighbors.
# Point 102 has 19 neighbors.
# Point 103 has 19 neighbors.
# Point 104 has 20 neighbors.
# Point 105 has 19 neighbors.
# Point 106 has 19 neighbors.
# Point 107 has 22 neighbors.
# Point 108 has 18 neighbors.
# Point 109 has 18 neighbors.
# Point 110 has 17 neighbors.
# Point 111 has 21 neighbors.
# Point 112 has 13 neighbors.
# Point 113 has 21 neighbors.
# Point 114 has 18 neighbors.
# Point 115 has 19 neighbors.
# Point 116 has 21 neighbors.
# Point 117 has 19 neighbors.
# Point 118 has 21 neighbors.
# Point 119 has 17 neighbors.
# Point 120 has 21 neighbors.
# Point 121 has 15 neighbors.
# Point 122 has 19 neighbors.
# Point 123 has 20 neighbors.
# Point 124 has 19 neighbors.
# Point 125 has 19 neighbors.
# Point 126 has 14 neighbors.
# Point 127 has 19 neighbors.
# Point 128 has 19 neighbors.
# Point 129 has 21 neighbors.
# Point 130 has 19 neighbors.
# Point 131 has 20 neighbors.
# Point 132 has 20 neighbors.
# Point 133 has 21 neighbors.
# Point 134 has 19 neighbors.
# Point 135 has 19 neighbors.
# Point 136 has 18 neighbors.
# Point 137 has 21 neighbors.
# Point 138 has 19 neighbors.
# Point 139 has 21 neighbors.
# Point 140 has 19 neighbors.
# Point 141 has 21 neighbors.
# Point 142 has 8 neighbors.
# Point 143 has 21 neighbors.
# Point 144 has 19 neighbors.
# Point 145 has 14 neighbors.
# Point 146 has 11 neighbors.
# Point 147 has 17 neighbors.
# Point 148 has 20 neighbors.
# Point 149 has 22 neighbors.
# Point 150 has 15 neighbors.
# Point 151 has 19 neighbors.
# Point 152 has 21 neighbors.
# Point 153 has 20 neighbors.
# Point 154 has 20 neighbors.
# Point 155 has 19 neighbors.
# Point 156 has 13 neighbors.
# Point 157 has 21 neighbors.
# Point 158 has 21 neighbors.
# Point 159 has 19 neighbors.
# Point 160 has 21 neighbors.
# Point 161 has 20 neighbors.
# Point 162 has 19 neighbors.
# Point 163 has 20 neighbors.
# Point 164 has 19 neighbors.
# Point 165 has 21 neighbors.
# Point 166 has 21 neighbors.
# Point 167 has 15 neighbors.
# Point 168 has 17 neighbors.
# Point 169 has 20 neighbors.
# Point 170 has 20 neighbors.
# Point 171 has 20 neighbors.
# Point 172 has 19 neighbors.
# Point 173 has 19 neighbors.
# Point 174 has 21 neighbors.
# Point 175 has 21 neighbors.
# Point 176 has 19 neighbors.
# Point 177 has 19 neighbors.
# Point 178 has 22 neighbors.
# Point 179 has 22 neighbors.
# Point 180 has 20 neighbors.
# Point 181 has 19 neighbors.
# Point 182 has 19 neighbors.
# Point 183 has 21 neighbors.
# Point 184 has 21 neighbors.
# Point 185 has 20 neighbors.
# Point 186 has 20 neighbors.
# Point 187 has 13 neighbors.
# Point 188 has 14 neighbors.
# Point 189 has 19 neighbors.
# Point 190 has 13 neighbors.
# Point 191 has 15 neighbors.
# Point 192 has 21 neighbors.
# Point 193 has 21 neighbors.
# Point 194 has 21 neighbors.
# Point 195 has 21 neighbors.
# Point 196 has 19 neighbors.
# Point 197 has 19 neighbors.
# Point 198 has 21 neighbors.
# Point 199 has 19 neighbors.
# Point 200 has 21 neighbors.
# Point 201 has 22 neighbors.
# Point 202 has 21 neighbors.
# Point 203 has 8 neighbors.
# Point 204 has 20 neighbors.
# Point 205 has 21 neighbors.
# Point 206 has 13 neighbors.
# Point 207 has 12 neighbors.
# Point 208 has 18 neighbors.
# Point 209 has 21 neighbors.
# Point 210 has 18 neighbors.
# Point 211 has 21 neighbors.
# Point 212 has 20 neighbors.
# Point 213 has 19 neighbors.
# Point 214 has 21 neighbors.
# Point 215 has 21 neighbors.
# Point 216 has 21 neighbors.
# Point 217 has 19 neighbors.
# Point 218 has 19 neighbors.
# Point 219 has 19 neighbors.
# Point 220 has 21 neighbors.
# Point 221 has 21 neighbors.
# Point 222 has 21 neighbors.
# Point 223 has 21 neighbors.
# Point 224 has 20 neighbors.
# Point 225 has 21 neighbors.
# Point 226 has 11 neighbors.
# Point 227 has 17 neighbors.
# Point 228 has 19 neighbors.
# Point 229 has 21 neighbors.
# Point 230 has 19 neighbors.
# Point 231 has 21 neighbors.
# Point 232 has 19 neighbors.
# Point 233 has 19 neighbors.
# Point 234 has 18 neighbors.
# Point 235 has 14 neighbors.
# Point 236 has 21 neighbors.
# Point 237 has 18 neighbors.
# Point 238 has 18 neighbors.
# Point 239 has 21 neighbors.
# Point 240 has 21 neighbors.
# Point 241 has 19 neighbors.
# Point 242 has 21 neighbors.
# Point 243 has 21 neighbors.
# Point 244 has 21 neighbors.
# Point 245 has 11 neighbors.
# Point 246 has 19 neighbors.
# Point 247 has 21 neighbors.
# Point 248 has 21 neighbors.
# Point 249 has 18 neighbors.
# Point 250 has 21 neighbors.
# Point 251 has 21 neighbors.
# Point 252 has 19 neighbors.
# Point 253 has 14 neighbors.
# Point 254 has 21 neighbors.
# Point 255 has 16 neighbors.
# Point 256 has 19 neighbors.
# Point 257 has 22 neighbors.
# Point 258 has 20 neighbors.
# Point 259 has 20 neighbors.
# Point 260 has 21 neighbors.
# Point 261 has 19 neighbors.
# Point 262 has 21 neighbors.
# Point 263 has 19 neighbors.
# Point 264 has 15 neighbors.
# Point 265 has 21 neighbors.
# Point 266 has 22 neighbors.
# Point 267 has 22 neighbors.
# Point 268 has 19 neighbors.
# Point 269 has 20 neighbors.
# Point 270 has 14 neighbors.
# Point 271 has 17 neighbors.
# Point 272 has 21 neighbors.
# Point 273 has 13 neighbors.
# Point 274 has 14 neighbors.
# Point 275 has 21 neighbors.
# Point 276 has 19 neighbors.
# Point 277 has 20 neighbors.
# Point 278 has 16 neighbors.
# Point 279 has 21 neighbors.
# Point 280 has 21 neighbors.
# Point 281 has 20 neighbors.
# Point 282 has 19 neighbors.
# Point 283 has 22 neighbors.
# Point 284 has 21 neighbors.
# Point 285 has 16 neighbors.
# Point 286 has 20 neighbors.
# Point 287 has 21 neighbors.
# Point 288 has 13 neighbors.
# Point 289 has 17 neighbors.
# Point 290 has 19 neighbors.
# Point 291 has 21 neighbors.
# Point 292 has 20 neighbors.
# Point 293 has 21 neighbors.
# Point 294 has 19 neighbors.
# Point 295 has 21 neighbors.
# Point 296 has 19 neighbors.
# Point 297 has 15 neighbors.
# Point 298 has 13 neighbors.
# Point 299 has 20 neighbors.
# Point 300 has 19 neighbors.
# Point 301 has 18 neighbors.
# Point 302 has 19 neighbors.
# Point 303 has 19 neighbors.
# Point 304 has 22 neighbors.
# Point 305 has 19 neighbors.
# Point 306 has 19 neighbors.
# Point 307 has 21 neighbors.
# Point 308 has 21 neighbors.
# Point 309 has 18 neighbors.
# Point 310 has 20 neighbors.
# Point 311 has 21 neighbors.
# Point 312 has 20 neighbors.
# Point 313 has 19 neighbors.
# Point 314 has 21 neighbors.
# Point 315 has 16 neighbors.
# Point 316 has 21 neighbors.
# Point 317 has 21 neighbors.
# Point 318 has 14 neighbors.
# Point 319 has 19 neighbors.
# Point 320 has 20 neighbors.
# Point 321 has 16 neighbors.
# Point 322 has 19 neighbors.
# Point 323 has 21 neighbors.
# Point 324 has 21 neighbors.
# Point 325 has 20 neighbors.
# Point 326 has 11 neighbors.
# Point 327 has 10 neighbors.
# Point 328 has 21 neighbors.
# Point 329 has 15 neighbors.
# Point 330 has 19 neighbors.
# Point 331 has 12 neighbors.
# Point 332 has 20 neighbors.
# Point 333 has 21 neighbors.
# Point 334 has 19 neighbors.
# Point 335 has 19 neighbors.
# Point 336 has 21 neighbors.
# Point 337 has 21 neighbors.
# Point 338 has 21 neighbors.
# Point 339 has 15 neighbors.
# Point 340 has 21 neighbors.
# Point 341 has 19 neighbors.
# Point 342 has 20 neighbors.
# Point 343 has 19 neighbors.
# Point 344 has 19 neighbors.
# Point 345 has 12 neighbors.
# Point 346 has 11 neighbors.
# Point 347 has 21 neighbors.
# Point 348 has 19 neighbors.
# Point 349 has 21 neighbors.
# Point 350 has 20 neighbors.
# Point 351 has 18 neighbors.
# Point 352 has 20 neighbors.
# Point 353 has 21 neighbors.
# Point 354 has 8 neighbors.
# Point 355 has 19 neighbors.
# Point 356 has 21 neighbors.
# Point 357 has 22 neighbors.
# Point 358 has 18 neighbors.
# Point 359 has 21 neighbors.
# Point 360 has 21 neighbors.
# Point 361 has 21 neighbors.
# Point 362 has 19 neighbors.
# Point 363 has 21 neighbors.
# Point 364 has 22 neighbors.
# Point 365 has 21 neighbors.
# Point 366 has 14 neighbors.
# Point 367 has 22 neighbors.
# Point 368 has 11 neighbors.
# Point 369 has 21 neighbors.
# Point 370 has 20 neighbors.
# Point 371 has 20 neighbors.
# Point 372 has 20 neighbors.
# Point 373 has 15 neighbors.
# Point 374 has 21 neighbors.
# Point 375 has 14 neighbors.
# Point 376 has 19 neighbors.
# Point 377 has 19 neighbors.
# Point 378 has 20 neighbors.
# Point 379 has 19 neighbors.
# Point 380 has 20 neighbors.
# Point 381 has 22 neighbors.
# Point 382 has 20 neighbors.
# Point 383 has 11 neighbors.
# Point 384 has 19 neighbors.
# Point 385 has 19 neighbors.
# Point 386 has 20 neighbors.
# Point 387 has 19 neighbors.
# Point 388 has 20 neighbors.
# Point 389 has 20 neighbors.
# Point 390 has 19 neighbors.
# Point 391 has 8 neighbors.
# Point 392 has 20 neighbors.
# Point 393 has 20 neighbors.
# Point 394 has 19 neighbors.
# Point 395 has 21 neighbors.
# Point 396 has 15 neighbors.
# Point 397 has 21 neighbors.
# Point 398 has 16 neighbors.
# Point 399 has 21 neighbors.
# Point 400 has 20 neighbors.
# Point 401 has 17 neighbors.
# Point 402 has 19 neighbors.
# Point 403 has 21 neighbors.
# Point 404 has 20 neighbors.
# Point 405 has 19 neighbors.
# Point 406 has 12 neighbors.
# Point 407 has 21 neighbors.
# Point 408 has 20 neighbors.
# Point 409 has 22 neighbors.
# Point 410 has 21 neighbors.
# Point 411 has 17 neighbors.
# Point 412 has 22 neighbors.
# Point 413 has 18 neighbors.
# Point 414 has 19 neighbors.
# Point 415 has 22 neighbors.
# Point 416 has 21 neighbors.
# Point 417 has 21 neighbors.
# Point 418 has 19 neighbors.
# Point 419 has 19 neighbors.
# Point 420 has 21 neighbors.
# Point 421 has 21 neighbors.
# Point 422 has 19 neighbors.
# Point 423 has 20 neighbors.
# Point 424 has 21 neighbors.
# Point 425 has 19 neighbors.
# Point 426 has 20 neighbors.
# Point 427 has 21 neighbors.
# Point 428 has 19 neighbors.
# Point 429 has 22 neighbors.
# Point 430 has 21 neighbors.
# Point 431 has 17 neighbors.
# Point 432 has 16 neighbors.
# Point 433 has 19 neighbors.
# Point 434 has 21 neighbors.
# Point 435 has 20 neighbors.
# Point 436 has 21 neighbors.
# Point 437 has 8 neighbors.
# Point 438 has 19 neighbors.
# Point 439 has 21 neighbors.
# Point 440 has 19 neighbors.
# Point 441 has 19 neighbors.
# Point 442 has 19 neighbors.
# Point 443 has 22 neighbors.
# Point 444 has 22 neighbors.
# Point 445 has 21 neighbors.
# Point 446 has 20 neighbors.
# Point 447 has 19 neighbors.
# Point 448 has 21 neighbors.
# Point 449 has 21 neighbors.
# Point 450 has 22 neighbors.
# Point 451 has 20 neighbors.
# Point 452 has 21 neighbors.
# Point 453 has 20 neighbors.
# Point 454 has 19 neighbors.
# Point 455 has 22 neighbors.
# Point 456 has 21 neighbors.
# Point 457 has 19 neighbors.
# Point 458 has 19 neighbors.
# Point 459 has 21 neighbors.
# Point 460 has 21 neighbors.
# Point 461 has 21 neighbors.
# Point 462 has 19 neighbors.
# Point 463 has 19 neighbors.
# Point 464 has 21 neighbors.
# Point 465 has 15 neighbors.
# Point 466 has 20 neighbors.
# Point 467 has 19 neighbors.
# Point 468 has 21 neighbors.
# Point 469 has 22 neighbors.
# Point 470 has 19 neighbors.
# Point 471 has 21 neighbors.
# Point 472 has 21 neighbors.
# Point 473 has 15 neighbors.
# Point 474 has 21 neighbors.
# Point 475 has 19 neighbors.
# Point 476 has 21 neighbors.
# Point 477 has 19 neighbors.
# Point 478 has 19 neighbors.
# Point 479 has 19 neighbors.
# Point 480 has 21 neighbors.
# Point 481 has 22 neighbors.
# Point 482 has 19 neighbors.
# Point 483 has 14 neighbors.
# Point 484 has 19 neighbors.
# Point 485 has 18 neighbors.
# Point 486 has 19 neighbors.
# Point 487 has 21 neighbors.
# Point 488 has 18 neighbors.
# Point 489 has 9 neighbors.
# Point 490 has 21 neighbors.
# Point 491 has 16 neighbors.
# Point 492 has 19 neighbors.
# Point 493 has 17 neighbors.
# Point 494 has 17 neighbors.
# Point 495 has 21 neighbors.
# Point 496 has 12 neighbors.
# Point 497 has 22 neighbors.
# Point 498 has 21 neighbors.
# Point 499 has 21 neighbors.
# Point 500 has 18 neighbors.
# Point 501 has 21 neighbors.
# Point 502 has 19 neighbors.
# Point 503 has 13 neighbors.
# Point 504 has 20 neighbors.
# Point 505 has 15 neighbors.
# Point 506 has 13 neighbors.
# Point 507 has 21 neighbors.
# Point 508 has 21 neighbors.
# Point 509 has 20 neighbors.
# Point 510 has 16 neighbors.
# Point 511 has 16 neighbors.
# Point 512 has 21 neighbors.
# Point 513 has 20 neighbors.
# Point 514 has 21 neighbors.
# Point 515 has 13 neighbors.
# Point 516 has 20 neighbors.
# Point 517 has 21 neighbors.
# Point 518 has 19 neighbors.
# Point 519 has 16 neighbors.
# Point 520 has 20 neighbors.
# Point 521 has 21 neighbors.
# Point 522 has 18 neighbors.
# Point 523 has 19 neighbors.
# Point 524 has 16 neighbors.
# Point 525 has 20 neighbors.
# Point 526 has 22 neighbors.
# Point 527 has 11 neighbors.
# Point 528 has 22 neighbors.
# Point 529 has 21 neighbors.
# Point 530 has 21 neighbors.
# Point 531 has 21 neighbors.
# Point 532 has 19 neighbors.
# Point 533 has 20 neighbors.
# Point 534 has 11 neighbors.
# Point 535 has 20 neighbors.
# Point 536 has 19 neighbors.
# Point 537 has 22 neighbors.
# Point 538 has 21 neighbors.
# Point 539 has 20 neighbors.
# Point 540 has 21 neighbors.
# Point 541 has 21 neighbors.
# Point 542 has 21 neighbors.
# Point 543 has 21 neighbors.
# Point 544 has 20 neighbors.
# Point 545 has 21 neighbors.
# Point 546 has 17 neighbors.
# Point 547 has 19 neighbors.
# Point 548 has 22 neighbors.
# Point 549 has 19 neighbors.
# Point 550 has 18 neighbors.
# Point 551 has 21 neighbors.
# Point 552 has 12 neighbors.
# Point 553 has 18 neighbors.
# Point 554 has 21 neighbors.
# Point 555 has 21 neighbors.
# Point 556 has 21 neighbors.
# Point 557 has 20 neighbors.
# Point 558 has 19 neighbors.
# Point 559 has 21 neighbors.
# Point 560 has 20 neighbors.
# Point 561 has 20 neighbors.
# Point 562 has 19 neighbors.
# Point 563 has 21 neighbors.
# Point 564 has 19 neighbors.
# Point 565 has 18 neighbors.
# Point 566 has 9 neighbors.
# Point 567 has 22 neighbors.
# Point 568 has 11 neighbors.
# Point 569 has 20 neighbors.
# Point 570 has 19 neighbors.
# Point 571 has 19 neighbors.
# Point 572 has 21 neighbors.
# Point 573 has 20 neighbors.
# Point 574 has 19 neighbors.
# Point 575 has 19 neighbors.
# Point 576 has 19 neighbors.
# Point 577 has 21 neighbors.
# Point 578 has 20 neighbors.
# Point 579 has 18 neighbors.
# Point 580 has 12 neighbors.
# Point 581 has 20 neighbors.
# Point 582 has 20 neighbors.
# Point 583 has 21 neighbors.
# Point 584 has 20 neighbors.
# Point 585 has 22 neighbors.
# Point 586 has 21 neighbors.
# Point 587 has 20 neighbors.
# Point 588 has 21 neighbors.
# Point 589 has 22 neighbors.
# Point 590 has 21 neighbors.
# Point 591 has 18 neighbors.
# Point 592 has 13 neighbors.
# Point 593 has 8 neighbors.
# Point 594 has 21 neighbors.
# Point 595 has 21 neighbors.
# Point 596 has 19 neighbors.
# Point 597 has 22 neighbors.
# Point 598 has 21 neighbors.
# Point 599 has 19 neighbors.
# Point 600 has 21 neighbors.
# Point 601 has 22 neighbors.
# Point 602 has 14 neighbors.
# Point 603 has 13 neighbors.
# Point 604 has 19 neighbors.
# Point 605 has 19 neighbors.
# Point 606 has 19 neighbors.
# Point 607 has 21 neighbors.
# Point 608 has 21 neighbors.
# Point 609 has 22 neighbors.
# Point 610 has 20 neighbors.
# Point 611 has 21 neighbors.
# Point 612 has 20 neighbors.
# Point 613 has 21 neighbors.
# Point 614 has 19 neighbors.
# Point 615 has 19 neighbors.
# Point 616 has 19 neighbors.
# Point 617 has 20 neighbors.
# Point 618 has 19 neighbors.
# Point 619 has 19 neighbors.
# Point 620 has 19 neighbors.
# Point 621 has 12 neighbors.
# Point 622 has 22 neighbors.
# Point 623 has 21 neighbors.
# Point 624 has 19 neighbors.
# Point 625 has 21 neighbors.
# Point 626 has 14 neighbors.
# Point 627 has 20 neighbors.
# Point 628 has 21 neighbors.
# Point 629 has 21 neighbors.
# Point 630 has 20 neighbors.
# Point 631 has 20 neighbors.
# Point 632 has 21 neighbors.
# Point 633 has 19 neighbors.
# Point 634 has 19 neighbors.
# Point 635 has 21 neighbors.
# Point 636 has 20 neighbors.
# Point 637 has 19 neighbors.
# Point 638 has 21 neighbors.
# Point 639 has 22 neighbors.
# Point 640 has 14 neighbors.
# Point 641 has 22 neighbors.
# Point 642 has 20 neighbors.
# Point 643 has 21 neighbors.
# Point 644 has 20 neighbors.
# Point 645 has 21 neighbors.
# Point 646 has 22 neighbors.
# Point 647 has 19 neighbors.
# Point 648 has 20 neighbors.
# Point 649 has 21 neighbors.
# Point 650 has 21 neighbors.
# Point 651 has 21 neighbors.
# Point 652 has 20 neighbors.
# Point 653 has 19 neighbors.
# Point 654 has 9 neighbors.
# Point 655 has 21 neighbors.
# Point 656 has 15 neighbors.
# Point 657 has 21 neighbors.
# Point 658 has 19 neighbors.
# Point 659 has 19 neighbors.
# Point 660 has 21 neighbors.
# Point 661 has 20 neighbors.
# Point 662 has 21 neighbors.
# Point 663 has 16 neighbors.
# Point 664 has 21 neighbors.
# Point 665 has 21 neighbors.
# Point 666 has 19 neighbors.
# Point 667 has 19 neighbors.
# Point 668 has 20 neighbors.
# Point 669 has 20 neighbors.
# Point 670 has 21 neighbors.
# Point 671 has 12 neighbors.
# Point 672 has 21 neighbors.
# Point 673 has 17 neighbors.
# Point 674 has 17 neighbors.
# Point 675 has 19 neighbors.
# Point 676 has 21 neighbors.
# Point 677 has 18 neighbors.
# Point 678 has 13 neighbors.
# Point 679 has 16 neighbors.
# Point 680 has 11 neighbors.
# Point 681 has 20 neighbors.
# Point 682 has 20 neighbors.
# Point 683 has 20 neighbors.
# Point 684 has 21 neighbors.
# Point 685 has 21 neighbors.
# Point 686 has 21 neighbors.
# Point 687 has 10 neighbors.
# Point 688 has 20 neighbors.
# Point 689 has 21 neighbors.
# Point 690 has 19 neighbors.
# Point 691 has 21 neighbors.
# Point 692 has 20 neighbors.
# Point 693 has 19 neighbors.
# Point 694 has 21 neighbors.
# Point 695 has 17 neighbors.
# Point 696 has 21 neighbors.
# Point 697 has 19 neighbors.
# Point 698 has 19 neighbors.
# Point 699 has 21 neighbors.
# Point 700 has 20 neighbors.
# Point 701 has 19 neighbors.
# Point 702 has 17 neighbors.
# Point 703 has 21 neighbors.
# Point 704 has 20 neighbors.
# Point 705 has 21 neighbors.
# Point 706 has 21 neighbors.
# Point 707 has 19 neighbors.
# Point 708 has 15 neighbors.
# Point 709 has 10 neighbors.
# Point 710 has 17 neighbors.
# Point 711 has 21 neighbors.
# Point 712 has 21 neighbors.
# Point 713 has 19 neighbors.
# Point 714 has 21 neighbors.
# Point 715 has 19 neighbors.
# Point 716 has 19 neighbors.
# Point 717 has 21 neighbors.
# Point 718 has 18 neighbors.
# Point 719 has 19 neighbors.
# Point 720 has 19 neighbors.
# Point 721 has 19 neighbors.
# Point 722 has 21 neighbors.
# Point 723 has 20 neighbors.
# Point 724 has 20 neighbors.
# Point 725 has 20 neighbors.
# Point 726 has 15 neighbors.
# Point 727 has 21 neighbors.
# Point 728 has 21 neighbors.
# Point 729 has 15 neighbors.
# Point 730 has 20 neighbors.
# Point 731 has 20 neighbors.
# Point 732 has 19 neighbors.
# Point 733 has 21 neighbors.
# Point 734 has 16 neighbors.
# Point 735 has 19 neighbors.
# Point 736 has 19 neighbors.
# Point 737 has 22 neighbors.
# Point 738 has 10 neighbors.
# Point 739 has 20 neighbors.
# Point 740 has 20 neighbors.
# Point 741 has 20 neighbors.
# Point 742 has 21 neighbors.
# Point 743 has 21 neighbors.
# Point 744 has 19 neighbors.
# Point 745 has 20 neighbors.
# Point 746 has 20 neighbors.
# Point 747 has 19 neighbors.
# Point 748 has 21 neighbors.
# Point 749 has 21 neighbors.
# Point 750 has 19 neighbors.
# Point 751 has 20 neighbors.
# Point 752 has 20 neighbors.
# Point 753 has 11 neighbors.
# Point 754 has 14 neighbors.
# Point 755 has 12 neighbors.
# Point 756 has 22 neighbors.
# Point 757 has 20 neighbors.
# Point 758 has 10 neighbors.
# Point 759 has 19 neighbors.
# Point 760 has 19 neighbors.
# Point 761 has 19 neighbors.
# Point 762 has 19 neighbors.
# Point 763 has 19 neighbors.
# Point 764 has 19 neighbors.
# Point 765 has 20 neighbors.
# Point 766 has 20 neighbors.
# Point 767 has 21 neighbors.
# Point 768 has 22 neighbors.
# Point 769 has 19 neighbors.
# Point 770 has 21 neighbors.
# Point 771 has 17 neighbors.
# Point 772 has 21 neighbors.
# Point 773 has 22 neighbors.
# Point 774 has 21 neighbors.
# Point 775 has 21 neighbors.
# Point 776 has 22 neighbors.
# Point 777 has 11 neighbors.
# Point 778 has 19 neighbors.
# Point 779 has 19 neighbors.
# Point 780 has 16 neighbors.
# Point 781 has 19 neighbors.
# Point 782 has 21 neighbors.
# Point 783 has 20 neighbors.
# Point 784 has 12 neighbors.
# Point 785 has 21 neighbors.
# Point 786 has 21 neighbors.
# Point 787 has 18 neighbors.
# Point 788 has 21 neighbors.
# Point 789 has 20 neighbors.
# Point 790 has 19 neighbors.
# Point 791 has 20 neighbors.
# Point 792 has 21 neighbors.
# Point 793 has 19 neighbors.
# Point 794 has 21 neighbors.
# Point 795 has 21 neighbors.
# Point 796 has 19 neighbors.
# Point 797 has 21 neighbors.
# Point 798 has 13 neighbors.
# Point 799 has 19 neighbors.
# Point 800 has 22 neighbors.
# Point 801 has 12 neighbors.
# Point 802 has 22 neighbors.
# Point 803 has 20 neighbors.
# Point 804 has 21 neighbors.
# Point 805 has 20 neighbors.
# Point 806 has 19 neighbors.
# Point 807 has 10 neighbors.
# Point 808 has 19 neighbors.
# Point 809 has 20 neighbors.
# Point 810 has 18 neighbors.
# Point 811 has 22 neighbors.
# Point 812 has 21 neighbors.
# Point 813 has 20 neighbors.
# Point 814 has 19 neighbors.
# Point 815 has 19 neighbors.
# Point 816 has 21 neighbors.
# Point 817 has 19 neighbors.
# Point 818 has 21 neighbors.
# Point 819 has 21 neighbors.
# Point 820 has 19 neighbors.
# Point 821 has 19 neighbors.
# Point 822 has 22 neighbors.
# Point 823 has 21 neighbors.
# Point 824 has 20 neighbors.
# Point 825 has 19 neighbors.
# Point 826 has 19 neighbors.
# Point 827 has 12 neighbors.
# Point 828 has 20 neighbors.
# Point 829 has 20 neighbors.
# Point 830 has 21 neighbors.
# Point 831 has 21 neighbors.
# Point 832 has 21 neighbors.
# Point 833 has 19 neighbors.
# Point 834 has 11 neighbors.
# Point 835 has 19 neighbors.
# Point 836 has 21 neighbors.
# Point 837 has 19 neighbors.
# Point 838 has 18 neighbors.
# Point 839 has 11 neighbors.
# Point 840 has 15 neighbors.
# Point 841 has 21 neighbors.
# Point 842 has 21 neighbors.
# Point 843 has 20 neighbors.
# Point 844 has 20 neighbors.
# Point 845 has 19 neighbors.
# Point 846 has 19 neighbors.
# Point 847 has 21 neighbors.
# Point 848 has 19 neighbors.
# Point 849 has 19 neighbors.
# Point 850 has 21 neighbors.
# Point 851 has 19 neighbors.
# Point 852 has 18 neighbors.
# Point 853 has 22 neighbors.
# Point 854 has 22 neighbors.
# Point 855 has 14 neighbors.
# Point 856 has 22 neighbors.
# Point 857 has 18 neighbors.
# Point 858 has 21 neighbors.
# Point 859 has 19 neighbors.
# Point 860 has 20 neighbors.
# Point 861 has 21 neighbors.
# Point 862 has 14 neighbors.
# Point 863 has 21 neighbors.
# Point 864 has 15 neighbors.
# Point 865 has 17 neighbors.
# Point 866 has 15 neighbors.
# Point 867 has 19 neighbors.
# Point 868 has 19 neighbors.
# Point 869 has 19 neighbors.
# Point 870 has 19 neighbors.
# Point 871 has 21 neighbors.
# Point 872 has 20 neighbors.
# Point 873 has 20 neighbors.
# Point 874 has 20 neighbors.
# Point 875 has 22 neighbors.
# Point 876 has 22 neighbors.
# Point 877 has 19 neighbors.
# Point 878 has 21 neighbors.
# Point 879 has 21 neighbors.
# Point 880 has 19 neighbors.
# Point 881 has 13 neighbors.
# Point 882 has 20 neighbors.
# Point 883 has 20 neighbors.
# Point 884 has 19 neighbors.
# Point 885 has 21 neighbors.
# Point 886 has 21 neighbors.
# Point 887 has 21 neighbors.
# Point 888 has 16 neighbors.
# Point 889 has 20 neighbors.
# Point 890 has 19 neighbors.
# Point 891 has 19 neighbors.
# Point 892 has 22 neighbors.
# Point 893 has 21 neighbors.
# Point 894 has 17 neighbors.
# Point 895 has 21 neighbors.
# Point 896 has 21 neighbors.
# Point 897 has 15 neighbors.
# Point 898 has 21 neighbors.
# Point 899 has 21 neighbors.
# Point 900 has 21 neighbors.
# Point 901 has 20 neighbors.
# Point 902 has 21 neighbors.
# Point 903 has 19 neighbors.
# Point 904 has 22 neighbors.
# Point 905 has 22 neighbors.
# Point 906 has 19 neighbors.
# Point 907 has 20 neighbors.
# Point 908 has 21 neighbors.
# Point 909 has 20 neighbors.
# Point 910 has 21 neighbors.
# Point 911 has 19 neighbors.
# Point 912 has 20 neighbors.
# Point 913 has 21 neighbors.
# Point 914 has 19 neighbors.
# Point 915 has 16 neighbors.
# Point 916 has 15 neighbors.
# Point 917 has 17 neighbors.
# Point 918 has 21 neighbors.
# Point 919 has 19 neighbors.
# Point 920 has 21 neighbors.
# Point 921 has 21 neighbors.
# Point 922 has 20 neighbors.
# Point 923 has 21 neighbors.
# Point 924 has 18 neighbors.
# Point 925 has 19 neighbors.
# Point 926 has 14 neighbors.
# Point 927 has 19 neighbors.
# Point 928 has 17 neighbors.
# Point 929 has 22 neighbors.
# Point 930 has 21 neighbors.
# Point 931 has 20 neighbors.
# Point 932 has 19 neighbors.
# Point 933 has 15 neighbors.
# Point 934 has 21 neighbors.
# Point 935 has 21 neighbors.
# Point 936 has 19 neighbors.
# Point 937 has 16 neighbors.
# Point 938 has 19 neighbors.
# Point 939 has 16 neighbors.
# Point 940 has 20 neighbors.
# Point 941 has 19 neighbors.
# Point 942 has 18 neighbors.
# Point 943 has 19 neighbors.
# Point 944 has 22 neighbors.
# Point 945 has 19 neighbors.
# Point 946 has 10 neighbors.
# Point 947 has 21 neighbors.
# Point 948 has 20 neighbors.
# Point 949 has 21 neighbors.
# Point 950 has 19 neighbors.
# Point 951 has 19 neighbors.
# Point 952 has 21 neighbors.
# Point 953 has 21 neighbors.
# Point 954 has 19 neighbors.
# Point 955 has 17 neighbors.
# Point 956 has 21 neighbors.
# Point 957 has 20 neighbors.
# Point 958 has 19 neighbors.
# Point 959 has 20 neighbors.
# Point 960 has 19 neighbors.
# Point 961 has 21 neighbors.
# Point 962 has 20 neighbors.
# Point 963 has 21 neighbors.
# Point 964 has 20 neighbors.
# Point 965 has 21 neighbors.
# Point 966 has 21 neighbors.
# Point 967 has 21 neighbors.
# Point 968 has 20 neighbors.
# Point 969 has 19 neighbors.
# Point 970 has 21 neighbors.
# Point 971 has 21 neighbors.
# Point 972 has 18 neighbors.
# Point 973 has 21 neighbors.
# Point 974 has 19 neighbors.
# Point 975 has 19 neighbors.
# Point 976 has 17 neighbors.
# Point 977 has 21 neighbors.
# Point 978 has 20 neighbors.
# Point 979 has 21 neighbors.
# Point 980 has 19 neighbors.
# Point 981 has 21 neighbors.
# Point 982 has 19 neighbors.
# Point 983 has 21 neighbors.
# Point 984 has 21 neighbors.
# Point 985 has 15 neighbors.
# Point 986 has 21 neighbors.
# Point 987 has 15 neighbors.
# Point 988 has 21 neighbors.
# Point 989 has 17 neighbors.
# Point 990 has 19 neighbors.
# Point 991 has 9 neighbors.
# Point 992 has 19 neighbors.
# Point 993 has 20 neighbors.
# Point 994 has 19 neighbors.
# Point 995 has 19 neighbors.
# Point 996 has 19 neighbors.
# Point 997 has 12 neighbors.
# Point 998 has 21 neighbors.
# Point 999 has 21 neighbors.
# Point 1000 has 22 neighbors.
# Point 1001 has 21 neighbors.
# Point 1002 has 19 neighbors.
# Point 1003 has 18 neighbors.
# Point 1004 has 21 neighbors.
# Point 1005 has 21 neighbors.
# Point 1006 has 21 neighbors.
# Point 1007 has 18 neighbors.
# Point 1008 has 21 neighbors.
# Point 1009 has 20 neighbors.
# Point 1010 has 19 neighbors.
# Point 1011 has 14 neighbors.
# Point 1012 has 11 neighbors.
# Point 1013 has 21 neighbors.
# Point 1014 has 20 neighbors.
# Point 1015 has 18 neighbors.
# Point 1016 has 21 neighbors.
# Point 1017 has 16 neighbors.
# Point 1018 has 22 neighbors.
# Point 1019 has 22 neighbors.
# Point 1020 has 20 neighbors.
# Point 1021 has 19 neighbors.
# Point 1022 has 21 neighbors.
# Point 1023 has 17 neighbors.
# Point 1024 has 20 neighbors.
# Point 1025 has 21 neighbors.
# Point 1026 has 18 neighbors.
# Point 1027 has 16 neighbors.
# Point 1028 has 19 neighbors.
# Point 1029 has 19 neighbors.
# Point 1030 has 20 neighbors.
# Point 1031 has 21 neighbors.
# Point 1032 has 20 neighbors.
# Point 1033 has 16 neighbors.
# Point 1034 has 19 neighbors.
# Point 1035 has 22 neighbors.
# Point 1036 has 7 neighbors.
# Point 1037 has 20 neighbors.
# Point 1038 has 19 neighbors.
# Point 1039 has 21 neighbors.
# Point 1040 has 20 neighbors.
# Point 1041 has 18 neighbors.
# Point 1042 has 21 neighbors.
# Point 1043 has 12 neighbors.
# Point 1044 has 21 neighbors.
# Point 1045 has 22 neighbors.
# Point 1046 has 13 neighbors.
# Point 1047 has 19 neighbors.
# Point 1048 has 21 neighbors.
# Point 1049 has 18 neighbors.
# Point 1050 has 19 neighbors.
# Point 1051 has 20 neighbors.
# Point 1052 has 20 neighbors.
# Point 1053 has 19 neighbors.
# Point 1054 has 21 neighbors.
# Point 1055 has 21 neighbors.
# Point 1056 has 14 neighbors.
# Point 1057 has 21 neighbors.
# Point 1058 has 20 neighbors.
# Point 1059 has 21 neighbors.
# Point 1060 has 19 neighbors.
# Point 1061 has 21 neighbors.
# Point 1062 has 20 neighbors.
# Point 1063 has 21 neighbors.
# Point 1064 has 19 neighbors.
# Point 1065 has 19 neighbors.
# Point 1066 has 21 neighbors.
# Point 1067 has 21 neighbors.
# Point 1068 has 9 neighbors.
# Point 1069 has 20 neighbors.
# Point 1070 has 20 neighbors.
# Point 1071 has 9 neighbors.
# Point 1072 has 19 neighbors.
# Point 1073 has 17 neighbors.
# Point 1074 has 19 neighbors.
# Point 1075 has 19 neighbors.
# Point 1076 has 13 neighbors.
# Point 1077 has 19 neighbors.
# Point 1078 has 21 neighbors.
# Point 1079 has 19 neighbors.
# Point 1080 has 21 neighbors.
# Point 1081 has 20 neighbors.
# Point 1082 has 19 neighbors.
# Point 1083 has 19 neighbors.
# Point 1084 has 17 neighbors.
# Point 1085 has 20 neighbors.
# Point 1086 has 19 neighbors.
# Point 1087 has 21 neighbors.
# Point 1088 has 17 neighbors.
# Point 1089 has 19 neighbors.
# Point 1090 has 21 neighbors.
# Point 1091 has 20 neighbors.
# Point 1092 has 21 neighbors.
# Point 1093 has 20 neighbors.
# Point 1094 has 21 neighbors.
# Point 1095 has 22 neighbors.
# Point 1096 has 11 neighbors.
# Point 1097 has 21 neighbors.
# Point 1098 has 19 neighbors.
# Point 1099 has 20 neighbors.
# Point 1100 has 21 neighbors.
# Point 1101 has 21 neighbors.
# Point 1102 has 18 neighbors.
# Point 1103 has 19 neighbors.
# Point 1104 has 17 neighbors.
# Point 1105 has 20 neighbors.
# Point 1106 has 22 neighbors.
# Point 1107 has 20 neighbors.
# Point 1108 has 21 neighbors.
# Point 1109 has 21 neighbors.
# Point 1110 has 21 neighbors.
# Point 1111 has 20 neighbors.
# Point 1112 has 20 neighbors.
# Point 1113 has 20 neighbors.
# Point 1114 has 19 neighbors.
# Point 1115 has 21 neighbors.
# Point 1116 has 19 neighbors.
# Point 1117 has 20 neighbors.
# Point 1118 has 19 neighbors.
# Point 1119 has 15 neighbors.
# Point 1120 has 19 neighbors.
# Point 1121 has 21 neighbors.
# Point 1122 has 13 neighbors.
# Point 1123 has 19 neighbors.
# Point 1124 has 20 neighbors.
# Point 1125 has 19 neighbors.
# Point 1126 has 22 neighbors.
# Point 1127 has 22 neighbors.
# Point 1128 has 22 neighbors.
# Point 1129 has 22 neighbors.
# Point 1130 has 20 neighbors.
# Point 1131 has 21 neighbors.
# Point 1132 has 14 neighbors.
# Point 1133 has 19 neighbors.
# Point 1134 has 19 neighbors.
# Point 1135 has 20 neighbors.
# Point 1136 has 21 neighbors.
# Point 1137 has 19 neighbors.
# Point 1138 has 21 neighbors.
# Point 1139 has 9 neighbors.
# Point 1140 has 18 neighbors.
# Point 1141 has 21 neighbors.
# Point 1142 has 18 neighbors.
# Point 1143 has 21 neighbors.
# Point 1144 has 19 neighbors.
# Point 1145 has 11 neighbors.
# Point 1146 has 19 neighbors.
# Point 1147 has 21 neighbors.
# Point 1148 has 19 neighbors.
# Point 1149 has 20 neighbors.
# Point 1150 has 19 neighbors.
# Point 1151 has 21 neighbors.
# Point 1152 has 21 neighbors.
# Point 1153 has 21 neighbors.
# Point 1154 has 11 neighbors.
# Point 1155 has 19 neighbors.
# Point 1156 has 20 neighbors.
# Point 1157 has 22 neighbors.
# Point 1158 has 19 neighbors.
# Point 1159 has 19 neighbors.
# Point 1160 has 19 neighbors.
# Point 1161 has 15 neighbors.
# Point 1162 has 21 neighbors.
# Point 1163 has 21 neighbors.
# Point 1164 has 15 neighbors.
# Point 1165 has 20 neighbors.
# Point 1166 has 21 neighbors.
# Point 1167 has 21 neighbors.
# Point 1168 has 21 neighbors.
# Point 1169 has 20 neighbors.
# Point 1170 has 22 neighbors.
# Point 1171 has 19 neighbors.
# Point 1172 has 19 neighbors.
# Point 1173 has 20 neighbors.
# Point 1174 has 20 neighbors.
# Point 1175 has 21 neighbors.
# Point 1176 has 20 neighbors.
# Point 1177 has 18 neighbors.
# Point 1178 has 21 neighbors.
# Point 1179 has 22 neighbors.
# Point 1180 has 12 neighbors.
# Point 1181 has 19 neighbors.
# Point 1182 has 22 neighbors.
# Point 1183 has 22 neighbors.
# Point 1184 has 21 neighbors.
# Point 1185 has 14 neighbors.
# Point 1186 has 19 neighbors.
# Point 1187 has 21 neighbors.
# Point 1188 has 21 neighbors.
# Point 1189 has 21 neighbors.
# Point 1190 has 17 neighbors.
# Point 1191 has 12 neighbors.
# Point 1192 has 19 neighbors.
# Point 1193 has 16 neighbors.
# Point 1194 has 21 neighbors.
# Point 1195 has 21 neighbors.
# Point 1196 has 21 neighbors.
# Point 1197 has 19 neighbors.
# Point 1198 has 22 neighbors.
# Point 1199 has 18 neighbors.
# Point 1200 has 21 neighbors.
# Point 1201 has 19 neighbors.
# Point 1202 has 14 neighbors.
# Point 1203 has 21 neighbors.
# Point 1204 has 14 neighbors.
# Point 1205 has 22 neighbors.
# Point 1206 has 17 neighbors.
# Point 1207 has 22 neighbors.
# Point 1208 has 21 neighbors.
# Point 1209 has 21 neighbors.
# Point 1210 has 20 neighbors.
# Point 1211 has 22 neighbors.
# Point 1212 has 21 neighbors.
# Point 1213 has 19 neighbors.
# Point 1214 has 21 neighbors.
# Point 1215 has 18 neighbors.
# Point 1216 has 18 neighbors.
# Point 1217 has 19 neighbors.
# Point 1218 has 22 neighbors.
# Point 1219 has 21 neighbors.
# Point 1220 has 15 neighbors.
# Point 1221 has 21 neighbors.
# Point 1222 has 19 neighbors.
# Point 1223 has 22 neighbors.
# Point 1224 has 19 neighbors.
# Point 1225 has 21 neighbors.
# Point 1226 has 21 neighbors.
# Point 1227 has 12 neighbors.
# Point 1228 has 22 neighbors.
# Point 1229 has 17 neighbors.
# Point 1230 has 20 neighbors.
# Point 1231 has 22 neighbors.
# Point 1232 has 19 neighbors.
# Point 1233 has 20 neighbors.
# Point 1234 has 21 neighbors.
# Point 1235 has 20 neighbors.
# Point 1236 has 22 neighbors.
# Point 1237 has 21 neighbors.
# Point 1238 has 11 neighbors.
# Point 1239 has 20 neighbors.
# Point 1240 has 20 neighbors.
# Point 1241 has 13 neighbors.
# Point 1242 has 20 neighbors.
# Point 1243 has 19 neighbors.
# Point 1244 has 20 neighbors.
# Point 1245 has 21 neighbors.
# Point 1246 has 20 neighbors.
# Point 1247 has 19 neighbors.
# Point 1248 has 20 neighbors.
# Point 1249 has 14 neighbors.
# Point 1250 has 21 neighbors.
# Point 1251 has 20 neighbors.
# Point 1252 has 19 neighbors.
# Point 1253 has 19 neighbors.
# Point 1254 has 22 neighbors.
# Point 1255 has 21 neighbors.
# Point 1256 has 19 neighbors.
# Point 1257 has 21 neighbors.
# Point 1258 has 21 neighbors.
# Point 1259 has 22 neighbors.
# Point 1260 has 22 neighbors.
# Point 1261 has 22 neighbors.
# Point 1262 has 18 neighbors.
# Point 1263 has 13 neighbors.
# Point 1264 has 18 neighbors.
# Point 1265 has 21 neighbors.
# Point 1266 has 21 neighbors.
# Point 1267 has 20 neighbors.
# Point 1268 has 19 neighbors.
# Point 1269 has 21 neighbors.
# Point 1270 has 16 neighbors.
# Point 1271 has 13 neighbors.
# Point 1272 has 21 neighbors.
# Point 1273 has 19 neighbors.
# Point 1274 has 15 neighbors.
# Point 1275 has 22 neighbors.
# Point 1276 has 21 neighbors.
# Point 1277 has 21 neighbors.
# Point 1278 has 11 neighbors.
# Point 1279 has 21 neighbors.
# Point 1280 has 20 neighbors.
# Point 1281 has 20 neighbors.
# Point 1282 has 21 neighbors.
# Point 1283 has 21 neighbors.
# Point 1284 has 19 neighbors.
# Point 1285 has 20 neighbors.
# Point 1286 has 20 neighbors.
# Point 1287 has 18 neighbors.
# Point 1288 has 20 neighbors.
# Point 1289 has 21 neighbors.
# Point 1290 has 14 neighbors.
# Point 1291 has 19 neighbors.
# Point 1292 has 18 neighbors.
# Point 1293 has 21 neighbors.
# Point 1294 has 21 neighbors.
# Point 1295 has 21 neighbors.
# Point 1296 has 21 neighbors.
# Point 1297 has 20 neighbors.
# Point 1298 has 20 neighbors.
# Point 1299 has 21 neighbors.
# Point 1300 has 19 neighbors.
# Point 1301 has 20 neighbors.
# Point 1302 has 21 neighbors.
# Point 1303 has 19 neighbors.
# Point 1304 has 19 neighbors.
# Point 1305 has 21 neighbors.
# Point 1306 has 19 neighbors.
# Point 1307 has 21 neighbors.
# Point 1308 has 20 neighbors.
# Point 1309 has 17 neighbors.
# Point 1310 has 21 neighbors.
# Point 1311 has 20 neighbors.
# Point 1312 has 17 neighbors.
# Point 1313 has 21 neighbors.
# Point 1314 has 20 neighbors.
# Point 1315 has 19 neighbors.
# Point 1316 has 20 neighbors.
# Point 1317 has 17 neighbors.
# Point 1318 has 22 neighbors.
# Point 1319 has 19 neighbors.
# Point 1320 has 19 neighbors.
# Point 1321 has 13 neighbors.
# Point 1322 has 19 neighbors.
# Point 1323 has 22 neighbors.
# Point 1324 has 21 neighbors.
# Point 1325 has 18 neighbors.
# Point 1326 has 12 neighbors.
# Point 1327 has 19 neighbors.
# Point 1328 has 19 neighbors.
# Point 1329 has 22 neighbors.
# Point 1330 has 21 neighbors.
# Point 1331 has 19 neighbors.
# Point 1332 has 22 neighbors.
# Point 1333 has 14 neighbors.
# Point 1334 has 20 neighbors.
# Point 1335 has 20 neighbors.
# Point 1336 has 19 neighbors.
# Point 1337 has 22 neighbors.
# Point 1338 has 17 neighbors.
# Point 1339 has 16 neighbors.
# Point 1340 has 16 neighbors.
# Point 1341 has 15 neighbors.
# Point 1342 has 22 neighbors.
# Point 1343 has 21 neighbors.
# Point 1344 has 20 neighbors.
# Point 1345 has 20 neighbors.
# Point 1346 has 22 neighbors.
# Point 1347 has 19 neighbors.
# Point 1348 has 19 neighbors.
# Point 1349 has 22 neighbors.
# Point 1350 has 19 neighbors.
# Point 1351 has 22 neighbors.
# Point 1352 has 21 neighbors.
# Point 1353 has 19 neighbors.
# Point 1354 has 21 neighbors.
# Point 1355 has 21 neighbors.
# Point 1356 has 20 neighbors.
# Point 1357 has 12 neighbors.
# Point 1358 has 22 neighbors.
# Point 1359 has 21 neighbors.
# Point 1360 has 12 neighbors.
# Point 1361 has 20 neighbors.
# Point 1362 has 21 neighbors.
# Point 1363 has 16 neighbors.
# Point 1364 has 20 neighbors.
# Point 1365 has 21 neighbors.
# Point 1366 has 19 neighbors.
# Point 1367 has 12 neighbors.
# Point 1368 has 21 neighbors.
# Point 1369 has 18 neighbors.
# Point 1370 has 19 neighbors.
# Point 1371 has 17 neighbors.
# Point 1372 has 22 neighbors.
# Point 1373 has 19 neighbors.
# Point 1374 has 19 neighbors.
# Point 1375 has 21 neighbors.
# Point 1376 has 21 neighbors.
# Point 1377 has 22 neighbors.
# Point 1378 has 18 neighbors.
# Point 1379 has 18 neighbors.
# Point 1380 has 21 neighbors.
# Point 1381 has 19 neighbors.
# Point 1382 has 21 neighbors.
# Point 1383 has 21 neighbors.
# Point 1384 has 21 neighbors.
# Point 1385 has 19 neighbors.
# Point 1386 has 21 neighbors.
# Point 1387 has 20 neighbors.
# Point 1388 has 20 neighbors.
# Point 1389 has 22 neighbors.
# Point 1390 has 12 neighbors.
# Point 1391 has 13 neighbors.
# Point 1392 has 19 neighbors.
# Point 1393 has 18 neighbors.
# Point 1394 has 19 neighbors.
# Point 1395 has 21 neighbors.
# Point 1396 has 20 neighbors.
# Point 1397 has 19 neighbors.
# Point 1398 has 19 neighbors.
# Point 1399 has 22 neighbors.
# Point 1400 has 22 neighbors.
# Point 1401 has 19 neighbors.
# Point 1402 has 22 neighbors.
# Point 1403 has 21 neighbors.
# Point 1404 has 17 neighbors.
# Point 1405 has 10 neighbors.
# Point 1406 has 19 neighbors.
# Point 1407 has 21 neighbors.
# Point 1408 has 19 neighbors.
# Point 1409 has 21 neighbors.
# Point 1410 has 17 neighbors.
# Point 1411 has 21 neighbors.
# Point 1412 has 21 neighbors.
# Point 1413 has 21 neighbors.
# Point 1414 has 8 neighbors.
# Point 1415 has 16 neighbors.
# Point 1416 has 21 neighbors.
# Point 1417 has 19 neighbors.
# Point 1418 has 21 neighbors.
# Point 1419 has 14 neighbors.
# Point 1420 has 22 neighbors.
# Point 1421 has 19 neighbors.
# Point 1422 has 17 neighbors.
# Point 1423 has 21 neighbors.
# Point 1424 has 18 neighbors.
# Point 1425 has 21 neighbors.
# Point 1426 has 21 neighbors.
# Point 1427 has 19 neighbors.
# Point 1428 has 21 neighbors.
# Point 1429 has 18 neighbors.
# Point 1430 has 20 neighbors.
# Point 1431 has 20 neighbors.
# Point 1432 has 18 neighbors.
# Point 1433 has 21 neighbors.
# Point 1434 has 19 neighbors.
# Point 1435 has 22 neighbors.
# Point 1436 has 20 neighbors.
# Point 1437 has 21 neighbors.
# Point 1438 has 21 neighbors.
# Point 1439 has 11 neighbors.
# Point 1440 has 19 neighbors.
# Point 1441 has 20 neighbors.
# Point 1442 has 16 neighbors.
# Point 1443 has 21 neighbors.
# Point 1444 has 18 neighbors.
# Point 1445 has 21 neighbors.
# Point 1446 has 21 neighbors.
# Point 1447 has 21 neighbors.
# Point 1448 has 19 neighbors.
# Point 1449 has 15 neighbors.
# Point 1450 has 21 neighbors.
# Point 1451 has 20 neighbors.
# Point 1452 has 12 neighbors.
# Point 1453 has 19 neighbors.
# Point 1454 has 21 neighbors.
# Point 1455 has 21 neighbors.
# Point 1456 has 19 neighbors.
# Point 1457 has 19 neighbors.
# Point 1458 has 21 neighbors.
# Point 1459 has 20 neighbors.
# Point 1460 has 21 neighbors.
# Point 1461 has 22 neighbors.
# Point 1462 has 20 neighbors.
# Point 1463 has 19 neighbors.
# Point 1464 has 21 neighbors.
# Point 1465 has 22 neighbors.
# Point 1466 has 19 neighbors.
# Point 1467 has 19 neighbors.
# Point 1468 has 21 neighbors.
# Point 1469 has 11 neighbors.
# Point 1470 has 21 neighbors.
# Point 1471 has 19 neighbors.
# Point 1472 has 13 neighbors.
# Point 1473 has 21 neighbors.
# Point 1474 has 21 neighbors.
# Point 1475 has 13 neighbors.
# Point 1476 has 13 neighbors.
# Point 1477 has 21 neighbors.
# Point 1478 has 19 neighbors.
# Point 1479 has 11 neighbors.
# Point 1480 has 20 neighbors.
# Point 1481 has 19 neighbors.
# Point 1482 has 22 neighbors.
# Point 1483 has 20 neighbors.
# Point 1484 has 19 neighbors.
# Point 1485 has 20 neighbors.
# Point 1486 has 18 neighbors.
# Point 1487 has 21 neighbors.
# Point 1488 has 19 neighbors.
# Point 1489 has 21 neighbors.
# Point 1490 has 20 neighbors.
# Point 1491 has 21 neighbors.
# Point 1492 has 19 neighbors.
# Point 1493 has 16 neighbors.
# Point 1494 has 20 neighbors.
# Point 1495 has 22 neighbors.
# Point 1496 has 20 neighbors.
# Point 1497 has 20 neighbors.
# Point 1498 has 19 neighbors.
# Point 1499 has 21 neighbors.
# Point 1500 has 21 neighbors.
# Point 1501 has 22 neighbors.
# Point 1502 has 19 neighbors.
# Point 1503 has 18 neighbors.
# Point 1504 has 18 neighbors.
# Point 1505 has 19 neighbors.
# Point 1506 has 22 neighbors.
# Point 1507 has 21 neighbors.
# Point 1508 has 20 neighbors.
# Point 1509 has 20 neighbors.
# Point 1510 has 12 neighbors.
# Point 1511 has 15 neighbors.
# Point 1512 has 21 neighbors.
# Point 1513 has 21 neighbors.
# Point 1514 has 15 neighbors.
# Point 1515 has 20 neighbors.
# Point 1516 has 19 neighbors.
# Point 1517 has 14 neighbors.
# Point 1518 has 19 neighbors.
# Point 1519 has 21 neighbors.
# Point 1520 has 22 neighbors.
# Point 1521 has 19 neighbors.
# Point 1522 has 22 neighbors.
# Point 1523 has 21 neighbors.
# Point 1524 has 20 neighbors.
# Point 1525 has 19 neighbors.
# Point 1526 has 10 neighbors.
# Point 1527 has 19 neighbors.
# Point 1528 has 20 neighbors.
# Point 1529 has 21 neighbors.
# Point 1530 has 17 neighbors.
# Point 1531 has 20 neighbors.
# Point 1532 has 11 neighbors.
# Point 1533 has 18 neighbors.
# Point 1534 has 21 neighbors.
# Point 1535 has 13 neighbors.
# Point 1536 has 19 neighbors.
# Point 1537 has 19 neighbors.
# Point 1538 has 21 neighbors.
# Point 1539 has 15 neighbors.
# Point 1540 has 20 neighbors.
# Point 1541 has 16 neighbors.
# Point 1542 has 17 neighbors.
# Point 1543 has 22 neighbors.
# Point 1544 has 22 neighbors.
# Point 1545 has 21 neighbors.
# Point 1546 has 15 neighbors.
# Point 1547 has 17 neighbors.
# Point 1548 has 19 neighbors.
# Point 1549 has 20 neighbors.
# Point 1550 has 19 neighbors.
# Point 1551 has 17 neighbors.
# Point 1552 has 17 neighbors.
# Point 1553 has 21 neighbors.
# Point 1554 has 21 neighbors.
# Point 1555 has 19 neighbors.
# Point 1556 has 19 neighbors.
# Point 1557 has 19 neighbors.
# Point 1558 has 19 neighbors.
# Point 1559 has 21 neighbors.
# Point 1560 has 19 neighbors.
# Point 1561 has 20 neighbors.
# Point 1562 has 18 neighbors.
# Point 1563 has 17 neighbors.
# Point 1564 has 19 neighbors.
# Point 1565 has 21 neighbors.
# Point 1566 has 21 neighbors.
# Point 1567 has 19 neighbors.
# Point 1568 has 20 neighbors.
# Point 1569 has 21 neighbors.
# Point 1570 has 20 neighbors.
# Point 1571 has 21 neighbors.
# Point 1572 has 16 neighbors.
# Point 1573 has 20 neighbors.
# Point 1574 has 21 neighbors.
# Point 1575 has 20 neighbors.
# Point 1576 has 21 neighbors.
# Point 1577 has 21 neighbors.
# Point 1578 has 13 neighbors.
# Point 1579 has 21 neighbors.
# Point 1580 has 19 neighbors.
# Point 1581 has 22 neighbors.
# Point 1582 has 20 neighbors.
# Point 1583 has 21 neighbors.
# Point 1584 has 21 neighbors.
# Point 1585 has 21 neighbors.
# Point 1586 has 19 neighbors.
# Point 1587 has 20 neighbors.
# Point 1588 has 14 neighbors.
# Point 1589 has 21 neighbors.
# Point 1590 has 22 neighbors.
# Point 1591 has 21 neighbors.
# Point 1592 has 20 neighbors.
# Point 1593 has 21 neighbors.
# Point 1594 has 18 neighbors.
# Point 1595 has 19 neighbors.
# Point 1596 has 19 neighbors.
# Point 1597 has 21 neighbors.
# Point 1598 has 14 neighbors.
# Point 1599 has 21 neighbors.
# Point 1600 has 20 neighbors.
# Point 1601 has 14 neighbors.
# Point 1602 has 21 neighbors.
# Point 1603 has 19 neighbors.
# Point 1604 has 20 neighbors.
# Point 1605 has 21 neighbors.
# Point 1606 has 19 neighbors.
# Point 1607 has 12 neighbors.
# Point 1608 has 19 neighbors.
# Point 1609 has 16 neighbors.
# Point 1610 has 20 neighbors.
# Point 1611 has 21 neighbors.
# Point 1612 has 20 neighbors.
# Point 1613 has 20 neighbors.
# Point 1614 has 22 neighbors.
# Point 1615 has 19 neighbors.
# Point 1616 has 18 neighbors.
# Point 1617 has 22 neighbors.
# Point 1618 has 22 neighbors.
# Point 1619 has 21 neighbors.
# Point 1620 has 20 neighbors.
# Point 1621 has 19 neighbors.
# Point 1622 has 21 neighbors.
# Point 1623 has 20 neighbors.
# Point 1624 has 19 neighbors.
# Point 1625 has 18 neighbors.
# Point 1626 has 19 neighbors.
# Point 1627 has 21 neighbors.
# Point 1628 has 19 neighbors.
# Point 1629 has 20 neighbors.
# Point 1630 has 22 neighbors.
# Point 1631 has 18 neighbors.
# Point 1632 has 18 neighbors.
# Point 1633 has 21 neighbors.
# Point 1634 has 21 neighbors.
# Point 1635 has 17 neighbors.
# Point 1636 has 19 neighbors.
# Point 1637 has 20 neighbors.
# Point 1638 has 22 neighbors.
# Point 1639 has 20 neighbors.
# Point 1640 has 19 neighbors.
# Point 1641 has 20 neighbors.
# Point 1642 has 19 neighbors.
# Point 1643 has 21 neighbors.
# Point 1644 has 21 neighbors.
# Point 1645 has 21 neighbors.
# Point 1646 has 20 neighbors.
# Point 1647 has 19 neighbors.
# Point 1648 has 19 neighbors.
# Point 1649 has 15 neighbors.
# Point 1650 has 20 neighbors.
# Point 1651 has 20 neighbors.
# Point 1652 has 20 neighbors.
# Point 1653 has 20 neighbors.
# Point 1654 has 19 neighbors.
# Point 1655 has 19 neighbors.
# Point 1656 has 21 neighbors.
# Point 1657 has 22 neighbors.
# Point 1658 has 21 neighbors.
# Point 1659 has 19 neighbors.
# Point 1660 has 19 neighbors.
# Point 1661 has 21 neighbors.
# Point 1662 has 19 neighbors.
# Point 1663 has 16 neighbors.
# Point 1664 has 19 neighbors.
# Point 1665 has 19 neighbors.
# Point 1666 has 22 neighbors.
# Point 1667 has 21 neighbors.
# Point 1668 has 22 neighbors.
# Point 1669 has 20 neighbors.
# Point 1670 has 21 neighbors.
# Point 1671 has 21 neighbors.
# Point 1672 has 21 neighbors.
# Point 1673 has 22 neighbors.
# Point 1674 has 21 neighbors.
# Point 1675 has 21 neighbors.
# Point 1676 has 12 neighbors.
# Point 1677 has 13 neighbors.
# Point 1678 has 21 neighbors.
# Point 1679 has 20 neighbors.
# Point 1680 has 21 neighbors.
# Point 1681 has 21 neighbors.
# Point 1682 has 19 neighbors.
# Point 1683 has 12 neighbors.
# Point 1684 has 19 neighbors.
# Point 1685 has 19 neighbors.
# Point 1686 has 19 neighbors.
# Point 1687 has 18 neighbors.
# Point 1688 has 22 neighbors.
# ...
# Point 50 has 17 neighbors.
# Point 51 has 23 neighbors.
# Point 52 has 23 neighbors.
# Point 53 has 23 neighbors.
# Point 54 has 13 neighbors.
# Point 55 has 23 neighbors.
# Point 56 has 23 neighbors.
# Point 57 has 23 neighbors.
# Point 58 has 19 neighbors.
# Point 59 has 22 neighbors.
# Point 60 has 23 neighbors.
# Point 61 has 23 neighbors.
# Point 62 has 13 neighbors.
# Point 63 has 23 neighbors.
# Point 64 has 23 neighbors.
# Point 65 has 23 neighbors.
# Point 66 has 15 neighbors.
# Point 67 has 23 neighbors.
# Point 68 has 17 neighbors.
# Point 69 has 23 neighbors.
# Point 70 has 17 neighbors.
# Point 71 has 12 neighbors.
# Point 72 has 23 neighbors.
# Point 73 has 19 neighbors.
# Point 74 has 10 neighbors.
# Point 75 has 23 neighbors.
# Point 76 has 15 neighbors.
# Point 77 has 12 neighbors.
# Point 78 has 22 neighbors.
# Point 79 has 22 neighbors.
# Point 80 has 23 neighbors.
# Point 81 has 23 neighbors.
# Point 82 has 23 neighbors.
# Point 83 has 19 neighbors.
# Point 84 has 23 neighbors.
# Point 85 has 20 neighbors.
# Point 86 has 8 neighbors.
# Point 87 has 23 neighbors.
# Point 88 has 23 neighbors.
# Point 89 has 23 neighbors.
# Point 90 has 11 neighbors.
# Point 91 has 23 neighbors.
# Point 92 has 22 neighbors.
# Point 93 has 23 neighbors.
# Point 94 has 23 neighbors.
# Point 95 has 23 neighbors.
# Point 96 has 19 neighbors.
# Point 97 has 23 neighbors.
# Point 98 has 15 neighbors.
# Point 99 has 23 neighbors.
# Point 100 has 23 neighbors.
# Point 101 has 22 neighbors.
# Point 102 has 22 neighbors.
# Point 103 has 23 neighbors.
# Point 104 has 23 neighbors.
# Point 105 has 23 neighbors.
# Point 106 has 19 neighbors.
# Point 107 has 23 neighbors.
# Point 108 has 10 neighbors.
# Point 109 has 23 neighbors.
# Point 110 has 23 neighbors.
# Point 111 has 21 neighbors.
# Point 112 has 18 neighbors.
# Point 113 has 21 neighbors.
# Point 114 has 14 neighbors.
# Point 115 has 13 neighbors.
# Point 116 has 23 neighbors.
# Point 117 has 23 neighbors.
# Point 118 has 21 neighbors.
# Point 119 has 22 neighbors.
# Point 120 has 23 neighbors.
# Point 121 has 23 neighbors.
# Point 122 has 22 neighbors.
# Point 123 has 23 neighbors.
# Point 124 has 23 neighbors.
# Point 125 has 23 neighbors.
# Point 126 has 23 neighbors.
# Point 127 has 17 neighbors.
# Point 128 has 6 neighbors.
# Point 129 has 17 neighbors.
# Point 130 has 16 neighbors.
# Point 131 has 23 neighbors.
# Point 132 has 20 neighbors.
# Point 133 has 9 neighbors.
# Point 134 has 23 neighbors.
# Point 135 has 9 neighbors.
# Point 136 has 17 neighbors.
# Point 137 has 23 neighbors.
# Point 138 has 18 neighbors.
# Point 139 has 23 neighbors.
# Point 140 has 18 neighbors.
# Point 141 has 21 neighbors.
# Point 142 has 23 neighbors.
# Point 143 has 13 neighbors.
# Point 144 has 23 neighbors.
# Point 145 has 13 neighbors.
# Point 146 has 23 neighbors.
# Point 147 has 12 neighbors.
# Point 148 has 23 neighbors.
# Point 149 has 14 neighbors.
# Point 150 has 15 neighbors.
# Point 151 has 22 neighbors.
# Point 152 has 14 neighbors.
# Point 153 has 11 neighbors.
# Point 154 has 22 neighbors.
# Point 155 has 14 neighbors.
# Point 156 has 14 neighbors.
# Point 157 has 22 neighbors.
# Point 158 has 16 neighbors.
# Point 159 has 18 neighbors.
# Point 160 has 10 neighbors.
# Point 161 has 23 neighbors.
# Point 162 has 14 neighbors.
# Point 163 has 14 neighbors.
# Point 164 has 23 neighbors.
# Point 165 has 23 neighbors.
# Point 166 has 23 neighbors.
# Point 167 has 23 neighbors.
# Point 168 has 23 neighbors.
# Point 169 has 23 neighbors.
# Point 170 has 23 neighbors.
# Point 171 has 19 neighbors.
# Point 172 has 23 neighbors.
# Point 173 has 23 neighbors.
# Point 174 has 17 neighbors.
# Point 175 has 12 neighbors.
# Point 176 has 23 neighbors.
# Point 177 has 23 neighbors.
# Point 178 has 23 neighbors.
# Point 179 has 23 neighbors.
# Point 180 has 23 neighbors.
# Point 181 has 23 neighbors.
# Point 182 has 23 neighbors.
# Point 183 has 23 neighbors.
# Point 184 has 23 neighbors.
# Point 185 has 17 neighbors.
# Point 186 has 22 neighbors.
# Point 187 has 21 neighbors.
# Point 188 has 23 neighbors.
# Point 189 has 23 neighbors.
# Point 190 has 19 neighbors.
# Point 191 has 17 neighbors.
# Point 192 has 15 neighbors.
# Point 193 has 21 neighbors.
# Point 194 has 23 neighbors.
# Point 195 has 17 neighbors.
# Point 196 has 20 neighbors.
# Point 197 has 23 neighbors.
# Point 198 has 14 neighbors.
# Point 199 has 20 neighbors.
# Point 200 has 21 neighbors.
# Point 201 has 11 neighbors.
# Point 202 has 23 neighbors.
# Point 203 has 10 neighbors.
# Point 204 has 23 neighbors.
# Point 205 has 18 neighbors.
# Point 206 has 20 neighbors.
# Point 207 has 23 neighbors.
# Point 208 has 13 neighbors.
# Point 209 has 14 neighbors.
# Point 210 has 14 neighbors.
# Point 211 has 23 neighbors.
# Point 212 has 23 neighbors.
# Point 213 has 12 neighbors.
# Point 214 has 14 neighbors.
# Point 215 has 23 neighbors.
# Point 216 has 13 neighbors.
# Point 217 has 17 neighbors.
# Point 218 has 23 neighbors.
# Point 219 has 22 neighbors.
# Point 220 has 23 neighbors.
# Point 221 has 18 neighbors.
# Point 222 has 23 neighbors.
# Point 223 has 23 neighbors.
# Point 224 has 23 neighbors.
# Point 225 has 23 neighbors.
# Point 226 has 21 neighbors.
# Point 227 has 12 neighbors.
# Point 228 has 23 neighbors.
# Point 229 has 13 neighbors.
# Point 230 has 21 neighbors.
# Point 231 has 12 neighbors.
# Point 232 has 18 neighbors.
# Point 233 has 17 neighbors.
# Point 234 has 23 neighbors.
# Point 235 has 14 neighbors.
# Point 236 has 17 neighbors.
# Point 237 has 18 neighbors.
# Point 238 has 23 neighbors.
# Point 239 has 12 neighbors.
# Point 240 has 17 neighbors.
# Point 241 has 10 neighbors.
# Point 242 has 23 neighbors.
# Point 243 has 23 neighbors.
# Point 244 has 22 neighbors.
# Point 245 has 15 neighbors.
# Point 246 has 14 neighbors.
# Point 247 has 23 neighbors.
# Point 248 has 23 neighbors.
# Point 249 has 23 neighbors.
# Point 250 has 23 neighbors.
# Point 251 has 7 neighbors.
# Point 252 has 23 neighbors.
# Point 253 has 18 neighbors.
# Point 254 has 23 neighbors.
# Point 255 has 22 neighbors.
# Point 256 has 20 neighbors.
# Point 257 has 23 neighbors.
# Point 258 has 19 neighbors.
# Point 259 has 23 neighbors.
# Point 260 has 23 neighbors.
# Point 261 has 19 neighbors.
# Point 262 has 22 neighbors.
# Point 263 has 4 neighbors.
# Point 264 has 23 neighbors.
# Point 265 has 23 neighbors.
# Point 266 has 22 neighbors.
# Point 267 has 21 neighbors.
# Point 268 has 23 neighbors.
# Point 269 has 23 neighbors.
# Point 270 has 15 neighbors.
# Point 271 has 22 neighbors.
# Point 272 has 13 neighbors.
# Point 273 has 12 neighbors.
# Point 274 has 13 neighbors.
# Point 275 has 11 neighbors.
# Point 276 has 23 neighbors.
# Point 277 has 13 neighbors.
# Point 278 has 22 neighbors.
# Point 279 has 23 neighbors.
# Point 280 has 23 neighbors.
# Point 281 has 22 neighbors.
# Point 282 has 11 neighbors.
# Point 283 has 18 neighbors.
# Point 284 has 22 neighbors.
# Point 285 has 23 neighbors.
# Point 286 has 23 neighbors.
# Point 287 has 22 neighbors.
# Point 288 has 23 neighbors.
# Point 289 has 15 neighbors.
# Point 290 has 18 neighbors.
# Point 291 has 19 neighbors.
# Point 292 has 12 neighbors.
# Point 293 has 19 neighbors.
# Point 294 has 17 neighbors.
# Point 295 has 21 neighbors.
# Point 296 has 23 neighbors.
# Point 297 has 23 neighbors.
# Point 298 has 23 neighbors.
# Point 299 has 22 neighbors.
# Point 300 has 23 neighbors.
# Point 301 has 22 neighbors.
# Point 302 has 14 neighbors.
# Point 303 has 23 neighbors.
# Point 304 has 23 neighbors.
# Point 305 has 13 neighbors.
# Point 306 has 20 neighbors.
# Point 307 has 23 neighbors.
# Point 308 has 23 neighbors.
# Point 309 has 23 neighbors.
# Point 310 has 15 neighbors.
# Point 311 has 18 neighbors.
# Point 312 has 23 neighbors.
# Point 313 has 20 neighbors.
# Point 314 has 19 neighbors.
# Point 315 has 23 neighbors.
# Point 316 has 20 neighbors.
# Point 317 has 23 neighbors.
# Point 318 has 10 neighbors.
# Point 319 has 22 neighbors.
# Point 320 has 23 neighbors.
# Point 321 has 8 neighbors.
# Point 322 has 17 neighbors.
# Point 323 has 22 neighbors.
# Point 324 has 14 neighbors.
# Point 325 has 22 neighbors.
# Point 326 has 13 neighbors.
# Point 327 has 23 neighbors.
# Updated table for slide S_1:
#       x     y        C1        C2        C3        C4        C5        C6  \
# 0  1554  1297  0.014401  0.057499  0.022033  0.001704  0.533992  1.511707
# 1   462  1502  0.116196  0.197176  0.110600  0.042614  5.587681  0.006885
# 2  1488  1548  0.133284  0.035880  0.061352  0.003073  1.104479  0.009174
# 3  1725  1182  0.087715  0.235223  0.090382  0.013902  8.760482  0.140912
# 4   581  1113  0.128468  0.066399  0.098982  0.047022  3.425771  0.001009
#
#          C7        C8  ...       C28       C29       C30       C31       C32  \
# 0  0.015313  0.020029  ...  0.121361  0.007344  0.000017  0.036891  0.035934
# 1  0.096346  0.001711  ...  0.000238  0.024071  0.000023  0.217589  0.100662
# 2  0.009175  0.000114  ...  0.001401  0.000699  0.000009  0.024491  0.018810
# 3  0.188859  0.010154  ...  0.002036  0.047165  0.000022  0.180372  0.202981
# 4  0.026881  0.000468  ...  0.000048  0.006359  0.000585  0.052661  0.032168
#
#         C33       C34       C35  x_normalized  y_normalized
# 0  0.118937  0.001472  0.050057      0.815877      0.585326
# 1  0.004027  0.004122  0.049491      0.087392      0.754328
# 2  0.004171  0.000425  0.015348      0.771848      0.792251
# 3  0.003709  0.001845  0.116022      0.929953      0.490519
# 4  0.000107  0.000107  0.013103      0.166778      0.433636
#
# [5 rows x 39 columns]
# Updated table for slide S_2:
#       x     y        C1        C2        C3        C4        C5        C6  \
# 0  1572  1350  1.542454  0.052541  1.415544  0.487771  0.291268  0.000100
# 1   480  1555  3.257770  0.057553  1.948030  0.806345  0.484212  0.000077
# 2  1467   526  0.081944  0.013208  0.085818  0.271692  1.027989  0.066760
# 3   349  1189  5.108457  0.072301  2.773961  1.386638  0.496647  0.000065
# 4   401  1280  0.199682  0.014278  0.109534  0.007316  0.028238  0.000008
#
#          C7        C8  ...       C28       C29           C30       C31  \
# 0  0.016733  0.000078  ...  0.000156  0.000086  4.929894e-05  0.073729
# 1  0.032623  0.000092  ...  0.000147  0.001001  1.824790e-06  0.093010
# 2  0.009644  0.000291  ...  0.000005  0.000914  1.203776e-07  0.010981
# 3  0.031599  0.000490  ...  0.000365  0.000139  6.238090e-06  0.217229
# 4  0.000730  0.000158  ...  0.000005  0.000007  3.539291e-04  0.003999
#
#         C32           C33       C34       C35  x_normalized  y_normalized
# 0  0.066650  1.158249e-04  0.010423  0.050226      0.883910      0.684816
# 1  0.067205  2.352456e-02  0.026911  0.052347      0.142566      0.842025
# 2  0.006998  2.140756e-05  0.000059  0.003903      0.812627      0.052914
# 3  0.109407  1.024292e-04  0.064159  0.070167      0.053632      0.561350
# 4  0.006315  8.194072e-07  0.001353  0.000929      0.088934      0.631135
#
# [5 rows x 39 columns]
# Updated table for slide S_3:
#       x     y        C1        C2        C3        C4        C5        C6  \
# 0  1191   942  0.306145  0.022716  0.268922  0.850054  0.206196  0.058142
# 1  1037  1165  0.890074  0.170684  0.932113  0.290531  0.468740  0.000107
# 2   882  1388  0.499127  0.012574  0.487293  0.484179  0.129711  0.013899
# 3   973   696  0.188902  0.098136  0.100406  0.017040  0.409086  0.002186
# 4  1062  1210  1.473281  0.103033  1.118319  0.545588  0.621331  0.000447
#
#          C7        C8  ...       C28       C29       C30       C31       C32  \
# 0  0.008256  0.000067  ...  0.000106  0.001204  0.000032  0.017809  0.019789
# 1  0.034436  0.002441  ...  0.000792  0.003716  0.004590  0.122161  0.176697
# 2  0.004930  0.000015  ...  0.000007  0.000014  0.000002  0.010597  0.012455
# 3  0.011203  0.001725  ...  0.009246  0.011668  0.000842  0.069660  0.036147
# 4  0.038807  0.000576  ...  0.000793  0.003383  0.001091  0.107601  0.075335
#
#         C33       C34       C35  x_normalized  y_normalized
# 0  0.000061  0.000919  0.018196      0.756055      0.418750
# 1  0.001314  0.005219  0.050833      0.489619      0.651042
# 2  0.000022  0.001780  0.008370      0.221453      0.883333
# 3  0.003761  0.001655  0.014094      0.378893      0.162500
# 4  0.000607  0.004124  0.057966      0.532872      0.697917
#
# [5 rows x 39 columns]
# Updated table for slide S_4:
#       x     y        C1        C2        C3        C4        C5        C6  \
# 0   448  1481  0.110442  0.289731  0.156742  0.004558  0.000550  1.381400
# 1   563  1104  0.069022  0.397829  0.085766  0.000430  0.000142  0.026102
# 2   742  1326  0.028899  0.006405  0.006362  0.000166  0.089617  0.034687
# 3  1214   950  0.142531  1.134048  0.301456  0.000317  2.822195  0.000481
# 4  1098  1637  0.005329  0.007513  0.007087  0.000100  0.000466  0.091028
#
#          C7        C8  ...       C28       C29       C30       C31       C32  \
# 0  0.137226  0.013491  ...  1.633818  0.642298  0.000254  0.163243  0.337061
# 1  0.044741  0.031642  ...  0.162494  0.005902  0.613525  0.290938  0.199921
# 2  0.000730  0.000008  ...  0.000014  0.000054  0.000003  0.003410  0.003847
# 3  0.205789  0.185942  ...  0.193207  0.989575  0.834564  0.738212  0.667664
# 4  0.002012  0.000225  ...  0.003692  0.001010  0.000003  0.004595  0.011039
#
#         C33       C34       C35  x_normalized  y_normalized
# 0  0.167966  0.040062  0.337252      0.062562      0.804180
# 1  0.136424  0.009193  0.120528      0.176763      0.389439
# 2  0.000007  0.000017  0.002217      0.354518      0.633663
# 3  0.138013  0.049496  0.365663      0.823237      0.220022
# 4  0.000025  0.000126  0.010888      0.708044      0.975798
#
# [5 rows x 39 columns]
# Updated table for slide S_5:
#       x     y        C1        C2        C3        C4        C5        C6  \
# 0  1495  1261  0.021646  0.058713  0.010598  0.000654  0.000275  0.000091
# 1  1393   462  0.048376  0.030789  0.024272  0.015951  0.003141  0.042053
# 2  1661  1150  0.068092  0.218585  0.035569  0.000002  0.000005  0.000003
# 3  1202   928  0.076381  0.288892  0.052146  0.000072  0.000341  0.013603
# 4  1635   662  4.104257  1.152663  1.977180  0.166353  0.016428  0.001340
#
#          C7        C8  ...       C28       C29       C30       C31       C32  \
# 0  0.006006  0.001666  ...  0.000611  0.000379  0.232393  0.025239  0.016427
# 1  0.008928  0.001763  ...  0.001578  0.005355  0.000037  0.015891  0.023034
# 2  0.023652  0.012993  ...  0.008716  0.008028  0.946842  0.106590  0.071411
# 3  0.037613  0.021836  ...  0.011327  0.008719  0.484054  0.181469  0.116788
# 4  0.296567  0.055075  ...  0.095200  0.097710  0.773685  1.158112  0.786256
#
#         C33       C34       C35  x_normalized  y_normalized
# 0  0.000277  0.000383  0.007827      0.731029      0.866733
# 1  0.002034  0.016076  0.009496      0.645025      0.066132
# 2  0.003074  0.006676  0.032106      0.870995      0.755511
# 3  0.022435  0.010385  0.050761      0.483980      0.533066
# 4  0.015534  0.286496  0.334479      0.849073      0.266533
#
# [5 rows x 39 columns]
# Updated table for slide S_6:
#       x     y        C1        C2        C3        C4        C5        C6  \
# 0  1211   954  0.103681  0.599986  0.207474  0.003284  0.073070  0.002365
# 1  1057  1177  0.048212  0.197546  0.081925  0.007579  8.720077  0.000514
# 2  1082  1221  0.007926  0.053786  0.006056  0.000176  2.084878  0.000841
# 3   916  1154  0.000693  0.014479  0.001580  0.000009  0.333247  0.000008
# 4   942   931  0.005163  0.065887  0.020324  0.000199  0.151354  0.019961
#
#          C7        C8  ...       C28       C29       C30       C31       C32  \
# 0  0.213494  0.054137  ...  0.017699  0.026112  0.503582  0.359966  0.273288
# 1  0.111266  0.027179  ...  0.005945  0.171377  0.000601  0.151940  0.073384
# 2  0.023584  0.000399  ...  0.000169  0.006873  0.000768  0.038273  0.013365
# 3  0.005077  0.000138  ...  0.000020  0.000078  0.000238  0.007115  0.003421
# 4  0.004412  0.000892  ...  0.000255  0.002707  0.000789  0.027743  0.025575
#
#         C33       C34       C35  x_normalized  y_normalized
# 0  0.187153  0.039624  0.224019      0.831897      0.367713
# 1  0.003834  0.001132  0.061351      0.500000      0.701046
# 2  0.001754  0.000064  0.005133      0.553879      0.766816
# 3  0.000118  0.000021  0.001272      0.196121      0.666667
# 4  0.001270  0.000245  0.009807      0.252155      0.333333
#
# [5 rows x 39 columns]

# %% [markdown]
# ## calculate tile_size

# %%
# 預先計算每個 slide 的 edge_index 並儲存
with h5py.File("../elucidata_ai_challenge_data.h5", "r") as h5file:
    train_images = h5file["images/Train"]
    slide_ids = list(train_spot_tables.keys())

    for slide_id in slide_ids:
        if slide_id not in train_images:
            print(f"⚠️ Slide {slide_id} not found in HDF5, skipping.")
            continue
        
        # 讀取這個 slide 的 DataFrame
        df = train_spot_tables[slide_id]
        
        # 提取 (x, y) 座標並進行標準化
        coords = df[['x', 'y']].values
        edge_index = compute_edge_index(coords, radius=64)
        slide_edge_indices[slide_id] = edge_index
        
        # 更新 `train_spot_tables`，儲存標準化後的 DataFrame
        train_spot_tables[slide_id] = df

# 顯示更新後的 `train_spot_tables`
for slide_id in slide_ids:
    print(f"Updated table for slide {slide_id}:")
    print(train_spot_tables[slide_id].head())
# Out:
# Point 0 has 18 neighbors.
# Point 1 has 9 neighbors.
# Point 2 has 19 neighbors.
# Point 3 has 19 neighbors.
# Point 4 has 19 neighbors.
# Point 5 has 19 neighbors.
# Point 6 has 19 neighbors.
# Point 7 has 19 neighbors.
# Point 8 has 19 neighbors.
# Point 9 has 16 neighbors.
# Point 10 has 19 neighbors.
# Point 11 has 19 neighbors.
# Point 12 has 11 neighbors.
# Point 13 has 17 neighbors.
# Point 14 has 19 neighbors.
# Point 15 has 19 neighbors.
# Point 16 has 19 neighbors.
# Point 17 has 19 neighbors.
# Point 18 has 19 neighbors.
# Point 19 has 18 neighbors.
# Point 20 has 19 neighbors.
# Point 21 has 19 neighbors.
# Point 22 has 19 neighbors.
# Point 23 has 19 neighbors.
# Point 24 has 19 neighbors.
# Point 25 has 17 neighbors.
# Point 26 has 16 neighbors.
# Point 27 has 19 neighbors.
# Point 28 has 19 neighbors.
# Point 29 has 19 neighbors.
# Point 30 has 19 neighbors.
# Point 31 has 19 neighbors.
# Point 32 has 19 neighbors.
# Point 33 has 19 neighbors.
# Point 34 has 17 neighbors.
# Point 35 has 19 neighbors.
# Point 36 has 19 neighbors.
# Point 37 has 12 neighbors.
# Point 38 has 18 neighbors.
# Point 39 has 19 neighbors.
# Point 40 has 19 neighbors.
# Point 41 has 10 neighbors.
# Point 42 has 19 neighbors.
# Point 43 has 19 neighbors.
# Point 44 has 19 neighbors.
# Point 45 has 19 neighbors.
# Point 46 has 19 neighbors.
# Point 47 has 15 neighbors.
# Point 48 has 19 neighbors.
# Point 49 has 19 neighbors.
# Point 50 has 19 neighbors.
# Point 51 has 19 neighbors.
# Point 52 has 19 neighbors.
# Point 53 has 19 neighbors.
# Point 54 has 9 neighbors.
# Point 55 has 19 neighbors.
# Point 56 has 19 neighbors.
# Point 57 has 19 neighbors.
# Point 58 has 19 neighbors.
# Point 59 has 19 neighbors.
# Point 60 has 19 neighbors.
# Point 61 has 19 neighbors.
# Point 62 has 16 neighbors.
# Point 63 has 19 neighbors.
# Point 64 has 19 neighbors.
# Point 65 has 9 neighbors.
# Point 66 has 19 neighbors.
# Point 67 has 19 neighbors.
# Point 68 has 19 neighbors.
# Point 69 has 19 neighbors.
# Point 70 has 19 neighbors.
# Point 71 has 19 neighbors.
# Point 72 has 19 neighbors.
# Point 73 has 19 neighbors.
# Point 74 has 18 neighbors.
# Point 75 has 19 neighbors.
# Point 76 has 19 neighbors.
# Point 77 has 19 neighbors.
# Point 78 has 19 neighbors.
# Point 79 has 19 neighbors.
# Point 80 has 19 neighbors.
# Point 81 has 19 neighbors.
# Point 82 has 19 neighbors.
# Point 83 has 19 neighbors.
# Point 84 has 19 neighbors.
# Point 85 has 11 neighbors.
# Point 86 has 16 neighbors.
# Point 87 has 19 neighbors.
# Point 88 has 19 neighbors.
# Point 89 has 19 neighbors.
# Point 90 has 18 neighbors.
# Point 91 has 19 neighbors.
# Point 92 has 19 neighbors.
# Point 93 has 19 neighbors.
# Point 94 has 19 neighbors.
# Point 95 has 19 neighbors.
# Point 96 has 19 neighbors.
# Point 97 has 19 neighbors.
# Point 98 has 19 neighbors.
# Point 99 has 19 neighbors.
# Point 100 has 19 neighbors.
# Point 101 has 19 neighbors.
# Point 102 has 19 neighbors.
# Point 103 has 19 neighbors.
# Point 104 has 19 neighbors.
# Point 105 has 19 neighbors.
# Point 106 has 19 neighbors.
# Point 107 has 19 neighbors.
# Point 108 has 18 neighbors.
# Point 109 has 16 neighbors.
# Point 110 has 16 neighbors.
# Point 111 has 18 neighbors.
# Point 112 has 13 neighbors.
# Point 113 has 19 neighbors.
# Point 114 has 16 neighbors.
# Point 115 has 19 neighbors.
# Point 116 has 19 neighbors.
# Point 117 has 19 neighbors.
# Point 118 has 19 neighbors.
# Point 119 has 16 neighbors.
# Point 120 has 19 neighbors.
# Point 121 has 13 neighbors.
# Point 122 has 19 neighbors.
# Point 123 has 19 neighbors.
# Point 124 has 19 neighbors.
# Point 125 has 19 neighbors.
# Point 126 has 11 neighbors.
# Point 127 has 19 neighbors.
# Point 128 has 19 neighbors.
# Point 129 has 19 neighbors.
# Point 130 has 19 neighbors.
# Point 131 has 19 neighbors.
# Point 132 has 19 neighbors.
# Point 133 has 19 neighbors.
# Point 134 has 19 neighbors.
# Point 135 has 18 neighbors.
# Point 136 has 16 neighbors.
# Point 137 has 19 neighbors.
# Point 138 has 19 neighbors.
# Point 139 has 19 neighbors.
# Point 140 has 19 neighbors.
# Point 141 has 19 neighbors.
# Point 142 has 8 neighbors.
# Point 143 has 19 neighbors.
# Point 144 has 19 neighbors.
# Point 145 has 14 neighbors.
# Point 146 has 11 neighbors.
# Point 147 has 16 neighbors.
# Point 148 has 18 neighbors.
# Point 149 has 19 neighbors.
# Point 150 has 14 neighbors.
# Point 151 has 19 neighbors.
# Point 152 has 19 neighbors.
# Point 153 has 19 neighbors.
# Point 154 has 19 neighbors.
# Point 155 has 18 neighbors.
# Point 156 has 12 neighbors.
# Point 157 has 19 neighbors.
# Point 158 has 19 neighbors.
# Point 159 has 17 neighbors.
# Point 160 has 19 neighbors.
# Point 161 has 19 neighbors.
# Point 162 has 19 neighbors.
# Point 163 has 19 neighbors.
# Point 164 has 19 neighbors.
# Point 165 has 19 neighbors.
# Point 166 has 19 neighbors.
# Point 167 has 14 neighbors.
# Point 168 has 17 neighbors.
# Point 169 has 19 neighbors.
# Point 170 has 19 neighbors.
# Point 171 has 19 neighbors.
# Point 172 has 19 neighbors.
# Point 173 has 18 neighbors.
# Point 174 has 19 neighbors.
# Point 175 has 19 neighbors.
# Point 176 has 19 neighbors.
# Point 177 has 19 neighbors.
# Point 178 has 19 neighbors.
# Point 179 has 19 neighbors.
# Point 180 has 19 neighbors.
# Point 181 has 19 neighbors.
# Point 182 has 19 neighbors.
# Point 183 has 19 neighbors.
# Point 184 has 19 neighbors.
# Point 185 has 19 neighbors.
# Point 186 has 19 neighbors.
# Point 187 has 11 neighbors.
# Point 188 has 13 neighbors.
# Point 189 has 19 neighbors.
# Point 190 has 13 neighbors.
# Point 191 has 13 neighbors.
# Point 192 has 19 neighbors.
# Point 193 has 19 neighbors.
# Point 194 has 19 neighbors.
# Point 195 has 19 neighbors.
# Point 196 has 18 neighbors.
# Point 197 has 19 neighbors.
# Point 198 has 19 neighbors.
# Point 199 has 17 neighbors.
# Point 200 has 19 neighbors.
# Point 201 has 19 neighbors.
# Point 202 has 19 neighbors.
# Point 203 has 8 neighbors.
# Point 204 has 19 neighbors.
# Point 205 has 19 neighbors.
# Point 206 has 13 neighbors.
# Point 207 has 11 neighbors.
# Point 208 has 18 neighbors.
# Point 209 has 19 neighbors.
# Point 210 has 16 neighbors.
# Point 211 has 19 neighbors.
# Point 212 has 18 neighbors.
# Point 213 has 19 neighbors.
# Point 214 has 19 neighbors.
# Point 215 has 19 neighbors.
# Point 216 has 19 neighbors.
# Point 217 has 19 neighbors.
# Point 218 has 19 neighbors.
# Point 219 has 17 neighbors.
# Point 220 has 19 neighbors.
# Point 221 has 19 neighbors.
# Point 222 has 19 neighbors.
# Point 223 has 19 neighbors.
# Point 224 has 18 neighbors.
# Point 225 has 19 neighbors.
# Point 226 has 11 neighbors.
# Point 227 has 16 neighbors.
# Point 228 has 19 neighbors.
# Point 229 has 19 neighbors.
# Point 230 has 19 neighbors.
# Point 231 has 19 neighbors.
# Point 232 has 19 neighbors.
# Point 233 has 19 neighbors.
# Point 234 has 16 neighbors.
# Point 235 has 14 neighbors.
# Point 236 has 19 neighbors.
# Point 237 has 18 neighbors.
# Point 238 has 18 neighbors.
# Point 239 has 18 neighbors.
# Point 240 has 19 neighbors.
# Point 241 has 19 neighbors.
# Point 242 has 19 neighbors.
# Point 243 has 19 neighbors.
# Point 244 has 19 neighbors.
# Point 245 has 11 neighbors.
# Point 246 has 19 neighbors.
# Point 247 has 19 neighbors.
# Point 248 has 19 neighbors.
# Point 249 has 16 neighbors.
# Point 250 has 19 neighbors.
# Point 251 has 19 neighbors.
# Point 252 has 19 neighbors.
# Point 253 has 14 neighbors.
# Point 254 has 19 neighbors.
# Point 255 has 16 neighbors.
# Point 256 has 19 neighbors.
# Point 257 has 19 neighbors.
# Point 258 has 19 neighbors.
# Point 259 has 18 neighbors.
# Point 260 has 19 neighbors.
# Point 261 has 19 neighbors.
# Point 262 has 19 neighbors.
# Point 263 has 19 neighbors.
# Point 264 has 13 neighbors.
# Point 265 has 19 neighbors.
# Point 266 has 19 neighbors.
# Point 267 has 19 neighbors.
# Point 268 has 19 neighbors.
# Point 269 has 18 neighbors.
# Point 270 has 14 neighbors.
# Point 271 has 15 neighbors.
# Point 272 has 18 neighbors.
# Point 273 has 13 neighbors.
# Point 274 has 12 neighbors.
# Point 275 has 19 neighbors.
# Point 276 has 19 neighbors.
# Point 277 has 19 neighbors.
# Point 278 has 16 neighbors.
# Point 279 has 19 neighbors.
# Point 280 has 19 neighbors.
# Point 281 has 19 neighbors.
# Point 282 has 19 neighbors.
# Point 283 has 19 neighbors.
# Point 284 has 19 neighbors.
# Point 285 has 15 neighbors.
# Point 286 has 19 neighbors.
# Point 287 has 19 neighbors.
# Point 288 has 12 neighbors.
# Point 289 has 17 neighbors.
# Point 290 has 19 neighbors.
# Point 291 has 18 neighbors.
# Point 292 has 18 neighbors.
# Point 293 has 19 neighbors.
# Point 294 has 19 neighbors.
# Point 295 has 19 neighbors.
# Point 296 has 19 neighbors.
# Point 297 has 15 neighbors.
# Point 298 has 12 neighbors.
# Point 299 has 19 neighbors.
# Point 300 has 18 neighbors.
# Point 301 has 18 neighbors.
# Point 302 has 19 neighbors.
# Point 303 has 19 neighbors.
# Point 304 has 19 neighbors.
# Point 305 has 19 neighbors.
# Point 306 has 19 neighbors.
# Point 307 has 19 neighbors.
# Point 308 has 19 neighbors.
# Point 309 has 18 neighbors.
# Point 310 has 19 neighbors.
# Point 311 has 19 neighbors.
# Point 312 has 19 neighbors.
# Point 313 has 19 neighbors.
# Point 314 has 19 neighbors.
# Point 315 has 16 neighbors.
# Point 316 has 19 neighbors.
# Point 317 has 19 neighbors.
# Point 318 has 14 neighbors.
# Point 319 has 19 neighbors.
# Point 320 has 19 neighbors.
# Point 321 has 14 neighbors.
# Point 322 has 19 neighbors.
# Point 323 has 19 neighbors.
# Point 324 has 19 neighbors.
# Point 325 has 19 neighbors.
# Point 326 has 11 neighbors.
# Point 327 has 9 neighbors.
# Point 328 has 19 neighbors.
# Point 329 has 13 neighbors.
# Point 330 has 19 neighbors.
# Point 331 has 12 neighbors.
# Point 332 has 19 neighbors.
# Point 333 has 19 neighbors.
# Point 334 has 19 neighbors.
# Point 335 has 19 neighbors.
# Point 336 has 19 neighbors.
# Point 337 has 19 neighbors.
# Point 338 has 19 neighbors.
# Point 339 has 15 neighbors.
# Point 340 has 19 neighbors.
# Point 341 has 17 neighbors.
# Point 342 has 19 neighbors.
# Point 343 has 19 neighbors.
# Point 344 has 19 neighbors.
# Point 345 has 12 neighbors.
# Point 346 has 11 neighbors.
# Point 347 has 19 neighbors.
# Point 348 has 19 neighbors.
# Point 349 has 19 neighbors.
# Point 350 has 18 neighbors.
# Point 351 has 16 neighbors.
# Point 352 has 19 neighbors.
# Point 353 has 19 neighbors.
# Point 354 has 8 neighbors.
# Point 355 has 19 neighbors.
# Point 356 has 18 neighbors.
# Point 357 has 19 neighbors.
# Point 358 has 18 neighbors.
# Point 359 has 19 neighbors.
# Point 360 has 19 neighbors.
# Point 361 has 19 neighbors.
# Point 362 has 19 neighbors.
# Point 363 has 19 neighbors.
# Point 364 has 19 neighbors.
# Point 365 has 18 neighbors.
# Point 366 has 12 neighbors.
# Point 367 has 19 neighbors.
# Point 368 has 11 neighbors.
# Point 369 has 19 neighbors.
# Point 370 has 19 neighbors.
# Point 371 has 19 neighbors.
# Point 372 has 18 neighbors.
# Point 373 has 15 neighbors.
# Point 374 has 19 neighbors.
# Point 375 has 12 neighbors.
# Point 376 has 19 neighbors.
# Point 377 has 19 neighbors.
# Point 378 has 19 neighbors.
# Point 379 has 19 neighbors.
# Point 380 has 18 neighbors.
# Point 381 has 19 neighbors.
# Point 382 has 18 neighbors.
# Point 383 has 11 neighbors.
# Point 384 has 19 neighbors.
# Point 385 has 17 neighbors.
# Point 386 has 18 neighbors.
# Point 387 has 19 neighbors.
# Point 388 has 19 neighbors.
# Point 389 has 18 neighbors.
# Point 390 has 19 neighbors.
# Point 391 has 8 neighbors.
# Point 392 has 19 neighbors.
# Point 393 has 19 neighbors.
# Point 394 has 19 neighbors.
# Point 395 has 19 neighbors.
# Point 396 has 15 neighbors.
# Point 397 has 19 neighbors.
# Point 398 has 15 neighbors.
# Point 399 has 19 neighbors.
# Point 400 has 19 neighbors.
# Point 401 has 17 neighbors.
# Point 402 has 19 neighbors.
# Point 403 has 19 neighbors.
# Point 404 has 19 neighbors.
# Point 405 has 19 neighbors.
# Point 406 has 12 neighbors.
# Point 407 has 19 neighbors.
# Point 408 has 19 neighbors.
# Point 409 has 19 neighbors.
# Point 410 has 19 neighbors.
# Point 411 has 16 neighbors.
# Point 412 has 19 neighbors.
# Point 413 has 18 neighbors.
# Point 414 has 19 neighbors.
# Point 415 has 19 neighbors.
# Point 416 has 19 neighbors.
# Point 417 has 19 neighbors.
# Point 418 has 19 neighbors.
# Point 419 has 19 neighbors.
# Point 420 has 19 neighbors.
# Point 421 has 19 neighbors.
# Point 422 has 18 neighbors.
# Point 423 has 18 neighbors.
# Point 424 has 19 neighbors.
# Point 425 has 19 neighbors.
# Point 426 has 19 neighbors.
# Point 427 has 19 neighbors.
# Point 428 has 19 neighbors.
# Point 429 has 19 neighbors.
# Point 430 has 19 neighbors.
# Point 431 has 16 neighbors.
# Point 432 has 15 neighbors.
# Point 433 has 19 neighbors.
# Point 434 has 19 neighbors.
# Point 435 has 19 neighbors.
# Point 436 has 19 neighbors.
# Point 437 has 8 neighbors.
# Point 438 has 19 neighbors.
# Point 439 has 19 neighbors.
# Point 440 has 19 neighbors.
# Point 441 has 19 neighbors.
# Point 442 has 19 neighbors.
# Point 443 has 19 neighbors.
# Point 444 has 19 neighbors.
# Point 445 has 19 neighbors.
# Point 446 has 19 neighbors.
# Point 447 has 19 neighbors.
# Point 448 has 19 neighbors.
# Point 449 has 19 neighbors.
# Point 450 has 19 neighbors.
# Point 451 has 18 neighbors.
# Point 452 has 19 neighbors.
# Point 453 has 19 neighbors.
# Point 454 has 19 neighbors.
# Point 455 has 19 neighbors.
# Point 456 has 19 neighbors.
# Point 457 has 19 neighbors.
# Point 458 has 19 neighbors.
# Point 459 has 19 neighbors.
# Point 460 has 19 neighbors.
# Point 461 has 19 neighbors.
# Point 462 has 19 neighbors.
# Point 463 has 18 neighbors.
# Point 464 has 19 neighbors.
# Point 465 has 14 neighbors.
# Point 466 has 19 neighbors.
# Point 467 has 19 neighbors.
# Point 468 has 19 neighbors.
# Point 469 has 19 neighbors.
# Point 470 has 19 neighbors.
# Point 471 has 19 neighbors.
# Point 472 has 19 neighbors.
# Point 473 has 15 neighbors.
# Point 474 has 19 neighbors.
# Point 475 has 19 neighbors.
# Point 476 has 19 neighbors.
# Point 477 has 19 neighbors.
# Point 478 has 19 neighbors.
# Point 479 has 18 neighbors.
# Point 480 has 19 neighbors.
# Point 481 has 19 neighbors.
# Point 482 has 19 neighbors.
# Point 483 has 12 neighbors.
# Point 484 has 19 neighbors.
# Point 485 has 16 neighbors.
# Point 486 has 19 neighbors.
# Point 487 has 19 neighbors.
# Point 488 has 18 neighbors.
# Point 489 has 9 neighbors.
# Point 490 has 19 neighbors.
# Point 491 has 14 neighbors.
# Point 492 has 19 neighbors.
# Point 493 has 17 neighbors.
# Point 494 has 17 neighbors.
# Point 495 has 19 neighbors.
# Point 496 has 12 neighbors.
# Point 497 has 19 neighbors.
# Point 498 has 19 neighbors.
# Point 499 has 19 neighbors.
# Point 500 has 18 neighbors.
# Point 501 has 19 neighbors.
# Point 502 has 19 neighbors.
# Point 503 has 13 neighbors.
# Point 504 has 19 neighbors.
# Point 505 has 15 neighbors.
# Point 506 has 11 neighbors.
# Point 507 has 19 neighbors.
# Point 508 has 19 neighbors.
# Point 509 has 19 neighbors.
# Point 510 has 16 neighbors.
# Point 511 has 16 neighbors.
# Point 512 has 19 neighbors.
# Point 513 has 19 neighbors.
# Point 514 has 19 neighbors.
# Point 515 has 12 neighbors.
# Point 516 has 19 neighbors.
# Point 517 has 19 neighbors.
# Point 518 has 19 neighbors.
# Point 519 has 16 neighbors.
# Point 520 has 19 neighbors.
# Point 521 has 19 neighbors.
# Point 522 has 18 neighbors.
# Point 523 has 19 neighbors.
# Point 524 has 15 neighbors.
# Point 525 has 18 neighbors.
# Point 526 has 19 neighbors.
# Point 527 has 11 neighbors.
# Point 528 has 19 neighbors.
# Point 529 has 19 neighbors.
# Point 530 has 19 neighbors.
# Point 531 has 19 neighbors.
# Point 532 has 19 neighbors.
# Point 533 has 19 neighbors.
# Point 534 has 9 neighbors.
# Point 535 has 19 neighbors.
# Point 536 has 19 neighbors.
# Point 537 has 19 neighbors.
# Point 538 has 19 neighbors.
# Point 539 has 19 neighbors.
# Point 540 has 18 neighbors.
# Point 541 has 19 neighbors.
# Point 542 has 19 neighbors.
# Point 543 has 19 neighbors.
# Point 544 has 19 neighbors.
# Point 545 has 19 neighbors.
# Point 546 has 15 neighbors.
# Point 547 has 19 neighbors.
# Point 548 has 19 neighbors.
# Point 549 has 19 neighbors.
# Point 550 has 17 neighbors.
# Point 551 has 19 neighbors.
# Point 552 has 12 neighbors.
# Point 553 has 17 neighbors.
# Point 554 has 19 neighbors.
# Point 555 has 19 neighbors.
# Point 556 has 19 neighbors.
# Point 557 has 18 neighbors.
# Point 558 has 19 neighbors.
# Point 559 has 19 neighbors.
# Point 560 has 19 neighbors.
# Point 561 has 19 neighbors.
# Point 562 has 19 neighbors.
# Point 563 has 19 neighbors.
# Point 564 has 19 neighbors.
# Point 565 has 17 neighbors.
# Point 566 has 9 neighbors.
# Point 567 has 19 neighbors.
# Point 568 has 11 neighbors.
# Point 569 has 19 neighbors.
# Point 570 has 19 neighbors.
# Point 571 has 18 neighbors.
# Point 572 has 19 neighbors.
# Point 573 has 19 neighbors.
# Point 574 has 19 neighbors.
# Point 575 has 19 neighbors.
# Point 576 has 19 neighbors.
# Point 577 has 19 neighbors.
# Point 578 has 19 neighbors.
# Point 579 has 18 neighbors.
# Point 580 has 11 neighbors.
# Point 581 has 19 neighbors.
# Point 582 has 18 neighbors.
# Point 583 has 18 neighbors.
# Point 584 has 19 neighbors.
# Point 585 has 19 neighbors.
# Point 586 has 19 neighbors.
# Point 587 has 19 neighbors.
# Point 588 has 18 neighbors.
# Point 589 has 19 neighbors.
# Point 590 has 19 neighbors.
# Point 591 has 18 neighbors.
# Point 592 has 13 neighbors.
# Point 593 has 8 neighbors.
# Point 594 has 19 neighbors.
# Point 595 has 19 neighbors.
# Point 596 has 19 neighbors.
# Point 597 has 19 neighbors.
# Point 598 has 19 neighbors.
# Point 599 has 19 neighbors.
# Point 600 has 19 neighbors.
# Point 601 has 19 neighbors.
# Point 602 has 12 neighbors.
# Point 603 has 13 neighbors.
# Point 604 has 19 neighbors.
# Point 605 has 19 neighbors.
# Point 606 has 19 neighbors.
# Point 607 has 19 neighbors.
# Point 608 has 19 neighbors.
# Point 609 has 19 neighbors.
# Point 610 has 19 neighbors.
# Point 611 has 18 neighbors.
# Point 612 has 19 neighbors.
# Point 613 has 18 neighbors.
# Point 614 has 19 neighbors.
# Point 615 has 19 neighbors.
# Point 616 has 19 neighbors.
# Point 617 has 19 neighbors.
# Point 618 has 19 neighbors.
# Point 619 has 19 neighbors.
# Point 620 has 19 neighbors.
# Point 621 has 11 neighbors.
# Point 622 has 19 neighbors.
# Point 623 has 19 neighbors.
# Point 624 has 19 neighbors.
# Point 625 has 19 neighbors.
# Point 626 has 14 neighbors.
# Point 627 has 18 neighbors.
# Point 628 has 18 neighbors.
# Point 629 has 19 neighbors.
# Point 630 has 19 neighbors.
# Point 631 has 19 neighbors.
# Point 632 has 19 neighbors.
# Point 633 has 19 neighbors.
# Point 634 has 19 neighbors.
# Point 635 has 19 neighbors.
# Point 636 has 19 neighbors.
# Point 637 has 19 neighbors.
# Point 638 has 19 neighbors.
# Point 639 has 19 neighbors.
# Point 640 has 14 neighbors.
# Point 641 has 19 neighbors.
# Point 642 has 19 neighbors.
# Point 643 has 19 neighbors.
# Point 644 has 18 neighbors.
# Point 645 has 19 neighbors.
# Point 646 has 19 neighbors.
# Point 647 has 19 neighbors.
# Point 648 has 19 neighbors.
# Point 649 has 19 neighbors.
# Point 650 has 19 neighbors.
# Point 651 has 19 neighbors.
# Point 652 has 19 neighbors.
# Point 653 has 18 neighbors.
# Point 654 has 9 neighbors.
# Point 655 has 19 neighbors.
# Point 656 has 15 neighbors.
# Point 657 has 19 neighbors.
# Point 658 has 19 neighbors.
# Point 659 has 19 neighbors.
# Point 660 has 19 neighbors.
# Point 661 has 19 neighbors.
# Point 662 has 19 neighbors.
# Point 663 has 15 neighbors.
# Point 664 has 19 neighbors.
# Point 665 has 19 neighbors.
# Point 666 has 19 neighbors.
# Point 667 has 19 neighbors.
# Point 668 has 19 neighbors.
# Point 669 has 18 neighbors.
# Point 670 has 19 neighbors.
# Point 671 has 12 neighbors.
# Point 672 has 19 neighbors.
# Point 673 has 17 neighbors.
# Point 674 has 16 neighbors.
# Point 675 has 19 neighbors.
# Point 676 has 19 neighbors.
# Point 677 has 17 neighbors.
# Point 678 has 12 neighbors.
# Point 679 has 16 neighbors.
# Point 680 has 11 neighbors.
# Point 681 has 18 neighbors.
# Point 682 has 18 neighbors.
# Point 683 has 19 neighbors.
# Point 684 has 19 neighbors.
# Point 685 has 19 neighbors.
# Point 686 has 19 neighbors.
# Point 687 has 10 neighbors.
# Point 688 has 19 neighbors.
# Point 689 has 19 neighbors.
# Point 690 has 19 neighbors.
# Point 691 has 19 neighbors.
# Point 692 has 19 neighbors.
# Point 693 has 19 neighbors.
# Point 694 has 19 neighbors.
# Point 695 has 16 neighbors.
# Point 696 has 19 neighbors.
# Point 697 has 19 neighbors.
# Point 698 has 19 neighbors.
# Point 699 has 19 neighbors.
# Point 700 has 18 neighbors.
# Point 701 has 17 neighbors.
# Point 702 has 17 neighbors.
# Point 703 has 19 neighbors.
# Point 704 has 19 neighbors.
# Point 705 has 19 neighbors.
# Point 706 has 19 neighbors.
# Point 707 has 19 neighbors.
# Point 708 has 14 neighbors.
# Point 709 has 10 neighbors.
# Point 710 has 17 neighbors.
# Point 711 has 19 neighbors.
# Point 712 has 19 neighbors.
# Point 713 has 19 neighbors.
# Point 714 has 19 neighbors.
# Point 715 has 19 neighbors.
# Point 716 has 19 neighbors.
# Point 717 has 19 neighbors.
# Point 718 has 18 neighbors.
# Point 719 has 19 neighbors.
# Point 720 has 19 neighbors.
# Point 721 has 19 neighbors.
# Point 722 has 19 neighbors.
# Point 723 has 19 neighbors.
# Point 724 has 19 neighbors.
# Point 725 has 19 neighbors.
# Point 726 has 13 neighbors.
# Point 727 has 19 neighbors.
# Point 728 has 19 neighbors.
# Point 729 has 15 neighbors.
# Point 730 has 19 neighbors.
# Point 731 has 19 neighbors.
# Point 732 has 19 neighbors.
# Point 733 has 19 neighbors.
# Point 734 has 16 neighbors.
# Point 735 has 19 neighbors.
# Point 736 has 19 neighbors.
# Point 737 has 19 neighbors.
# Point 738 has 10 neighbors.
# Point 739 has 18 neighbors.
# Point 740 has 19 neighbors.
# Point 741 has 18 neighbors.
# Point 742 has 19 neighbors.
# Point 743 has 19 neighbors.
# Point 744 has 19 neighbors.
# Point 745 has 19 neighbors.
# Point 746 has 19 neighbors.
# Point 747 has 19 neighbors.
# Point 748 has 19 neighbors.
# Point 749 has 19 neighbors.
# Point 750 has 19 neighbors.
# Point 751 has 19 neighbors.
# Point 752 has 19 neighbors.
# Point 753 has 10 neighbors.
# Point 754 has 14 neighbors.
# Point 755 has 11 neighbors.
# Point 756 has 19 neighbors.
# Point 757 has 19 neighbors.
# Point 758 has 10 neighbors.
# Point 759 has 19 neighbors.
# Point 760 has 19 neighbors.
# Point 761 has 19 neighbors.
# Point 762 has 19 neighbors.
# Point 763 has 19 neighbors.
# Point 764 has 19 neighbors.
# Point 765 has 18 neighbors.
# Point 766 has 19 neighbors.
# Point 767 has 19 neighbors.
# Point 768 has 19 neighbors.
# Point 769 has 18 neighbors.
# Point 770 has 19 neighbors.
# Point 771 has 17 neighbors.
# Point 772 has 19 neighbors.
# Point 773 has 19 neighbors.
# Point 774 has 19 neighbors.
# Point 775 has 19 neighbors.
# Point 776 has 19 neighbors.
# Point 777 has 10 neighbors.
# Point 778 has 19 neighbors.
# Point 779 has 19 neighbors.
# Point 780 has 16 neighbors.
# Point 781 has 19 neighbors.
# Point 782 has 18 neighbors.
# Point 783 has 19 neighbors.
# Point 784 has 12 neighbors.
# Point 785 has 19 neighbors.
# Point 786 has 19 neighbors.
# Point 787 has 18 neighbors.
# Point 788 has 19 neighbors.
# Point 789 has 19 neighbors.
# Point 790 has 18 neighbors.
# Point 791 has 19 neighbors.
# Point 792 has 19 neighbors.
# Point 793 has 19 neighbors.
# Point 794 has 19 neighbors.
# Point 795 has 19 neighbors.
# Point 796 has 19 neighbors.
# Point 797 has 19 neighbors.
# Point 798 has 12 neighbors.
# Point 799 has 19 neighbors.
# Point 800 has 19 neighbors.
# Point 801 has 12 neighbors.
# Point 802 has 19 neighbors.
# Point 803 has 19 neighbors.
# Point 804 has 19 neighbors.
# Point 805 has 18 neighbors.
# Point 806 has 19 neighbors.
# Point 807 has 10 neighbors.
# Point 808 has 19 neighbors.
# Point 809 has 19 neighbors.
# Point 810 has 17 neighbors.
# Point 811 has 19 neighbors.
# Point 812 has 19 neighbors.
# Point 813 has 19 neighbors.
# Point 814 has 18 neighbors.
# Point 815 has 19 neighbors.
# Point 816 has 19 neighbors.
# Point 817 has 19 neighbors.
# Point 818 has 19 neighbors.
# Point 819 has 19 neighbors.
# Point 820 has 19 neighbors.
# Point 821 has 19 neighbors.
# Point 822 has 19 neighbors.
# Point 823 has 19 neighbors.
# Point 824 has 19 neighbors.
# Point 825 has 19 neighbors.
# Point 826 has 19 neighbors.
# Point 827 has 11 neighbors.
# Point 828 has 19 neighbors.
# Point 829 has 19 neighbors.
# Point 830 has 19 neighbors.
# Point 831 has 19 neighbors.
# Point 832 has 19 neighbors.
# Point 833 has 19 neighbors.
# Point 834 has 11 neighbors.
# Point 835 has 19 neighbors.
# Point 836 has 19 neighbors.
# Point 837 has 19 neighbors.
# Point 838 has 18 neighbors.
# Point 839 has 11 neighbors.
# Point 840 has 15 neighbors.
# Point 841 has 19 neighbors.
# Point 842 has 19 neighbors.
# Point 843 has 19 neighbors.
# Point 844 has 19 neighbors.
# Point 845 has 19 neighbors.
# Point 846 has 19 neighbors.
# Point 847 has 19 neighbors.
# Point 848 has 19 neighbors.
# Point 849 has 17 neighbors.
# Point 850 has 19 neighbors.
# Point 851 has 19 neighbors.
# Point 852 has 16 neighbors.
# Point 853 has 19 neighbors.
# Point 854 has 19 neighbors.
# Point 855 has 12 neighbors.
# Point 856 has 19 neighbors.
# Point 857 has 18 neighbors.
# Point 858 has 19 neighbors.
# Point 859 has 19 neighbors.
# Point 860 has 19 neighbors.
# Point 861 has 19 neighbors.
# Point 862 has 13 neighbors.
# Point 863 has 19 neighbors.
# Point 864 has 13 neighbors.
# Point 865 has 16 neighbors.
# Point 866 has 14 neighbors.
# Point 867 has 19 neighbors.
# Point 868 has 18 neighbors.
# Point 869 has 19 neighbors.
# Point 870 has 19 neighbors.
# Point 871 has 19 neighbors.
# Point 872 has 19 neighbors.
# Point 873 has 19 neighbors.
# Point 874 has 18 neighbors.
# Point 875 has 19 neighbors.
# Point 876 has 19 neighbors.
# Point 877 has 19 neighbors.
# Point 878 has 19 neighbors.
# Point 879 has 19 neighbors.
# Point 880 has 19 neighbors.
# Point 881 has 13 neighbors.
# Point 882 has 19 neighbors.
# Point 883 has 19 neighbors.
# Point 884 has 19 neighbors.
# Point 885 has 19 neighbors.
# Point 886 has 19 neighbors.
# Point 887 has 19 neighbors.
# Point 888 has 16 neighbors.
# Point 889 has 19 neighbors.
# Point 890 has 19 neighbors.
# Point 891 has 19 neighbors.
# Point 892 has 19 neighbors.
# Point 893 has 19 neighbors.
# Point 894 has 15 neighbors.
# Point 895 has 19 neighbors.
# Point 896 has 19 neighbors.
# Point 897 has 15 neighbors.
# Point 898 has 19 neighbors.
# Point 899 has 19 neighbors.
# Point 900 has 19 neighbors.
# Point 901 has 19 neighbors.
# Point 902 has 19 neighbors.
# Point 903 has 18 neighbors.
# Point 904 has 19 neighbors.
# Point 905 has 19 neighbors.
# Point 906 has 19 neighbors.
# Point 907 has 18 neighbors.
# Point 908 has 19 neighbors.
# Point 909 has 19 neighbors.
# Point 910 has 19 neighbors.
# Point 911 has 19 neighbors.
# Point 912 has 19 neighbors.
# Point 913 has 19 neighbors.
# Point 914 has 19 neighbors.
# Point 915 has 16 neighbors.
# Point 916 has 15 neighbors.
# Point 917 has 15 neighbors.
# Point 918 has 19 neighbors.
# Point 919 has 19 neighbors.
# Point 920 has 19 neighbors.
# Point 921 has 19 neighbors.
# Point 922 has 19 neighbors.
# Point 923 has 19 neighbors.
# Point 924 has 16 neighbors.
# Point 925 has 19 neighbors.
# Point 926 has 14 neighbors.
# Point 927 has 18 neighbors.
# Point 928 has 16 neighbors.
# Point 929 has 19 neighbors.
# Point 930 has 19 neighbors.
# Point 931 has 19 neighbors.
# Point 932 has 19 neighbors.
# Point 933 has 13 neighbors.
# Point 934 has 19 neighbors.
# Point 935 has 19 neighbors.
# Point 936 has 19 neighbors.
# Point 937 has 16 neighbors.
# Point 938 has 18 neighbors.
# Point 939 has 16 neighbors.
# Point 940 has 19 neighbors.
# Point 941 has 18 neighbors.
# Point 942 has 16 neighbors.
# Point 943 has 19 neighbors.
# Point 944 has 19 neighbors.
# Point 945 has 17 neighbors.
# Point 946 has 9 neighbors.
# Point 947 has 19 neighbors.
# Point 948 has 19 neighbors.
# Point 949 has 18 neighbors.
# Point 950 has 19 neighbors.
# Point 951 has 19 neighbors.
# Point 952 has 19 neighbors.
# Point 953 has 19 neighbors.
# Point 954 has 19 neighbors.
# Point 955 has 15 neighbors.
# Point 956 has 19 neighbors.
# Point 957 has 19 neighbors.
# Point 958 has 19 neighbors.
# Point 959 has 18 neighbors.
# Point 960 has 19 neighbors.
# Point 961 has 19 neighbors.
# Point 962 has 19 neighbors.
# Point 963 has 19 neighbors.
# Point 964 has 18 neighbors.
# Point 965 has 19 neighbors.
# Point 966 has 19 neighbors.
# Point 967 has 19 neighbors.
# Point 968 has 19 neighbors.
# Point 969 has 19 neighbors.
# Point 970 has 19 neighbors.
# Point 971 has 19 neighbors.
# Point 972 has 17 neighbors.
# Point 973 has 19 neighbors.
# Point 974 has 19 neighbors.
# Point 975 has 19 neighbors.
# Point 976 has 17 neighbors.
# Point 977 has 19 neighbors.
# Point 978 has 19 neighbors.
# Point 979 has 18 neighbors.
# Point 980 has 19 neighbors.
# Point 981 has 19 neighbors.
# Point 982 has 19 neighbors.
# Point 983 has 19 neighbors.
# Point 984 has 19 neighbors.
# Point 985 has 14 neighbors.
# Point 986 has 19 neighbors.
# Point 987 has 14 neighbors.
# Point 988 has 19 neighbors.
# Point 989 has 17 neighbors.
# Point 990 has 19 neighbors.
# Point 991 has 9 neighbors.
# Point 992 has 19 neighbors.
# Point 993 has 19 neighbors.
# Point 994 has 19 neighbors.
# Point 995 has 19 neighbors.
# Point 996 has 19 neighbors.
# Point 997 has 12 neighbors.
# Point 998 has 19 neighbors.
# Point 999 has 19 neighbors.
# Point 1000 has 19 neighbors.
# Point 1001 has 19 neighbors.
# Point 1002 has 19 neighbors.
# Point 1003 has 18 neighbors.
# Point 1004 has 19 neighbors.
# Point 1005 has 19 neighbors.
# Point 1006 has 19 neighbors.
# Point 1007 has 18 neighbors.
# Point 1008 has 19 neighbors.
# Point 1009 has 19 neighbors.
# Point 1010 has 19 neighbors.
# Point 1011 has 14 neighbors.
# Point 1012 has 11 neighbors.
# Point 1013 has 19 neighbors.
# Point 1014 has 19 neighbors.
# Point 1015 has 17 neighbors.
# Point 1016 has 19 neighbors.
# Point 1017 has 14 neighbors.
# Point 1018 has 19 neighbors.
# Point 1019 has 19 neighbors.
# Point 1020 has 19 neighbors.
# Point 1021 has 19 neighbors.
# Point 1022 has 19 neighbors.
# Point 1023 has 15 neighbors.
# Point 1024 has 19 neighbors.
# Point 1025 has 19 neighbors.
# Point 1026 has 18 neighbors.
# Point 1027 has 14 neighbors.
# Point 1028 has 19 neighbors.
# Point 1029 has 19 neighbors.
# Point 1030 has 19 neighbors.
# Point 1031 has 19 neighbors.
# Point 1032 has 19 neighbors.
# Point 1033 has 16 neighbors.
# Point 1034 has 19 neighbors.
# Point 1035 has 19 neighbors.
# Point 1036 has 6 neighbors.
# Point 1037 has 19 neighbors.
# Point 1038 has 19 neighbors.
# Point 1039 has 19 neighbors.
# Point 1040 has 19 neighbors.
# Point 1041 has 16 neighbors.
# Point 1042 has 19 neighbors.
# Point 1043 has 12 neighbors.
# Point 1044 has 19 neighbors.
# Point 1045 has 19 neighbors.
# Point 1046 has 12 neighbors.
# Point 1047 has 19 neighbors.
# Point 1048 has 19 neighbors.
# Point 1049 has 18 neighbors.
# Point 1050 has 19 neighbors.
# Point 1051 has 19 neighbors.
# Point 1052 has 18 neighbors.
# Point 1053 has 17 neighbors.
# Point 1054 has 19 neighbors.
# Point 1055 has 19 neighbors.
# Point 1056 has 14 neighbors.
# Point 1057 has 19 neighbors.
# Point 1058 has 19 neighbors.
# Point 1059 has 19 neighbors.
# Point 1060 has 19 neighbors.
# Point 1061 has 19 neighbors.
# Point 1062 has 19 neighbors.
# Point 1063 has 19 neighbors.
# Point 1064 has 19 neighbors.
# Point 1065 has 19 neighbors.
# Point 1066 has 19 neighbors.
# Point 1067 has 19 neighbors.
# Point 1068 has 9 neighbors.
# Point 1069 has 19 neighbors.
# Point 1070 has 19 neighbors.
# Point 1071 has 8 neighbors.
# Point 1072 has 19 neighbors.
# Point 1073 has 17 neighbors.
# Point 1074 has 19 neighbors.
# Point 1075 has 19 neighbors.
# Point 1076 has 11 neighbors.
# Point 1077 has 19 neighbors.
# Point 1078 has 19 neighbors.
# Point 1079 has 19 neighbors.
# Point 1080 has 19 neighbors.
# Point 1081 has 19 neighbors.
# Point 1082 has 19 neighbors.
# Point 1083 has 18 neighbors.
# Point 1084 has 17 neighbors.
# Point 1085 has 19 neighbors.
# Point 1086 has 19 neighbors.
# Point 1087 has 19 neighbors.
# Point 1088 has 16 neighbors.
# Point 1089 has 19 neighbors.
# Point 1090 has 19 neighbors.
# Point 1091 has 19 neighbors.
# Point 1092 has 19 neighbors.
# Point 1093 has 19 neighbors.
# Point 1094 has 19 neighbors.
# Point 1095 has 19 neighbors.
# Point 1096 has 11 neighbors.
# Point 1097 has 19 neighbors.
# Point 1098 has 19 neighbors.
# Point 1099 has 18 neighbors.
# Point 1100 has 19 neighbors.
# Point 1101 has 18 neighbors.
# Point 1102 has 17 neighbors.
# Point 1103 has 19 neighbors.
# Point 1104 has 16 neighbors.
# Point 1105 has 18 neighbors.
# Point 1106 has 19 neighbors.
# Point 1107 has 19 neighbors.
# Point 1108 has 19 neighbors.
# Point 1109 has 19 neighbors.
# Point 1110 has 19 neighbors.
# Point 1111 has 19 neighbors.
# Point 1112 has 19 neighbors.
# Point 1113 has 18 neighbors.
# Point 1114 has 19 neighbors.
# Point 1115 has 19 neighbors.
# Point 1116 has 19 neighbors.
# Point 1117 has 19 neighbors.
# Point 1118 has 17 neighbors.
# Point 1119 has 13 neighbors.
# Point 1120 has 19 neighbors.
# Point 1121 has 19 neighbors.
# Point 1122 has 13 neighbors.
# Point 1123 has 19 neighbors.
# Point 1124 has 18 neighbors.
# Point 1125 has 19 neighbors.
# Point 1126 has 19 neighbors.
# Point 1127 has 19 neighbors.
# Point 1128 has 19 neighbors.
# Point 1129 has 19 neighbors.
# Point 1130 has 19 neighbors.
# Point 1131 has 19 neighbors.
# Point 1132 has 12 neighbors.
# Point 1133 has 19 neighbors.
# Point 1134 has 19 neighbors.
# Point 1135 has 19 neighbors.
# Point 1136 has 19 neighbors.
# Point 1137 has 19 neighbors.
# Point 1138 has 19 neighbors.
# Point 1139 has 9 neighbors.
# Point 1140 has 15 neighbors.
# Point 1141 has 19 neighbors.
# Point 1142 has 16 neighbors.
# Point 1143 has 19 neighbors.
# Point 1144 has 19 neighbors.
# Point 1145 has 10 neighbors.
# Point 1146 has 19 neighbors.
# Point 1147 has 19 neighbors.
# Point 1148 has 19 neighbors.
# Point 1149 has 19 neighbors.
# Point 1150 has 17 neighbors.
# Point 1151 has 19 neighbors.
# Point 1152 has 19 neighbors.
# Point 1153 has 19 neighbors.
# Point 1154 has 10 neighbors.
# Point 1155 has 19 neighbors.
# Point 1156 has 18 neighbors.
# Point 1157 has 19 neighbors.
# Point 1158 has 19 neighbors.
# Point 1159 has 19 neighbors.
# Point 1160 has 19 neighbors.
# Point 1161 has 15 neighbors.
# Point 1162 has 19 neighbors.
# Point 1163 has 19 neighbors.
# Point 1164 has 13 neighbors.
# Point 1165 has 18 neighbors.
# Point 1166 has 18 neighbors.
# Point 1167 has 19 neighbors.
# Point 1168 has 19 neighbors.
# Point 1169 has 18 neighbors.
# Point 1170 has 19 neighbors.
# Point 1171 has 17 neighbors.
# Point 1172 has 19 neighbors.
# Point 1173 has 19 neighbors.
# Point 1174 has 19 neighbors.
# Point 1175 has 19 neighbors.
# Point 1176 has 19 neighbors.
# Point 1177 has 18 neighbors.
# Point 1178 has 19 neighbors.
# Point 1179 has 19 neighbors.
# Point 1180 has 12 neighbors.
# Point 1181 has 19 neighbors.
# Point 1182 has 19 neighbors.
# Point 1183 has 19 neighbors.
# Point 1184 has 19 neighbors.
# Point 1185 has 13 neighbors.
# Point 1186 has 19 neighbors.
# Point 1187 has 19 neighbors.
# Point 1188 has 19 neighbors.
# Point 1189 has 19 neighbors.
# Point 1190 has 17 neighbors.
# Point 1191 has 12 neighbors.
# Point 1192 has 19 neighbors.
# Point 1193 has 16 neighbors.
# Point 1194 has 19 neighbors.
# Point 1195 has 19 neighbors.
# Point 1196 has 19 neighbors.
# Point 1197 has 19 neighbors.
# Point 1198 has 19 neighbors.
# Point 1199 has 18 neighbors.
# Point 1200 has 19 neighbors.
# Point 1201 has 19 neighbors.
# Point 1202 has 12 neighbors.
# Point 1203 has 19 neighbors.
# Point 1204 has 12 neighbors.
# Point 1205 has 19 neighbors.
# Point 1206 has 17 neighbors.
# Point 1207 has 19 neighbors.
# Point 1208 has 19 neighbors.
# Point 1209 has 19 neighbors.
# Point 1210 has 19 neighbors.
# Point 1211 has 19 neighbors.
# Point 1212 has 19 neighbors.
# Point 1213 has 19 neighbors.
# Point 1214 has 19 neighbors.
# Point 1215 has 17 neighbors.
# Point 1216 has 16 neighbors.
# Point 1217 has 19 neighbors.
# Point 1218 has 19 neighbors.
# Point 1219 has 19 neighbors.
# Point 1220 has 13 neighbors.
# Point 1221 has 19 neighbors.
# Point 1222 has 19 neighbors.
# Point 1223 has 19 neighbors.
# Point 1224 has 19 neighbors.
# Point 1225 has 19 neighbors.
# Point 1226 has 19 neighbors.
# Point 1227 has 12 neighbors.
# Point 1228 has 19 neighbors.
# Point 1229 has 15 neighbors.
# Point 1230 has 19 neighbors.
# Point 1231 has 19 neighbors.
# Point 1232 has 19 neighbors.
# Point 1233 has 19 neighbors.
# Point 1234 has 19 neighbors.
# Point 1235 has 19 neighbors.
# Point 1236 has 19 neighbors.
# Point 1237 has 19 neighbors.
# Point 1238 has 11 neighbors.
# Point 1239 has 19 neighbors.
# Point 1240 has 19 neighbors.
# Point 1241 has 12 neighbors.
# Point 1242 has 19 neighbors.
# Point 1243 has 19 neighbors.
# Point 1244 has 19 neighbors.
# Point 1245 has 19 neighbors.
# Point 1246 has 19 neighbors.
# Point 1247 has 19 neighbors.
# Point 1248 has 19 neighbors.
# Point 1249 has 12 neighbors.
# Point 1250 has 19 neighbors.
# Point 1251 has 19 neighbors.
# Point 1252 has 19 neighbors.
# Point 1253 has 19 neighbors.
# Point 1254 has 19 neighbors.
# Point 1255 has 19 neighbors.
# Point 1256 has 18 neighbors.
# Point 1257 has 19 neighbors.
# Point 1258 has 19 neighbors.
# Point 1259 has 19 neighbors.
# Point 1260 has 19 neighbors.
# Point 1261 has 19 neighbors.
# Point 1262 has 16 neighbors.
# Point 1263 has 12 neighbors.
# Point 1264 has 16 neighbors.
# Point 1265 has 19 neighbors.
# Point 1266 has 19 neighbors.
# Point 1267 has 19 neighbors.
# Point 1268 has 19 neighbors.
# Point 1269 has 19 neighbors.
# Point 1270 has 16 neighbors.
# Point 1271 has 13 neighbors.
# Point 1272 has 19 neighbors.
# Point 1273 has 19 neighbors.
# Point 1274 has 15 neighbors.
# Point 1275 has 19 neighbors.
# Point 1276 has 19 neighbors.
# Point 1277 has 19 neighbors.
# Point 1278 has 11 neighbors.
# Point 1279 has 19 neighbors.
# Point 1280 has 19 neighbors.
# Point 1281 has 19 neighbors.
# Point 1282 has 19 neighbors.
# Point 1283 has 19 neighbors.
# Point 1284 has 19 neighbors.
# Point 1285 has 19 neighbors.
# Point 1286 has 19 neighbors.
# Point 1287 has 18 neighbors.
# Point 1288 has 19 neighbors.
# Point 1289 has 19 neighbors.
# Point 1290 has 14 neighbors.
# Point 1291 has 19 neighbors.
# Point 1292 has 18 neighbors.
# Point 1293 has 19 neighbors.
# Point 1294 has 19 neighbors.
# Point 1295 has 19 neighbors.
# Point 1296 has 19 neighbors.
# Point 1297 has 19 neighbors.
# Point 1298 has 19 neighbors.
# Point 1299 has 19 neighbors.
# Point 1300 has 19 neighbors.
# Point 1301 has 19 neighbors.
# Point 1302 has 19 neighbors.
# Point 1303 has 17 neighbors.
# Point 1304 has 19 neighbors.
# Point 1305 has 19 neighbors.
# Point 1306 has 19 neighbors.
# Point 1307 has 19 neighbors.
# Point 1308 has 18 neighbors.
# Point 1309 has 16 neighbors.
# Point 1310 has 19 neighbors.
# Point 1311 has 19 neighbors.
# Point 1312 has 16 neighbors.
# Point 1313 has 19 neighbors.
# Point 1314 has 19 neighbors.
# Point 1315 has 19 neighbors.
# Point 1316 has 19 neighbors.
# Point 1317 has 17 neighbors.
# Point 1318 has 19 neighbors.
# Point 1319 has 19 neighbors.
# Point 1320 has 19 neighbors.
# Point 1321 has 13 neighbors.
# Point 1322 has 19 neighbors.
# Point 1323 has 19 neighbors.
# Point 1324 has 19 neighbors.
# Point 1325 has 18 neighbors.
# Point 1326 has 12 neighbors.
# Point 1327 has 19 neighbors.
# Point 1328 has 19 neighbors.
# Point 1329 has 19 neighbors.
# Point 1330 has 19 neighbors.
# Point 1331 has 19 neighbors.
# Point 1332 has 19 neighbors.
# Point 1333 has 14 neighbors.
# Point 1334 has 19 neighbors.
# Point 1335 has 18 neighbors.
# Point 1336 has 19 neighbors.
# Point 1337 has 19 neighbors.
# Point 1338 has 16 neighbors.
# Point 1339 has 16 neighbors.
# Point 1340 has 16 neighbors.
# Point 1341 has 14 neighbors.
# Point 1342 has 19 neighbors.
# Point 1343 has 19 neighbors.
# Point 1344 has 19 neighbors.
# Point 1345 has 19 neighbors.
# Point 1346 has 19 neighbors.
# Point 1347 has 17 neighbors.
# Point 1348 has 19 neighbors.
# Point 1349 has 19 neighbors.
# Point 1350 has 19 neighbors.
# Point 1351 has 19 neighbors.
# Point 1352 has 19 neighbors.
# Point 1353 has 19 neighbors.
# Point 1354 has 19 neighbors.
# Point 1355 has 19 neighbors.
# Point 1356 has 19 neighbors.
# Point 1357 has 12 neighbors.
# Point 1358 has 19 neighbors.
# Point 1359 has 19 neighbors.
# Point 1360 has 12 neighbors.
# Point 1361 has 19 neighbors.
# Point 1362 has 19 neighbors.
# Point 1363 has 14 neighbors.
# Point 1364 has 19 neighbors.
# Point 1365 has 19 neighbors.
# Point 1366 has 19 neighbors.
# Point 1367 has 12 neighbors.
# Point 1368 has 19 neighbors.
# Point 1369 has 18 neighbors.
# Point 1370 has 18 neighbors.
# Point 1371 has 17 neighbors.
# Point 1372 has 19 neighbors.
# Point 1373 has 16 neighbors.
# Point 1374 has 19 neighbors.
# Point 1375 has 19 neighbors.
# Point 1376 has 19 neighbors.
# Point 1377 has 19 neighbors.
# Point 1378 has 16 neighbors.
# Point 1379 has 17 neighbors.
# Point 1380 has 19 neighbors.
# Point 1381 has 19 neighbors.
# Point 1382 has 19 neighbors.
# Point 1383 has 19 neighbors.
# Point 1384 has 19 neighbors.
# Point 1385 has 19 neighbors.
# Point 1386 has 19 neighbors.
# Point 1387 has 19 neighbors.
# Point 1388 has 18 neighbors.
# Point 1389 has 19 neighbors.
# Point 1390 has 11 neighbors.
# Point 1391 has 12 neighbors.
# Point 1392 has 19 neighbors.
# Point 1393 has 17 neighbors.
# Point 1394 has 19 neighbors.
# Point 1395 has 19 neighbors.
# Point 1396 has 19 neighbors.
# Point 1397 has 19 neighbors.
# Point 1398 has 19 neighbors.
# Point 1399 has 19 neighbors.
# Point 1400 has 19 neighbors.
# Point 1401 has 19 neighbors.
# Point 1402 has 19 neighbors.
# Point 1403 has 19 neighbors.
# Point 1404 has 17 neighbors.
# Point 1405 has 10 neighbors.
# Point 1406 has 19 neighbors.
# Point 1407 has 19 neighbors.
# Point 1408 has 19 neighbors.
# Point 1409 has 18 neighbors.
# Point 1410 has 15 neighbors.
# Point 1411 has 19 neighbors.
# Point 1412 has 19 neighbors.
# Point 1413 has 19 neighbors.
# Point 1414 has 8 neighbors.
# Point 1415 has 16 neighbors.
# Point 1416 has 19 neighbors.
# Point 1417 has 19 neighbors.
# Point 1418 has 19 neighbors.
# Point 1419 has 14 neighbors.
# Point 1420 has 19 neighbors.
# Point 1421 has 19 neighbors.
# Point 1422 has 17 neighbors.
# Point 1423 has 19 neighbors.
# Point 1424 has 18 neighbors.
# Point 1425 has 19 neighbors.
# Point 1426 has 19 neighbors.
# Point 1427 has 19 neighbors.
# Point 1428 has 19 neighbors.
# Point 1429 has 16 neighbors.
# Point 1430 has 19 neighbors.
# Point 1431 has 19 neighbors.
# Point 1432 has 18 neighbors.
# Point 1433 has 19 neighbors.
# Point 1434 has 19 neighbors.
# Point 1435 has 19 neighbors.
# Point 1436 has 19 neighbors.
# Point 1437 has 19 neighbors.
# Point 1438 has 19 neighbors.
# Point 1439 has 11 neighbors.
# Point 1440 has 19 neighbors.
# Point 1441 has 19 neighbors.
# Point 1442 has 16 neighbors.
# Point 1443 has 19 neighbors.
# Point 1444 has 18 neighbors.
# Point 1445 has 19 neighbors.
# Point 1446 has 19 neighbors.
# Point 1447 has 19 neighbors.
# Point 1448 has 19 neighbors.
# Point 1449 has 14 neighbors.
# Point 1450 has 19 neighbors.
# Point 1451 has 19 neighbors.
# Point 1452 has 12 neighbors.
# Point 1453 has 19 neighbors.
# Point 1454 has 19 neighbors.
# Point 1455 has 19 neighbors.
# Point 1456 has 19 neighbors.
# Point 1457 has 19 neighbors.
# Point 1458 has 19 neighbors.
# Point 1459 has 19 neighbors.
# Point 1460 has 19 neighbors.
# Point 1461 has 19 neighbors.
# Point 1462 has 19 neighbors.
# Point 1463 has 18 neighbors.
# Point 1464 has 19 neighbors.
# Point 1465 has 19 neighbors.
# Point 1466 has 19 neighbors.
# Point 1467 has 19 neighbors.
# Point 1468 has 19 neighbors.
# Point 1469 has 11 neighbors.
# Point 1470 has 19 neighbors.
# Point 1471 has 19 neighbors.
# Point 1472 has 12 neighbors.
# Point 1473 has 19 neighbors.
# Point 1474 has 19 neighbors.
# Point 1475 has 12 neighbors.
# Point 1476 has 12 neighbors.
# Point 1477 has 19 neighbors.
# Point 1478 has 18 neighbors.
# Point 1479 has 10 neighbors.
# Point 1480 has 18 neighbors.
# Point 1481 has 19 neighbors.
# Point 1482 has 19 neighbors.
# Point 1483 has 19 neighbors.
# Point 1484 has 19 neighbors.
# Point 1485 has 19 neighbors.
# Point 1486 has 18 neighbors.
# Point 1487 has 19 neighbors.
# Point 1488 has 19 neighbors.
# Point 1489 has 19 neighbors.
# Point 1490 has 19 neighbors.
# Point 1491 has 19 neighbors.
# Point 1492 has 19 neighbors.
# Point 1493 has 15 neighbors.
# Point 1494 has 19 neighbors.
# Point 1495 has 19 neighbors.
# Point 1496 has 19 neighbors.
# Point 1497 has 19 neighbors.
# Point 1498 has 19 neighbors.
# Point 1499 has 19 neighbors.
# Point 1500 has 19 neighbors.
# Point 1501 has 19 neighbors.
# Point 1502 has 19 neighbors.
# Point 1503 has 18 neighbors.
# Point 1504 has 18 neighbors.
# Point 1505 has 17 neighbors.
# Point 1506 has 19 neighbors.
# Point 1507 has 19 neighbors.
# Point 1508 has 18 neighbors.
# Point 1509 has 19 neighbors.
# Point 1510 has 11 neighbors.
# Point 1511 has 15 neighbors.
# Point 1512 has 19 neighbors.
# Point 1513 has 19 neighbors.
# Point 1514 has 14 neighbors.
# Point 1515 has 19 neighbors.
# Point 1516 has 19 neighbors.
# Point 1517 has 13 neighbors.
# Point 1518 has 19 neighbors.
# Point 1519 has 19 neighbors.
# Point 1520 has 19 neighbors.
# Point 1521 has 19 neighbors.
# Point 1522 has 19 neighbors.
# Point 1523 has 19 neighbors.
# Point 1524 has 19 neighbors.
# Point 1525 has 19 neighbors.
# Point 1526 has 9 neighbors.
# Point 1527 has 19 neighbors.
# Point 1528 has 19 neighbors.
# Point 1529 has 19 neighbors.
# Point 1530 has 17 neighbors.
# Point 1531 has 19 neighbors.
# Point 1532 has 11 neighbors.
# Point 1533 has 18 neighbors.
# Point 1534 has 19 neighbors.
# Point 1535 has 12 neighbors.
# Point 1536 has 19 neighbors.
# Point 1537 has 19 neighbors.
# Point 1538 has 19 neighbors.
# Point 1539 has 15 neighbors.
# Point 1540 has 19 neighbors.
# Point 1541 has 15 neighbors.
# Point 1542 has 17 neighbors.
# Point 1543 has 19 neighbors.
# Point 1544 has 19 neighbors.
# Point 1545 has 19 neighbors.
# Point 1546 has 13 neighbors.
# Point 1547 has 17 neighbors.
# Point 1548 has 18 neighbors.
# Point 1549 has 18 neighbors.
# Point 1550 has 19 neighbors.
# Point 1551 has 15 neighbors.
# Point 1552 has 16 neighbors.
# Point 1553 has 19 neighbors.
# Point 1554 has 19 neighbors.
# Point 1555 has 19 neighbors.
# Point 1556 has 19 neighbors.
# Point 1557 has 19 neighbors.
# Point 1558 has 19 neighbors.
# Point 1559 has 19 neighbors.
# Point 1560 has 19 neighbors.
# Point 1561 has 18 neighbors.
# Point 1562 has 16 neighbors.
# Point 1563 has 16 neighbors.
# Point 1564 has 19 neighbors.
# Point 1565 has 19 neighbors.
# Point 1566 has 19 neighbors.
# Point 1567 has 19 neighbors.
# Point 1568 has 19 neighbors.
# Point 1569 has 19 neighbors.
# Point 1570 has 19 neighbors.
# Point 1571 has 19 neighbors.
# Point 1572 has 14 neighbors.
# Point 1573 has 19 neighbors.
# Point 1574 has 19 neighbors.
# Point 1575 has 18 neighbors.
# Point 1576 has 19 neighbors.
# Point 1577 has 19 neighbors.
# Point 1578 has 12 neighbors.
# Point 1579 has 19 neighbors.
# Point 1580 has 19 neighbors.
# Point 1581 has 19 neighbors.
# Point 1582 has 19 neighbors.
# Point 1583 has 19 neighbors.
# Point 1584 has 19 neighbors.
# Point 1585 has 19 neighbors.
# Point 1586 has 19 neighbors.
# Point 1587 has 19 neighbors.
# Point 1588 has 12 neighbors.
# Point 1589 has 19 neighbors.
# Point 1590 has 19 neighbors.
# Point 1591 has 19 neighbors.
# Point 1592 has 18 neighbors.
# Point 1593 has 19 neighbors.
# Point 1594 has 16 neighbors.
# Point 1595 has 19 neighbors.
# Point 1596 has 19 neighbors.
# Point 1597 has 19 neighbors.
# Point 1598 has 14 neighbors.
# Point 1599 has 19 neighbors.
# Point 1600 has 19 neighbors.
# Point 1601 has 12 neighbors.
# Point 1602 has 19 neighbors.
# Point 1603 has 19 neighbors.
# Point 1604 has 19 neighbors.
# Point 1605 has 19 neighbors.
# Point 1606 has 19 neighbors.
# Point 1607 has 12 neighbors.
# Point 1608 has 19 neighbors.
# Point 1609 has 14 neighbors.
# Point 1610 has 19 neighbors.
# Point 1611 has 19 neighbors.
# Point 1612 has 19 neighbors.
# Point 1613 has 19 neighbors.
# Point 1614 has 19 neighbors.
# Point 1615 has 19 neighbors.
# Point 1616 has 16 neighbors.
# Point 1617 has 19 neighbors.
# Point 1618 has 19 neighbors.
# Point 1619 has 19 neighbors.
# Point 1620 has 19 neighbors.
# Point 1621 has 19 neighbors.
# Point 1622 has 19 neighbors.
# Point 1623 has 19 neighbors.
# Point 1624 has 17 neighbors.
# Point 1625 has 16 neighbors.
# Point 1626 has 19 neighbors.
# Point 1627 has 19 neighbors.
# Point 1628 has 19 neighbors.
# Point 1629 has 19 neighbors.
# Point 1630 has 19 neighbors.
# Point 1631 has 18 neighbors.
# Point 1632 has 18 neighbors.
# Point 1633 has 19 neighbors.
# Point 1634 has 19 neighbors.
# Point 1635 has 16 neighbors.
# Point 1636 has 19 neighbors.
# Point 1637 has 18 neighbors.
# Point 1638 has 19 neighbors.
# Point 1639 has 19 neighbors.
# Point 1640 has 19 neighbors.
# Point 1641 has 19 neighbors.
# Point 1642 has 19 neighbors.
# Point 1643 has 19 neighbors.
# Point 1644 has 19 neighbors.
# Point 1645 has 19 neighbors.
# Point 1646 has 19 neighbors.
# Point 1647 has 19 neighbors.
# Point 1648 has 19 neighbors.
# Point 1649 has 15 neighbors.
# Point 1650 has 19 neighbors.
# Point 1651 has 19 neighbors.
# Point 1652 has 19 neighbors.
# Point 1653 has 18 neighbors.
# Point 1654 has 19 neighbors.
# Point 1655 has 19 neighbors.
# Point 1656 has 19 neighbors.
# Point 1657 has 19 neighbors.
# Point 1658 has 19 neighbors.
# Point 1659 has 19 neighbors.
# Point 1660 has 19 neighbors.
# Point 1661 has 19 neighbors.
# Point 1662 has 19 neighbors.
# Point 1663 has 16 neighbors.
# Point 1664 has 19 neighbors.
# Point 1665 has 19 neighbors.
# Point 1666 has 19 neighbors.
# Point 1667 has 19 neighbors.
# Point 1668 has 19 neighbors.
# Point 1669 has 19 neighbors.
# Point 1670 has 19 neighbors.
# Point 1671 has 19 neighbors.
# Point 1672 has 19 neighbors.
# Point 1673 has 19 neighbors.
# Point 1674 has 18 neighbors.
# Point 1675 has 19 neighbors.
# Point 1676 has 12 neighbors.
# Point 1677 has 12 neighbors.
# Point 1678 has 19 neighbors.
# Point 1679 has 17 neighbors.
# Point 1680 has 19 neighbors.
# Point 1681 has 19 neighbors.
# Point 1682 has 19 neighbors.
# Point 1683 has 12 neighbors.
# Point 1684 has 19 neighbors.
# Point 1685 has 19 neighbors.
# Point 1686 has 19 neighbors.
# Point 1687 has 16 neighbors.
# Point 1688 has 19 neighbors.
# Point 1689 has 19 neighbors.
# Point 1690 has 19 neighbors.
# Point 1691 has 18 neighbors.
# Point 1692 has 19 neighbors.
# Point 1693 has 13 neighbors.
# ...
# Point 50 has 15 neighbors.
# Point 51 has 19 neighbors.
# Point 52 has 19 neighbors.
# Point 53 has 19 neighbors.
# Point 54 has 11 neighbors.
# Point 55 has 19 neighbors.
# Point 56 has 19 neighbors.
# Point 57 has 19 neighbors.
# Point 58 has 17 neighbors.
# Point 59 has 19 neighbors.
# Point 60 has 19 neighbors.
# Point 61 has 19 neighbors.
# Point 62 has 11 neighbors.
# Point 63 has 19 neighbors.
# Point 64 has 19 neighbors.
# Point 65 has 19 neighbors.
# Point 66 has 13 neighbors.
# Point 67 has 19 neighbors.
# Point 68 has 15 neighbors.
# Point 69 has 19 neighbors.
# Point 70 has 15 neighbors.
# Point 71 has 10 neighbors.
# Point 72 has 19 neighbors.
# Point 73 has 15 neighbors.
# Point 74 has 9 neighbors.
# Point 75 has 19 neighbors.
# Point 76 has 12 neighbors.
# Point 77 has 10 neighbors.
# Point 78 has 18 neighbors.
# Point 79 has 19 neighbors.
# Point 80 has 19 neighbors.
# Point 81 has 19 neighbors.
# Point 82 has 19 neighbors.
# Point 83 has 15 neighbors.
# Point 84 has 19 neighbors.
# Point 85 has 18 neighbors.
# Point 86 has 8 neighbors.
# Point 87 has 19 neighbors.
# Point 88 has 19 neighbors.
# Point 89 has 19 neighbors.
# Point 90 has 10 neighbors.
# Point 91 has 19 neighbors.
# Point 92 has 19 neighbors.
# Point 93 has 19 neighbors.
# Point 94 has 19 neighbors.
# Point 95 has 19 neighbors.
# Point 96 has 16 neighbors.
# Point 97 has 19 neighbors.
# Point 98 has 13 neighbors.
# Point 99 has 19 neighbors.
# Point 100 has 19 neighbors.
# Point 101 has 18 neighbors.
# Point 102 has 18 neighbors.
# Point 103 has 19 neighbors.
# Point 104 has 19 neighbors.
# Point 105 has 19 neighbors.
# Point 106 has 16 neighbors.
# Point 107 has 19 neighbors.
# Point 108 has 9 neighbors.
# Point 109 has 19 neighbors.
# Point 110 has 19 neighbors.
# Point 111 has 19 neighbors.
# Point 112 has 16 neighbors.
# Point 113 has 18 neighbors.
# Point 114 has 12 neighbors.
# Point 115 has 12 neighbors.
# Point 116 has 19 neighbors.
# Point 117 has 19 neighbors.
# Point 118 has 18 neighbors.
# Point 119 has 19 neighbors.
# Point 120 has 19 neighbors.
# Point 121 has 19 neighbors.
# Point 122 has 18 neighbors.
# Point 123 has 19 neighbors.
# Point 124 has 19 neighbors.
# Point 125 has 19 neighbors.
# Point 126 has 19 neighbors.
# Point 127 has 15 neighbors.
# Point 128 has 5 neighbors.
# Point 129 has 14 neighbors.
# Point 130 has 13 neighbors.
# Point 131 has 19 neighbors.
# Point 132 has 18 neighbors.
# Point 133 has 9 neighbors.
# Point 134 has 19 neighbors.
# Point 135 has 7 neighbors.
# Point 136 has 15 neighbors.
# Point 137 has 19 neighbors.
# Point 138 has 14 neighbors.
# Point 139 has 19 neighbors.
# Point 140 has 14 neighbors.
# Point 141 has 17 neighbors.
# Point 142 has 19 neighbors.
# Point 143 has 10 neighbors.
# Point 144 has 19 neighbors.
# Point 145 has 12 neighbors.
# Point 146 has 19 neighbors.
# Point 147 has 10 neighbors.
# Point 148 has 19 neighbors.
# Point 149 has 13 neighbors.
# Point 150 has 13 neighbors.
# Point 151 has 18 neighbors.
# Point 152 has 11 neighbors.
# Point 153 has 11 neighbors.
# Point 154 has 18 neighbors.
# Point 155 has 12 neighbors.
# Point 156 has 12 neighbors.
# Point 157 has 19 neighbors.
# Point 158 has 13 neighbors.
# Point 159 has 14 neighbors.
# Point 160 has 8 neighbors.
# Point 161 has 19 neighbors.
# Point 162 has 12 neighbors.
# Point 163 has 12 neighbors.
# Point 164 has 19 neighbors.
# Point 165 has 19 neighbors.
# Point 166 has 19 neighbors.
# Point 167 has 19 neighbors.
# Point 168 has 19 neighbors.
# Point 169 has 19 neighbors.
# Point 170 has 19 neighbors.
# Point 171 has 16 neighbors.
# Point 172 has 19 neighbors.
# Point 173 has 19 neighbors.
# Point 174 has 15 neighbors.
# Point 175 has 9 neighbors.
# Point 176 has 19 neighbors.
# Point 177 has 19 neighbors.
# Point 178 has 19 neighbors.
# Point 179 has 19 neighbors.
# Point 180 has 19 neighbors.
# Point 181 has 19 neighbors.
# Point 182 has 19 neighbors.
# Point 183 has 19 neighbors.
# Point 184 has 19 neighbors.
# Point 185 has 15 neighbors.
# Point 186 has 18 neighbors.
# Point 187 has 17 neighbors.
# Point 188 has 19 neighbors.
# Point 189 has 19 neighbors.
# Point 190 has 15 neighbors.
# Point 191 has 14 neighbors.
# Point 192 has 13 neighbors.
# Point 193 has 19 neighbors.
# Point 194 has 19 neighbors.
# Point 195 has 14 neighbors.
# Point 196 has 18 neighbors.
# Point 197 has 19 neighbors.
# Point 198 has 12 neighbors.
# Point 199 has 18 neighbors.
# Point 200 has 19 neighbors.
# Point 201 has 9 neighbors.
# Point 202 has 19 neighbors.
# Point 203 has 9 neighbors.
# Point 204 has 19 neighbors.
# Point 205 has 16 neighbors.
# Point 206 has 16 neighbors.
# Point 207 has 19 neighbors.
# Point 208 has 11 neighbors.
# Point 209 has 12 neighbors.
# Point 210 has 12 neighbors.
# Point 211 has 19 neighbors.
# Point 212 has 19 neighbors.
# Point 213 has 11 neighbors.
# Point 214 has 11 neighbors.
# Point 215 has 19 neighbors.
# Point 216 has 10 neighbors.
# Point 217 has 15 neighbors.
# Point 218 has 19 neighbors.
# Point 219 has 18 neighbors.
# Point 220 has 19 neighbors.
# Point 221 has 16 neighbors.
# Point 222 has 19 neighbors.
# Point 223 has 19 neighbors.
# Point 224 has 19 neighbors.
# Point 225 has 19 neighbors.
# Point 226 has 18 neighbors.
# Point 227 has 10 neighbors.
# Point 228 has 19 neighbors.
# Point 229 has 13 neighbors.
# Point 230 has 17 neighbors.
# Point 231 has 10 neighbors.
# Point 232 has 16 neighbors.
# Point 233 has 14 neighbors.
# Point 234 has 19 neighbors.
# Point 235 has 12 neighbors.
# Point 236 has 13 neighbors.
# Point 237 has 14 neighbors.
# Point 238 has 19 neighbors.
# Point 239 has 10 neighbors.
# Point 240 has 15 neighbors.
# Point 241 has 10 neighbors.
# Point 242 has 19 neighbors.
# Point 243 has 19 neighbors.
# Point 244 has 18 neighbors.
# Point 245 has 13 neighbors.
# Point 246 has 12 neighbors.
# Point 247 has 19 neighbors.
# Point 248 has 19 neighbors.
# Point 249 has 19 neighbors.
# Point 250 has 19 neighbors.
# Point 251 has 6 neighbors.
# Point 252 has 19 neighbors.
# Point 253 has 14 neighbors.
# Point 254 has 19 neighbors.
# Point 255 has 18 neighbors.
# Point 256 has 18 neighbors.
# Point 257 has 19 neighbors.
# Point 258 has 16 neighbors.
# Point 259 has 19 neighbors.
# Point 260 has 19 neighbors.
# Point 261 has 17 neighbors.
# Point 262 has 18 neighbors.
# Point 263 has 4 neighbors.
# Point 264 has 19 neighbors.
# Point 265 has 19 neighbors.
# Point 266 has 19 neighbors.
# Point 267 has 18 neighbors.
# Point 268 has 19 neighbors.
# Point 269 has 19 neighbors.
# Point 270 has 13 neighbors.
# Point 271 has 18 neighbors.
# Point 272 has 11 neighbors.
# Point 273 has 10 neighbors.
# Point 274 has 10 neighbors.
# Point 275 has 9 neighbors.
# Point 276 has 19 neighbors.
# Point 277 has 11 neighbors.
# Point 278 has 18 neighbors.
# Point 279 has 19 neighbors.
# Point 280 has 19 neighbors.
# Point 281 has 18 neighbors.
# Point 282 has 11 neighbors.
# Point 283 has 15 neighbors.
# Point 284 has 18 neighbors.
# Point 285 has 19 neighbors.
# Point 286 has 19 neighbors.
# Point 287 has 19 neighbors.
# Point 288 has 19 neighbors.
# Point 289 has 12 neighbors.
# Point 290 has 16 neighbors.
# Point 291 has 17 neighbors.
# Point 292 has 11 neighbors.
# Point 293 has 16 neighbors.
# Point 294 has 15 neighbors.
# Point 295 has 18 neighbors.
# Point 296 has 19 neighbors.
# Point 297 has 19 neighbors.
# Point 298 has 19 neighbors.
# Point 299 has 18 neighbors.
# Point 300 has 19 neighbors.
# Point 301 has 18 neighbors.
# Point 302 has 11 neighbors.
# Point 303 has 19 neighbors.
# Point 304 has 19 neighbors.
# Point 305 has 9 neighbors.
# Point 306 has 17 neighbors.
# Point 307 has 19 neighbors.
# Point 308 has 19 neighbors.
# Point 309 has 19 neighbors.
# Point 310 has 12 neighbors.
# Point 311 has 16 neighbors.
# Point 312 has 19 neighbors.
# Point 313 has 17 neighbors.
# Point 314 has 17 neighbors.
# Point 315 has 19 neighbors.
# Point 316 has 16 neighbors.
# Point 317 has 19 neighbors.
# Point 318 has 8 neighbors.
# Point 319 has 18 neighbors.
# Point 320 has 19 neighbors.
# Point 321 has 6 neighbors.
# Point 322 has 15 neighbors.
# Point 323 has 18 neighbors.
# Point 324 has 12 neighbors.
# Point 325 has 18 neighbors.
# Point 326 has 11 neighbors.
# Point 327 has 19 neighbors.
# Updated table for slide S_1:
#       x     y        C1        C2        C3        C4        C5        C6  \
# 0  1554  1297  0.014401  0.057499  0.022033  0.001704  0.533992  1.511707
# 1   462  1502  0.116196  0.197176  0.110600  0.042614  5.587681  0.006885
# 2  1488  1548  0.133284  0.035880  0.061352  0.003073  1.104479  0.009174
# 3  1725  1182  0.087715  0.235223  0.090382  0.013902  8.760482  0.140912
# 4   581  1113  0.128468  0.066399  0.098982  0.047022  3.425771  0.001009
#
#          C7        C8  ...       C28       C29       C30       C31       C32  \
# 0  0.015313  0.020029  ...  0.121361  0.007344  0.000017  0.036891  0.035934
# 1  0.096346  0.001711  ...  0.000238  0.024071  0.000023  0.217589  0.100662
# 2  0.009175  0.000114  ...  0.001401  0.000699  0.000009  0.024491  0.018810
# 3  0.188859  0.010154  ...  0.002036  0.047165  0.000022  0.180372  0.202981
# 4  0.026881  0.000468  ...  0.000048  0.006359  0.000585  0.052661  0.032168
#
#         C33       C34       C35  x_normalized  y_normalized
# 0  0.118937  0.001472  0.050057      0.815877      0.585326
# 1  0.004027  0.004122  0.049491      0.087392      0.754328
# 2  0.004171  0.000425  0.015348      0.771848      0.792251
# 3  0.003709  0.001845  0.116022      0.929953      0.490519
# 4  0.000107  0.000107  0.013103      0.166778      0.433636
#
# [5 rows x 39 columns]
# Updated table for slide S_2:
#       x     y        C1        C2        C3        C4        C5        C6  \
# 0  1572  1350  1.542454  0.052541  1.415544  0.487771  0.291268  0.000100
# 1   480  1555  3.257770  0.057553  1.948030  0.806345  0.484212  0.000077
# 2  1467   526  0.081944  0.013208  0.085818  0.271692  1.027989  0.066760
# 3   349  1189  5.108457  0.072301  2.773961  1.386638  0.496647  0.000065
# 4   401  1280  0.199682  0.014278  0.109534  0.007316  0.028238  0.000008
#
#          C7        C8  ...       C28       C29           C30       C31  \
# 0  0.016733  0.000078  ...  0.000156  0.000086  4.929894e-05  0.073729
# 1  0.032623  0.000092  ...  0.000147  0.001001  1.824790e-06  0.093010
# 2  0.009644  0.000291  ...  0.000005  0.000914  1.203776e-07  0.010981
# 3  0.031599  0.000490  ...  0.000365  0.000139  6.238090e-06  0.217229
# 4  0.000730  0.000158  ...  0.000005  0.000007  3.539291e-04  0.003999
#
#         C32           C33       C34       C35  x_normalized  y_normalized
# 0  0.066650  1.158249e-04  0.010423  0.050226      0.883910      0.684816
# 1  0.067205  2.352456e-02  0.026911  0.052347      0.142566      0.842025
# 2  0.006998  2.140756e-05  0.000059  0.003903      0.812627      0.052914
# 3  0.109407  1.024292e-04  0.064159  0.070167      0.053632      0.561350
# 4  0.006315  8.194072e-07  0.001353  0.000929      0.088934      0.631135
#
# [5 rows x 39 columns]
# Updated table for slide S_3:
#       x     y        C1        C2        C3        C4        C5        C6  \
# 0  1191   942  0.306145  0.022716  0.268922  0.850054  0.206196  0.058142
# 1  1037  1165  0.890074  0.170684  0.932113  0.290531  0.468740  0.000107
# 2   882  1388  0.499127  0.012574  0.487293  0.484179  0.129711  0.013899
# 3   973   696  0.188902  0.098136  0.100406  0.017040  0.409086  0.002186
# 4  1062  1210  1.473281  0.103033  1.118319  0.545588  0.621331  0.000447
#
#          C7        C8  ...       C28       C29       C30       C31       C32  \
# 0  0.008256  0.000067  ...  0.000106  0.001204  0.000032  0.017809  0.019789
# 1  0.034436  0.002441  ...  0.000792  0.003716  0.004590  0.122161  0.176697
# 2  0.004930  0.000015  ...  0.000007  0.000014  0.000002  0.010597  0.012455
# 3  0.011203  0.001725  ...  0.009246  0.011668  0.000842  0.069660  0.036147
# 4  0.038807  0.000576  ...  0.000793  0.003383  0.001091  0.107601  0.075335
#
#         C33       C34       C35  x_normalized  y_normalized
# 0  0.000061  0.000919  0.018196      0.756055      0.418750
# 1  0.001314  0.005219  0.050833      0.489619      0.651042
# 2  0.000022  0.001780  0.008370      0.221453      0.883333
# 3  0.003761  0.001655  0.014094      0.378893      0.162500
# 4  0.000607  0.004124  0.057966      0.532872      0.697917
#
# [5 rows x 39 columns]
# Updated table for slide S_4:
#       x     y        C1        C2        C3        C4        C5        C6  \
# 0   448  1481  0.110442  0.289731  0.156742  0.004558  0.000550  1.381400
# 1   563  1104  0.069022  0.397829  0.085766  0.000430  0.000142  0.026102
# 2   742  1326  0.028899  0.006405  0.006362  0.000166  0.089617  0.034687
# 3  1214   950  0.142531  1.134048  0.301456  0.000317  2.822195  0.000481
# 4  1098  1637  0.005329  0.007513  0.007087  0.000100  0.000466  0.091028
#
#          C7        C8  ...       C28       C29       C30       C31       C32  \
# 0  0.137226  0.013491  ...  1.633818  0.642298  0.000254  0.163243  0.337061
# 1  0.044741  0.031642  ...  0.162494  0.005902  0.613525  0.290938  0.199921
# 2  0.000730  0.000008  ...  0.000014  0.000054  0.000003  0.003410  0.003847
# 3  0.205789  0.185942  ...  0.193207  0.989575  0.834564  0.738212  0.667664
# 4  0.002012  0.000225  ...  0.003692  0.001010  0.000003  0.004595  0.011039
#
#         C33       C34       C35  x_normalized  y_normalized
# 0  0.167966  0.040062  0.337252      0.062562      0.804180
# 1  0.136424  0.009193  0.120528      0.176763      0.389439
# 2  0.000007  0.000017  0.002217      0.354518      0.633663
# 3  0.138013  0.049496  0.365663      0.823237      0.220022
# 4  0.000025  0.000126  0.010888      0.708044      0.975798
#
# [5 rows x 39 columns]
# Updated table for slide S_5:
#       x     y        C1        C2        C3        C4        C5        C6  \
# 0  1495  1261  0.021646  0.058713  0.010598  0.000654  0.000275  0.000091
# 1  1393   462  0.048376  0.030789  0.024272  0.015951  0.003141  0.042053
# 2  1661  1150  0.068092  0.218585  0.035569  0.000002  0.000005  0.000003
# 3  1202   928  0.076381  0.288892  0.052146  0.000072  0.000341  0.013603
# 4  1635   662  4.104257  1.152663  1.977180  0.166353  0.016428  0.001340
#
#          C7        C8  ...       C28       C29       C30       C31       C32  \
# 0  0.006006  0.001666  ...  0.000611  0.000379  0.232393  0.025239  0.016427
# 1  0.008928  0.001763  ...  0.001578  0.005355  0.000037  0.015891  0.023034
# 2  0.023652  0.012993  ...  0.008716  0.008028  0.946842  0.106590  0.071411
# 3  0.037613  0.021836  ...  0.011327  0.008719  0.484054  0.181469  0.116788
# 4  0.296567  0.055075  ...  0.095200  0.097710  0.773685  1.158112  0.786256
#
#         C33       C34       C35  x_normalized  y_normalized
# 0  0.000277  0.000383  0.007827      0.731029      0.866733
# 1  0.002034  0.016076  0.009496      0.645025      0.066132
# 2  0.003074  0.006676  0.032106      0.870995      0.755511
# 3  0.022435  0.010385  0.050761      0.483980      0.533066
# 4  0.015534  0.286496  0.334479      0.849073      0.266533
#
# [5 rows x 39 columns]
# Updated table for slide S_6:
#       x     y        C1        C2        C3        C4        C5        C6  \
# 0  1211   954  0.103681  0.599986  0.207474  0.003284  0.073070  0.002365
# 1  1057  1177  0.048212  0.197546  0.081925  0.007579  8.720077  0.000514
# 2  1082  1221  0.007926  0.053786  0.006056  0.000176  2.084878  0.000841
# 3   916  1154  0.000693  0.014479  0.001580  0.000009  0.333247  0.000008
# 4   942   931  0.005163  0.065887  0.020324  0.000199  0.151354  0.019961
#
#          C7        C8  ...       C28       C29       C30       C31       C32  \
# 0  0.213494  0.054137  ...  0.017699  0.026112  0.503582  0.359966  0.273288
# 1  0.111266  0.027179  ...  0.005945  0.171377  0.000601  0.151940  0.073384
# 2  0.023584  0.000399  ...  0.000169  0.006873  0.000768  0.038273  0.013365
# 3  0.005077  0.000138  ...  0.000020  0.000078  0.000238  0.007115  0.003421
# 4  0.004412  0.000892  ...  0.000255  0.002707  0.000789  0.027743  0.025575
#
#         C33       C34       C35  x_normalized  y_normalized
# 0  0.187153  0.039624  0.224019      0.831897      0.367713
# 1  0.003834  0.001132  0.061351      0.500000      0.701046
# 2  0.001754  0.000064  0.005133      0.553879      0.766816
# 3  0.000118  0.000021  0.001272      0.196121      0.666667
# 4  0.001270  0.000245  0.009807      0.252155      0.333333
#
# [5 rows x 39 columns]

# %%
slide_edge_indices
# Out:
# {'S_1': tensor([[   0,    0,    0,  ..., 2196, 2196, 2196],
#          [ 141,  413, 2018,  ...,  657, 1896, 2183]]),
#  'S_2': tensor([[   0,    0,    0,  ..., 2269, 2269, 2269],
#          [ 357, 1276, 2087,  ..., 1356,  337, 1456]]),
#  'S_3': tensor([[  0,   0,   0,  ..., 689, 689, 689],
#          [419, 649,  18,  ..., 587, 451, 598]]),
#  'S_4': tensor([[   0,    0,    0,  ..., 1186, 1186, 1186],
#          [ 957,  755,  534,  ...,  564,  310,  363]]),
#  'S_5': tensor([[   0,    0,    0,  ..., 1676, 1676, 1676],
#          [1539,  361,  292,  ..., 1091,  599, 1419]]),
#  'S_6': tensor([[  0,   0,   0,  ..., 327, 327, 327],
#          [312, 317,  94,  ..., 285, 211, 249]])}

# %%
import torch


torch.save({
    'normal_coords':normal_coords,
    'slide_edge_indices': slide_edge_indices
}, "train_slide_edge_indices.pt")

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.spatial import KDTree

def compute_edge_index_and_neighbor_counts(coords, radius=128):
    """
    計算每個 batch 的 edge_index（鄰接關係）和鄰居數量
    """
    kdtree = KDTree(coords)
    edge_list = []
    neighbor_counts = []
    
    for i, coord in enumerate(coords):
        neighbors = kdtree.query_ball_point(coord, r=radius)
        neighbor_counts.append(len(neighbors))  # 記錄每個點的鄰居數量
        for j in neighbors:
            if i != j:
                edge_list.append([i, j])

    edge_index = torch.tensor(edge_list, dtype=torch.long).t().contiguous()
    return edge_index, neighbor_counts

# 假設有一些 (x, y) 座標np.array([[100, 200], [120, 220], [300, 400], [500, 600], [130, 230]])
coords = df[['x', 'y']].values

# 計算 `edge_index` 和每個點的鄰居數量
radius = 64
edge_index, neighbor_counts = compute_edge_index_and_neighbor_counts(coords, radius)

# 繪製鄰居數量的分佈圖
plt.hist(neighbor_counts, bins=20, color='blue', alpha=0.7)
plt.xlabel('Number of Neighbors')
plt.ylabel('Frequency')
plt.title(f'Distribution of Neighbors with radius={radius}')
plt.show()

# 打印每個點的鄰居數量
for i, count in enumerate(neighbor_counts):
    print(f"Point {i} has {count} neighbors.")
# Out:
# Point 0 has 19 neighbors.
# Point 1 has 19 neighbors.
# Point 2 has 12 neighbors.
# Point 3 has 16 neighbors.
# Point 4 has 19 neighbors.
# Point 5 has 9 neighbors.
# Point 6 has 19 neighbors.
# Point 7 has 19 neighbors.
# Point 8 has 19 neighbors.
# Point 9 has 18 neighbors.
# Point 10 has 19 neighbors.
# Point 11 has 18 neighbors.
# Point 12 has 14 neighbors.
# Point 13 has 19 neighbors.
# Point 14 has 17 neighbors.
# Point 15 has 12 neighbors.
# Point 16 has 19 neighbors.
# Point 17 has 14 neighbors.
# Point 18 has 19 neighbors.
# Point 19 has 19 neighbors.
# Point 20 has 19 neighbors.
# Point 21 has 19 neighbors.
# Point 22 has 11 neighbors.
# Point 23 has 19 neighbors.
# Point 24 has 8 neighbors.
# Point 25 has 11 neighbors.
# Point 26 has 19 neighbors.
# Point 27 has 19 neighbors.
# Point 28 has 19 neighbors.
# Point 29 has 19 neighbors.
# Point 30 has 19 neighbors.
# Point 31 has 19 neighbors.
# Point 32 has 15 neighbors.
# Point 33 has 12 neighbors.
# Point 34 has 12 neighbors.
# Point 35 has 18 neighbors.
# Point 36 has 19 neighbors.
# Point 37 has 17 neighbors.
# Point 38 has 18 neighbors.
# Point 39 has 17 neighbors.
# Point 40 has 19 neighbors.
# Point 41 has 19 neighbors.
# Point 42 has 19 neighbors.
# Point 43 has 19 neighbors.
# Point 44 has 19 neighbors.
# Point 45 has 11 neighbors.
# Point 46 has 19 neighbors.
# Point 47 has 17 neighbors.
# Point 48 has 17 neighbors.
# Point 49 has 13 neighbors.
# Point 50 has 15 neighbors.
# Point 51 has 19 neighbors.
# Point 52 has 19 neighbors.
# Point 53 has 19 neighbors.
# Point 54 has 11 neighbors.
# Point 55 has 19 neighbors.
# Point 56 has 19 neighbors.
# Point 57 has 19 neighbors.
# Point 58 has 17 neighbors.
# Point 59 has 19 neighbors.
# Point 60 has 19 neighbors.
# Point 61 has 19 neighbors.
# Point 62 has 11 neighbors.
# Point 63 has 19 neighbors.
# Point 64 has 19 neighbors.
# Point 65 has 19 neighbors.
# Point 66 has 13 neighbors.
# Point 67 has 19 neighbors.
# Point 68 has 15 neighbors.
# Point 69 has 19 neighbors.
# Point 70 has 15 neighbors.
# Point 71 has 10 neighbors.
# Point 72 has 19 neighbors.
# Point 73 has 15 neighbors.
# Point 74 has 9 neighbors.
# Point 75 has 19 neighbors.
# Point 76 has 12 neighbors.
# Point 77 has 10 neighbors.
# Point 78 has 18 neighbors.
# Point 79 has 19 neighbors.
# Point 80 has 19 neighbors.
# Point 81 has 19 neighbors.
# Point 82 has 19 neighbors.
# Point 83 has 15 neighbors.
# Point 84 has 19 neighbors.
# Point 85 has 18 neighbors.
# Point 86 has 8 neighbors.
# Point 87 has 19 neighbors.
# Point 88 has 19 neighbors.
# Point 89 has 19 neighbors.
# Point 90 has 10 neighbors.
# Point 91 has 19 neighbors.
# Point 92 has 19 neighbors.
# Point 93 has 19 neighbors.
# Point 94 has 19 neighbors.
# Point 95 has 19 neighbors.
# Point 96 has 16 neighbors.
# Point 97 has 19 neighbors.
# Point 98 has 13 neighbors.
# Point 99 has 19 neighbors.
# Point 100 has 19 neighbors.
# Point 101 has 18 neighbors.
# Point 102 has 18 neighbors.
# Point 103 has 19 neighbors.
# Point 104 has 19 neighbors.
# Point 105 has 19 neighbors.
# Point 106 has 16 neighbors.
# Point 107 has 19 neighbors.
# Point 108 has 9 neighbors.
# Point 109 has 19 neighbors.
# Point 110 has 19 neighbors.
# Point 111 has 19 neighbors.
# Point 112 has 16 neighbors.
# Point 113 has 18 neighbors.
# Point 114 has 12 neighbors.
# Point 115 has 12 neighbors.
# Point 116 has 19 neighbors.
# Point 117 has 19 neighbors.
# Point 118 has 18 neighbors.
# Point 119 has 19 neighbors.
# Point 120 has 19 neighbors.
# Point 121 has 19 neighbors.
# Point 122 has 18 neighbors.
# Point 123 has 19 neighbors.
# Point 124 has 19 neighbors.
# Point 125 has 19 neighbors.
# Point 126 has 19 neighbors.
# Point 127 has 15 neighbors.
# Point 128 has 5 neighbors.
# Point 129 has 14 neighbors.
# Point 130 has 13 neighbors.
# Point 131 has 19 neighbors.
# Point 132 has 18 neighbors.
# Point 133 has 9 neighbors.
# Point 134 has 19 neighbors.
# Point 135 has 7 neighbors.
# Point 136 has 15 neighbors.
# Point 137 has 19 neighbors.
# Point 138 has 14 neighbors.
# Point 139 has 19 neighbors.
# Point 140 has 14 neighbors.
# Point 141 has 17 neighbors.
# Point 142 has 19 neighbors.
# Point 143 has 10 neighbors.
# Point 144 has 19 neighbors.
# Point 145 has 12 neighbors.
# Point 146 has 19 neighbors.
# Point 147 has 10 neighbors.
# Point 148 has 19 neighbors.
# Point 149 has 13 neighbors.
# Point 150 has 13 neighbors.
# Point 151 has 18 neighbors.
# Point 152 has 11 neighbors.
# Point 153 has 11 neighbors.
# Point 154 has 18 neighbors.
# Point 155 has 12 neighbors.
# Point 156 has 12 neighbors.
# Point 157 has 19 neighbors.
# Point 158 has 13 neighbors.
# Point 159 has 14 neighbors.
# Point 160 has 8 neighbors.
# Point 161 has 19 neighbors.
# Point 162 has 12 neighbors.
# Point 163 has 12 neighbors.
# Point 164 has 19 neighbors.
# Point 165 has 19 neighbors.
# Point 166 has 19 neighbors.
# Point 167 has 19 neighbors.
# Point 168 has 19 neighbors.
# Point 169 has 19 neighbors.
# Point 170 has 19 neighbors.
# Point 171 has 16 neighbors.
# Point 172 has 19 neighbors.
# Point 173 has 19 neighbors.
# Point 174 has 15 neighbors.
# Point 175 has 9 neighbors.
# Point 176 has 19 neighbors.
# Point 177 has 19 neighbors.
# Point 178 has 19 neighbors.
# Point 179 has 19 neighbors.
# Point 180 has 19 neighbors.
# Point 181 has 19 neighbors.
# Point 182 has 19 neighbors.
# Point 183 has 19 neighbors.
# Point 184 has 19 neighbors.
# Point 185 has 15 neighbors.
# Point 186 has 18 neighbors.
# Point 187 has 17 neighbors.
# Point 188 has 19 neighbors.
# Point 189 has 19 neighbors.
# Point 190 has 15 neighbors.
# Point 191 has 14 neighbors.
# Point 192 has 13 neighbors.
# Point 193 has 19 neighbors.
# Point 194 has 19 neighbors.
# Point 195 has 14 neighbors.
# Point 196 has 18 neighbors.
# Point 197 has 19 neighbors.
# Point 198 has 12 neighbors.
# Point 199 has 18 neighbors.
# Point 200 has 19 neighbors.
# Point 201 has 9 neighbors.
# Point 202 has 19 neighbors.
# Point 203 has 9 neighbors.
# Point 204 has 19 neighbors.
# Point 205 has 16 neighbors.
# Point 206 has 16 neighbors.
# Point 207 has 19 neighbors.
# Point 208 has 11 neighbors.
# Point 209 has 12 neighbors.
# Point 210 has 12 neighbors.
# Point 211 has 19 neighbors.
# Point 212 has 19 neighbors.
# Point 213 has 11 neighbors.
# Point 214 has 11 neighbors.
# Point 215 has 19 neighbors.
# Point 216 has 10 neighbors.
# Point 217 has 15 neighbors.
# Point 218 has 19 neighbors.
# Point 219 has 18 neighbors.
# Point 220 has 19 neighbors.
# Point 221 has 16 neighbors.
# Point 222 has 19 neighbors.
# Point 223 has 19 neighbors.
# Point 224 has 19 neighbors.
# Point 225 has 19 neighbors.
# Point 226 has 18 neighbors.
# Point 227 has 10 neighbors.
# Point 228 has 19 neighbors.
# Point 229 has 13 neighbors.
# Point 230 has 17 neighbors.
# Point 231 has 10 neighbors.
# Point 232 has 16 neighbors.
# Point 233 has 14 neighbors.
# Point 234 has 19 neighbors.
# Point 235 has 12 neighbors.
# Point 236 has 13 neighbors.
# Point 237 has 14 neighbors.
# Point 238 has 19 neighbors.
# Point 239 has 10 neighbors.
# Point 240 has 15 neighbors.
# Point 241 has 10 neighbors.
# Point 242 has 19 neighbors.
# Point 243 has 19 neighbors.
# Point 244 has 18 neighbors.
# Point 245 has 13 neighbors.
# Point 246 has 12 neighbors.
# Point 247 has 19 neighbors.
# Point 248 has 19 neighbors.
# Point 249 has 19 neighbors.
# Point 250 has 19 neighbors.
# Point 251 has 6 neighbors.
# Point 252 has 19 neighbors.
# Point 253 has 14 neighbors.
# Point 254 has 19 neighbors.
# Point 255 has 18 neighbors.
# Point 256 has 18 neighbors.
# Point 257 has 19 neighbors.
# Point 258 has 16 neighbors.
# Point 259 has 19 neighbors.
# Point 260 has 19 neighbors.
# Point 261 has 17 neighbors.
# Point 262 has 18 neighbors.
# Point 263 has 4 neighbors.
# Point 264 has 19 neighbors.
# Point 265 has 19 neighbors.
# Point 266 has 19 neighbors.
# Point 267 has 18 neighbors.
# Point 268 has 19 neighbors.
# Point 269 has 19 neighbors.
# Point 270 has 13 neighbors.
# Point 271 has 18 neighbors.
# Point 272 has 11 neighbors.
# Point 273 has 10 neighbors.
# Point 274 has 10 neighbors.
# Point 275 has 9 neighbors.
# Point 276 has 19 neighbors.
# Point 277 has 11 neighbors.
# Point 278 has 18 neighbors.
# Point 279 has 19 neighbors.
# Point 280 has 19 neighbors.
# Point 281 has 18 neighbors.
# Point 282 has 11 neighbors.
# Point 283 has 15 neighbors.
# Point 284 has 18 neighbors.
# Point 285 has 19 neighbors.
# Point 286 has 19 neighbors.
# Point 287 has 19 neighbors.
# Point 288 has 19 neighbors.
# Point 289 has 12 neighbors.
# Point 290 has 16 neighbors.
# Point 291 has 17 neighbors.
# Point 292 has 11 neighbors.
# Point 293 has 16 neighbors.
# Point 294 has 15 neighbors.
# Point 295 has 18 neighbors.
# Point 296 has 19 neighbors.
# Point 297 has 19 neighbors.
# Point 298 has 19 neighbors.
# Point 299 has 18 neighbors.
# Point 300 has 19 neighbors.
# Point 301 has 18 neighbors.
# Point 302 has 11 neighbors.
# Point 303 has 19 neighbors.
# Point 304 has 19 neighbors.
# Point 305 has 9 neighbors.
# Point 306 has 17 neighbors.
# Point 307 has 19 neighbors.
# Point 308 has 19 neighbors.
# Point 309 has 19 neighbors.
# Point 310 has 12 neighbors.
# Point 311 has 16 neighbors.
# Point 312 has 19 neighbors.
# Point 313 has 17 neighbors.
# Point 314 has 17 neighbors.
# Point 315 has 19 neighbors.
# Point 316 has 16 neighbors.
# Point 317 has 19 neighbors.
# Point 318 has 8 neighbors.
# Point 319 has 18 neighbors.
# Point 320 has 19 neighbors.
# Point 321 has 6 neighbors.
# Point 322 has 15 neighbors.
# Point 323 has 18 neighbors.
# Point 324 has 12 neighbors.
# Point 325 has 18 neighbors.
# Point 326 has 11 neighbors.
# Point 327 has 19 neighbors.

# %% [markdown]
# ## show image

# %% [markdown]
# # Test data preparation

# %%
test_normal_coords = []
test_slide_edge_indices = {}

# 預先計算每個 slide 的 edge_index 並儲存
with h5py.File("../elucidata_ai_challenge_data.h5", "r") as f:
    test_spots = f["spots/Test"]
    slide_ids = list(test_spots.keys())  # Convert KeysView to a list
    
    for slide_id in slide_ids:
        print(f"Processing slide: {slide_id}")
        
        # Get the spot array for the current slide
        spot_array = np.array(test_spots[slide_id])
        test_spot_table = pd.DataFrame(spot_array)

        # 提取 (x, y) 座標並進行標準化
        coords = test_spot_table[['x', 'y']].values
        scaler = MinMaxScaler()
        coords_normalized = scaler.fit_transform(coords)  # 將座標標準化到 [0, 1] 範圍內
        
        # 儲存標準化後的 (x, y) 座標
        test_spot_table[['x_normalized', 'y_normalized']] = coords_normalized
        test_normal_coords.append(coords_normalized)  # Wrap the values in a tuple

        # 計算原始座標的半徑
        original_radius = 64  # 原始的 radius 值（像素）

        # 計算標準化後的 radius
        min_x, max_x = np.min(coords[:, 0]), np.max(coords[:, 0])
        print(f"min_x: {min_x}, max_x: {max_x}")
        min_y, max_y = np.min(coords[:, 1]), np.max(coords[:, 1])
        print(f"min_y: {min_y}, max_y: {max_y}")

        # 計算標準化後的半徑
        normalized_radius_x = original_radius / (max_x - min_x)
        normalized_radius_y = original_radius / (max_y - min_y)
        print(f"normalized_radius_x: {normalized_radius_x}, normalized_radius_y: {normalized_radius_y}")
        
        # 你可以選擇平均這兩個來得到一個統一的標準化半徑
        normalized_radius = (normalized_radius_x + normalized_radius_y) / 2

        # 計算 `edge_index` 並儲存
        edge_index = compute_edge_index(coords_normalized, radius=normalized_radius)
        test_slide_edge_indices[slide_id] = edge_index

# 顯示更新後的 `test_slide_edge_indices`
test_slide_edge_indices
# Out:
# Processing slide: S_7
# min_x: 380, max_x: 1639
# min_y: 440, max_y: 1769
# normalized_radius_x: 0.050833995234312944, normalized_radius_y: 0.04815650865312265
# Point 0 has 18 neighbors.
# Point 1 has 19 neighbors.
# Point 2 has 19 neighbors.
# Point 3 has 19 neighbors.
# Point 4 has 19 neighbors.
# Point 5 has 17 neighbors.
# Point 6 has 19 neighbors.
# Point 7 has 16 neighbors.
# Point 8 has 19 neighbors.
# Point 9 has 19 neighbors.
# Point 10 has 19 neighbors.
# Point 11 has 7 neighbors.
# Point 12 has 16 neighbors.
# Point 13 has 19 neighbors.
# Point 14 has 19 neighbors.
# Point 15 has 16 neighbors.
# Point 16 has 19 neighbors.
# Point 17 has 18 neighbors.
# Point 18 has 19 neighbors.
# Point 19 has 19 neighbors.
# Point 20 has 19 neighbors.
# Point 21 has 19 neighbors.
# Point 22 has 19 neighbors.
# Point 23 has 18 neighbors.
# Point 24 has 19 neighbors.
# Point 25 has 19 neighbors.
# Point 26 has 19 neighbors.
# Point 27 has 12 neighbors.
# Point 28 has 19 neighbors.
# Point 29 has 19 neighbors.
# Point 30 has 19 neighbors.
# Point 31 has 6 neighbors.
# Point 32 has 19 neighbors.
# Point 33 has 19 neighbors.
# Point 34 has 18 neighbors.
# Point 35 has 19 neighbors.
# Point 36 has 19 neighbors.
# Point 37 has 19 neighbors.
# Point 38 has 19 neighbors.
# Point 39 has 19 neighbors.
# Point 40 has 19 neighbors.
# Point 41 has 15 neighbors.
# Point 42 has 19 neighbors.
# Point 43 has 18 neighbors.
# Point 44 has 11 neighbors.
# Point 45 has 19 neighbors.
# Point 46 has 19 neighbors.
# Point 47 has 19 neighbors.
# Point 48 has 19 neighbors.
# Point 49 has 19 neighbors.
# Point 50 has 19 neighbors.
# Point 51 has 19 neighbors.
# Point 52 has 19 neighbors.
# Point 53 has 19 neighbors.
# Point 54 has 19 neighbors.
# Point 55 has 19 neighbors.
# Point 56 has 11 neighbors.
# Point 57 has 19 neighbors.
# Point 58 has 19 neighbors.
# Point 59 has 19 neighbors.
# Point 60 has 19 neighbors.
# Point 61 has 19 neighbors.
# Point 62 has 19 neighbors.
# Point 63 has 19 neighbors.
# Point 64 has 19 neighbors.
# Point 65 has 17 neighbors.
# Point 66 has 19 neighbors.
# Point 67 has 19 neighbors.
# Point 68 has 19 neighbors.
# Point 69 has 19 neighbors.
# Point 70 has 19 neighbors.
# Point 71 has 11 neighbors.
# Point 72 has 19 neighbors.
# Point 73 has 19 neighbors.
# Point 74 has 19 neighbors.
# Point 75 has 19 neighbors.
# Point 76 has 19 neighbors.
# Point 77 has 19 neighbors.
# Point 78 has 19 neighbors.
# Point 79 has 10 neighbors.
# Point 80 has 17 neighbors.
# Point 81 has 18 neighbors.
# Point 82 has 13 neighbors.
# Point 83 has 18 neighbors.
# Point 84 has 19 neighbors.
# Point 85 has 19 neighbors.
# Point 86 has 11 neighbors.
# Point 87 has 19 neighbors.
# Point 88 has 19 neighbors.
# Point 89 has 19 neighbors.
# Point 90 has 19 neighbors.
# Point 91 has 19 neighbors.
# Point 92 has 19 neighbors.
# Point 93 has 19 neighbors.
# Point 94 has 16 neighbors.
# Point 95 has 19 neighbors.
# Point 96 has 18 neighbors.
# Point 97 has 19 neighbors.
# Point 98 has 11 neighbors.
# Point 99 has 19 neighbors.
# Point 100 has 19 neighbors.
# Point 101 has 19 neighbors.
# Point 102 has 19 neighbors.
# Point 103 has 19 neighbors.
# Point 104 has 19 neighbors.
# Point 105 has 19 neighbors.
# Point 106 has 19 neighbors.
# Point 107 has 19 neighbors.
# Point 108 has 16 neighbors.
# Point 109 has 10 neighbors.
# Point 110 has 19 neighbors.
# Point 111 has 19 neighbors.
# Point 112 has 19 neighbors.
# Point 113 has 19 neighbors.
# Point 114 has 19 neighbors.
# Point 115 has 19 neighbors.
# Point 116 has 19 neighbors.
# Point 117 has 19 neighbors.
# Point 118 has 19 neighbors.
# Point 119 has 10 neighbors.
# Point 120 has 16 neighbors.
# Point 121 has 19 neighbors.
# Point 122 has 19 neighbors.
# Point 123 has 19 neighbors.
# Point 124 has 16 neighbors.
# Point 125 has 18 neighbors.
# Point 126 has 17 neighbors.
# Point 127 has 19 neighbors.
# Point 128 has 19 neighbors.
# Point 129 has 11 neighbors.
# Point 130 has 16 neighbors.
# Point 131 has 19 neighbors.
# Point 132 has 19 neighbors.
# Point 133 has 18 neighbors.
# Point 134 has 19 neighbors.
# Point 135 has 9 neighbors.
# Point 136 has 19 neighbors.
# Point 137 has 19 neighbors.
# Point 138 has 19 neighbors.
# Point 139 has 19 neighbors.
# Point 140 has 19 neighbors.
# Point 141 has 19 neighbors.
# Point 142 has 17 neighbors.
# Point 143 has 9 neighbors.
# Point 144 has 19 neighbors.
# Point 145 has 19 neighbors.
# Point 146 has 13 neighbors.
# Point 147 has 19 neighbors.
# Point 148 has 15 neighbors.
# Point 149 has 19 neighbors.
# Point 150 has 19 neighbors.
# Point 151 has 19 neighbors.
# Point 152 has 17 neighbors.
# Point 153 has 19 neighbors.
# Point 154 has 11 neighbors.
# Point 155 has 19 neighbors.
# Point 156 has 18 neighbors.
# Point 157 has 19 neighbors.
# Point 158 has 19 neighbors.
# Point 159 has 10 neighbors.
# Point 160 has 18 neighbors.
# Point 161 has 19 neighbors.
# Point 162 has 19 neighbors.
# Point 163 has 19 neighbors.
# Point 164 has 19 neighbors.
# Point 165 has 15 neighbors.
# Point 166 has 19 neighbors.
# Point 167 has 19 neighbors.
# Point 168 has 19 neighbors.
# Point 169 has 19 neighbors.
# Point 170 has 19 neighbors.
# Point 171 has 12 neighbors.
# Point 172 has 19 neighbors.
# Point 173 has 19 neighbors.
# Point 174 has 19 neighbors.
# Point 175 has 16 neighbors.
# Point 176 has 19 neighbors.
# Point 177 has 19 neighbors.
# Point 178 has 11 neighbors.
# Point 179 has 19 neighbors.
# Point 180 has 19 neighbors.
# Point 181 has 18 neighbors.
# Point 182 has 14 neighbors.
# Point 183 has 17 neighbors.
# Point 184 has 16 neighbors.
# Point 185 has 19 neighbors.
# Point 186 has 19 neighbors.
# Point 187 has 19 neighbors.
# Point 188 has 19 neighbors.
# Point 189 has 13 neighbors.
# Point 190 has 19 neighbors.
# Point 191 has 19 neighbors.
# Point 192 has 19 neighbors.
# Point 193 has 19 neighbors.
# Point 194 has 19 neighbors.
# Point 195 has 19 neighbors.
# Point 196 has 19 neighbors.
# Point 197 has 19 neighbors.
# Point 198 has 19 neighbors.
# Point 199 has 19 neighbors.
# Point 200 has 18 neighbors.
# Point 201 has 14 neighbors.
# Point 202 has 19 neighbors.
# Point 203 has 19 neighbors.
# Point 204 has 18 neighbors.
# Point 205 has 19 neighbors.
# Point 206 has 19 neighbors.
# Point 207 has 19 neighbors.
# Point 208 has 19 neighbors.
# Point 209 has 18 neighbors.
# Point 210 has 15 neighbors.
# Point 211 has 19 neighbors.
# Point 212 has 19 neighbors.
# Point 213 has 18 neighbors.
# Point 214 has 19 neighbors.
# Point 215 has 19 neighbors.
# Point 216 has 13 neighbors.
# Point 217 has 19 neighbors.
# Point 218 has 19 neighbors.
# Point 219 has 19 neighbors.
# Point 220 has 19 neighbors.
# Point 221 has 19 neighbors.
# Point 222 has 19 neighbors.
# Point 223 has 19 neighbors.
# Point 224 has 19 neighbors.
# Point 225 has 19 neighbors.
# Point 226 has 19 neighbors.
# Point 227 has 18 neighbors.
# Point 228 has 19 neighbors.
# Point 229 has 19 neighbors.
# Point 230 has 19 neighbors.
# Point 231 has 19 neighbors.
# Point 232 has 19 neighbors.
# Point 233 has 19 neighbors.
# Point 234 has 19 neighbors.
# Point 235 has 15 neighbors.
# Point 236 has 18 neighbors.
# Point 237 has 19 neighbors.
# Point 238 has 19 neighbors.
# Point 239 has 19 neighbors.
# Point 240 has 19 neighbors.
# Point 241 has 19 neighbors.
# Point 242 has 19 neighbors.
# Point 243 has 12 neighbors.
# Point 244 has 19 neighbors.
# Point 245 has 19 neighbors.
# Point 246 has 19 neighbors.
# Point 247 has 19 neighbors.
# Point 248 has 19 neighbors.
# Point 249 has 19 neighbors.
# Point 250 has 11 neighbors.
# Point 251 has 12 neighbors.
# Point 252 has 5 neighbors.
# Point 253 has 12 neighbors.
# Point 254 has 18 neighbors.
# Point 255 has 18 neighbors.
# Point 256 has 19 neighbors.
# Point 257 has 19 neighbors.
# Point 258 has 14 neighbors.
# Point 259 has 19 neighbors.
# Point 260 has 19 neighbors.
# Point 261 has 19 neighbors.
# Point 262 has 19 neighbors.
# Point 263 has 19 neighbors.
# Point 264 has 19 neighbors.
# Point 265 has 19 neighbors.
# Point 266 has 19 neighbors.
# Point 267 has 19 neighbors.
# Point 268 has 19 neighbors.
# Point 269 has 19 neighbors.
# Point 270 has 19 neighbors.
# Point 271 has 19 neighbors.
# Point 272 has 17 neighbors.
# Point 273 has 19 neighbors.
# Point 274 has 17 neighbors.
# Point 275 has 19 neighbors.
# Point 276 has 15 neighbors.
# Point 277 has 18 neighbors.
# Point 278 has 12 neighbors.
# Point 279 has 19 neighbors.
# Point 280 has 19 neighbors.
# Point 281 has 19 neighbors.
# Point 282 has 19 neighbors.
# Point 283 has 19 neighbors.
# Point 284 has 18 neighbors.
# Point 285 has 19 neighbors.
# Point 286 has 19 neighbors.
# Point 287 has 19 neighbors.
# Point 288 has 19 neighbors.
# Point 289 has 19 neighbors.
# Point 290 has 15 neighbors.
# Point 291 has 16 neighbors.
# Point 292 has 19 neighbors.
# Point 293 has 19 neighbors.
# Point 294 has 12 neighbors.
# Point 295 has 18 neighbors.
# Point 296 has 19 neighbors.
# Point 297 has 19 neighbors.
# Point 298 has 19 neighbors.
# Point 299 has 19 neighbors.
# Point 300 has 12 neighbors.
# Point 301 has 19 neighbors.
# Point 302 has 19 neighbors.
# Point 303 has 19 neighbors.
# Point 304 has 19 neighbors.
# Point 305 has 14 neighbors.
# Point 306 has 18 neighbors.
# Point 307 has 19 neighbors.
# Point 308 has 14 neighbors.
# Point 309 has 15 neighbors.
# Point 310 has 18 neighbors.
# Point 311 has 13 neighbors.
# Point 312 has 19 neighbors.
# Point 313 has 11 neighbors.
# Point 314 has 19 neighbors.
# Point 315 has 19 neighbors.
# Point 316 has 19 neighbors.
# Point 317 has 19 neighbors.
# Point 318 has 19 neighbors.
# Point 319 has 19 neighbors.
# Point 320 has 19 neighbors.
# Point 321 has 11 neighbors.
# Point 322 has 16 neighbors.
# Point 323 has 13 neighbors.
# Point 324 has 16 neighbors.
# Point 325 has 17 neighbors.
# Point 326 has 13 neighbors.
# Point 327 has 19 neighbors.
# Point 328 has 19 neighbors.
# Point 329 has 16 neighbors.
# Point 330 has 8 neighbors.
# Point 331 has 19 neighbors.
# Point 332 has 19 neighbors.
# Point 333 has 16 neighbors.
# Point 334 has 9 neighbors.
# Point 335 has 19 neighbors.
# Point 336 has 19 neighbors.
# Point 337 has 19 neighbors.
# Point 338 has 19 neighbors.
# Point 339 has 16 neighbors.
# Point 340 has 18 neighbors.
# Point 341 has 19 neighbors.
# Point 342 has 19 neighbors.
# Point 343 has 19 neighbors.
# Point 344 has 19 neighbors.
# Point 345 has 15 neighbors.
# Point 346 has 19 neighbors.
# Point 347 has 19 neighbors.
# Point 348 has 15 neighbors.
# Point 349 has 19 neighbors.
# Point 350 has 19 neighbors.
# Point 351 has 18 neighbors.
# Point 352 has 18 neighbors.
# Point 353 has 19 neighbors.
# Point 354 has 19 neighbors.
# Point 355 has 19 neighbors.
# Point 356 has 19 neighbors.
# Point 357 has 16 neighbors.
# Point 358 has 19 neighbors.
# Point 359 has 19 neighbors.
# Point 360 has 19 neighbors.
# Point 361 has 19 neighbors.
# Point 362 has 11 neighbors.
# Point 363 has 19 neighbors.
# Point 364 has 19 neighbors.
# Point 365 has 19 neighbors.
# Point 366 has 19 neighbors.
# Point 367 has 18 neighbors.
# Point 368 has 19 neighbors.
# Point 369 has 19 neighbors.
# Point 370 has 10 neighbors.
# Point 371 has 19 neighbors.
# Point 372 has 19 neighbors.
# Point 373 has 19 neighbors.
# Point 374 has 19 neighbors.
# Point 375 has 19 neighbors.
# Point 376 has 18 neighbors.
# Point 377 has 16 neighbors.
# Point 378 has 19 neighbors.
# Point 379 has 19 neighbors.
# Point 380 has 10 neighbors.
# Point 381 has 19 neighbors.
# Point 382 has 19 neighbors.
# Point 383 has 19 neighbors.
# Point 384 has 19 neighbors.
# Point 385 has 19 neighbors.
# Point 386 has 19 neighbors.
# Point 387 has 19 neighbors.
# Point 388 has 19 neighbors.
# Point 389 has 19 neighbors.
# Point 390 has 19 neighbors.
# Point 391 has 14 neighbors.
# Point 392 has 12 neighbors.
# Point 393 has 19 neighbors.
# Point 394 has 19 neighbors.
# Point 395 has 19 neighbors.
# Point 396 has 19 neighbors.
# Point 397 has 19 neighbors.
# Point 398 has 19 neighbors.
# Point 399 has 19 neighbors.
# Point 400 has 19 neighbors.
# Point 401 has 19 neighbors.
# Point 402 has 19 neighbors.
# Point 403 has 19 neighbors.
# Point 404 has 19 neighbors.
# Point 405 has 19 neighbors.
# Point 406 has 19 neighbors.
# Point 407 has 14 neighbors.
# Point 408 has 19 neighbors.
# Point 409 has 10 neighbors.
# Point 410 has 18 neighbors.
# Point 411 has 19 neighbors.
# Point 412 has 19 neighbors.
# Point 413 has 19 neighbors.
# Point 414 has 19 neighbors.
# Point 415 has 19 neighbors.
# Point 416 has 15 neighbors.
# Point 417 has 19 neighbors.
# Point 418 has 19 neighbors.
# Point 419 has 19 neighbors.
# Point 420 has 14 neighbors.
# Point 421 has 19 neighbors.
# Point 422 has 19 neighbors.
# Point 423 has 19 neighbors.
# Point 424 has 16 neighbors.
# Point 425 has 19 neighbors.
# Point 426 has 19 neighbors.
# Point 427 has 19 neighbors.
# Point 428 has 19 neighbors.
# Point 429 has 19 neighbors.
# Point 430 has 18 neighbors.
# Point 431 has 19 neighbors.
# Point 432 has 19 neighbors.
# Point 433 has 19 neighbors.
# Point 434 has 15 neighbors.
# Point 435 has 19 neighbors.
# Point 436 has 19 neighbors.
# Point 437 has 19 neighbors.
# Point 438 has 19 neighbors.
# Point 439 has 19 neighbors.
# Point 440 has 19 neighbors.
# Point 441 has 16 neighbors.
# Point 442 has 19 neighbors.
# Point 443 has 19 neighbors.
# Point 444 has 17 neighbors.
# Point 445 has 19 neighbors.
# Point 446 has 15 neighbors.
# Point 447 has 17 neighbors.
# Point 448 has 13 neighbors.
# Point 449 has 18 neighbors.
# Point 450 has 19 neighbors.
# Point 451 has 19 neighbors.
# Point 452 has 19 neighbors.
# Point 453 has 10 neighbors.
# Point 454 has 19 neighbors.
# Point 455 has 12 neighbors.
# Point 456 has 19 neighbors.
# Point 457 has 9 neighbors.
# Point 458 has 19 neighbors.
# Point 459 has 19 neighbors.
# Point 460 has 19 neighbors.
# Point 461 has 18 neighbors.
# Point 462 has 19 neighbors.
# Point 463 has 19 neighbors.
# Point 464 has 19 neighbors.
# Point 465 has 19 neighbors.
# Point 466 has 19 neighbors.
# Point 467 has 18 neighbors.
# Point 468 has 19 neighbors.
# Point 469 has 18 neighbors.
# Point 470 has 19 neighbors.
# Point 471 has 19 neighbors.
# Point 472 has 14 neighbors.
# Point 473 has 19 neighbors.
# Point 474 has 19 neighbors.
# Point 475 has 12 neighbors.
# Point 476 has 19 neighbors.
# Point 477 has 18 neighbors.
# Point 478 has 19 neighbors.
# Point 479 has 17 neighbors.
# Point 480 has 19 neighbors.
# Point 481 has 5 neighbors.
# Point 482 has 18 neighbors.
# Point 483 has 19 neighbors.
# Point 484 has 18 neighbors.
# Point 485 has 19 neighbors.
# Point 486 has 16 neighbors.
# Point 487 has 19 neighbors.
# Point 488 has 19 neighbors.
# Point 489 has 19 neighbors.
# Point 490 has 14 neighbors.
# Point 491 has 18 neighbors.
# Point 492 has 19 neighbors.
# Point 493 has 16 neighbors.
# Point 494 has 16 neighbors.
# Point 495 has 15 neighbors.
# Point 496 has 19 neighbors.
# Point 497 has 19 neighbors.
# Point 498 has 19 neighbors.
# Point 499 has 17 neighbors.
# Point 500 has 19 neighbors.
# Point 501 has 19 neighbors.
# Point 502 has 19 neighbors.
# Point 503 has 19 neighbors.
# Point 504 has 19 neighbors.
# Point 505 has 19 neighbors.
# Point 506 has 19 neighbors.
# Point 507 has 18 neighbors.
# Point 508 has 19 neighbors.
# Point 509 has 13 neighbors.
# Point 510 has 16 neighbors.
# Point 511 has 11 neighbors.
# Point 512 has 19 neighbors.
# Point 513 has 19 neighbors.
# Point 514 has 13 neighbors.
# Point 515 has 16 neighbors.
# Point 516 has 19 neighbors.
# Point 517 has 19 neighbors.
# Point 518 has 8 neighbors.
# Point 519 has 7 neighbors.
# Point 520 has 15 neighbors.
# Point 521 has 19 neighbors.
# Point 522 has 16 neighbors.
# Point 523 has 19 neighbors.
# Point 524 has 19 neighbors.
# Point 525 has 19 neighbors.
# Point 526 has 19 neighbors.
# Point 527 has 18 neighbors.
# Point 528 has 19 neighbors.
# Point 529 has 14 neighbors.
# Point 530 has 19 neighbors.
# Point 531 has 19 neighbors.
# Point 532 has 11 neighbors.
# Point 533 has 8 neighbors.
# Point 534 has 19 neighbors.
# Point 535 has 19 neighbors.
# Point 536 has 17 neighbors.
# Point 537 has 10 neighbors.
# Point 538 has 19 neighbors.
# Point 539 has 19 neighbors.
# Point 540 has 19 neighbors.
# Point 541 has 19 neighbors.
# Point 542 has 19 neighbors.
# Point 543 has 19 neighbors.
# Point 544 has 19 neighbors.
# Point 545 has 17 neighbors.
# Point 546 has 19 neighbors.
# Point 547 has 7 neighbors.
# Point 548 has 18 neighbors.
# Point 549 has 19 neighbors.
# Point 550 has 19 neighbors.
# Point 551 has 14 neighbors.
# Point 552 has 19 neighbors.
# Point 553 has 19 neighbors.
# Point 554 has 19 neighbors.
# Point 555 has 18 neighbors.
# Point 556 has 19 neighbors.
# Point 557 has 19 neighbors.
# Point 558 has 19 neighbors.
# Point 559 has 18 neighbors.
# Point 560 has 19 neighbors.
# Point 561 has 18 neighbors.
# Point 562 has 8 neighbors.
# Point 563 has 19 neighbors.
# Point 564 has 13 neighbors.
# Point 565 has 13 neighbors.
# Point 566 has 19 neighbors.
# Point 567 has 19 neighbors.
# Point 568 has 17 neighbors.
# Point 569 has 19 neighbors.
# Point 570 has 19 neighbors.
# Point 571 has 19 neighbors.
# Point 572 has 19 neighbors.
# Point 573 has 13 neighbors.
# Point 574 has 19 neighbors.
# Point 575 has 18 neighbors.
# Point 576 has 15 neighbors.
# Point 577 has 19 neighbors.
# Point 578 has 19 neighbors.
# Point 579 has 15 neighbors.
# Point 580 has 19 neighbors.
# Point 581 has 6 neighbors.
# Point 582 has 19 neighbors.
# Point 583 has 19 neighbors.
# Point 584 has 19 neighbors.
# Point 585 has 19 neighbors.
# Point 586 has 19 neighbors.
# Point 587 has 19 neighbors.
# Point 588 has 19 neighbors.
# Point 589 has 19 neighbors.
# Point 590 has 18 neighbors.
# Point 591 has 19 neighbors.
# Point 592 has 19 neighbors.
# Point 593 has 19 neighbors.
# Point 594 has 19 neighbors.
# Point 595 has 19 neighbors.
# Point 596 has 16 neighbors.
# Point 597 has 11 neighbors.
# Point 598 has 19 neighbors.
# Point 599 has 19 neighbors.
# Point 600 has 19 neighbors.
# Point 601 has 19 neighbors.
# Point 602 has 16 neighbors.
# Point 603 has 5 neighbors.
# Point 604 has 19 neighbors.
# Point 605 has 19 neighbors.
# Point 606 has 19 neighbors.
# Point 607 has 19 neighbors.
# Point 608 has 19 neighbors.
# Point 609 has 17 neighbors.
# Point 610 has 19 neighbors.
# Point 611 has 19 neighbors.
# Point 612 has 19 neighbors.
# Point 613 has 19 neighbors.
# Point 614 has 19 neighbors.
# Point 615 has 19 neighbors.
# Point 616 has 19 neighbors.
# Point 617 has 19 neighbors.
# Point 618 has 8 neighbors.
# Point 619 has 19 neighbors.
# Point 620 has 19 neighbors.
# Point 621 has 19 neighbors.
# Point 622 has 15 neighbors.
# Point 623 has 19 neighbors.
# Point 624 has 12 neighbors.
# Point 625 has 19 neighbors.
# Point 626 has 11 neighbors.
# Point 627 has 19 neighbors.
# Point 628 has 19 neighbors.
# Point 629 has 16 neighbors.
# Point 630 has 19 neighbors.
# Point 631 has 12 neighbors.
# Point 632 has 19 neighbors.
# Point 633 has 14 neighbors.
# Point 634 has 19 neighbors.
# Point 635 has 18 neighbors.
# Point 636 has 11 neighbors.
# Point 637 has 19 neighbors.
# Point 638 has 15 neighbors.
# Point 639 has 11 neighbors.
# Point 640 has 19 neighbors.
# Point 641 has 19 neighbors.
# Point 642 has 19 neighbors.
# Point 643 has 19 neighbors.
# Point 644 has 19 neighbors.
# Point 645 has 19 neighbors.
# Point 646 has 19 neighbors.
# Point 647 has 19 neighbors.
# Point 648 has 19 neighbors.
# Point 649 has 19 neighbors.
# Point 650 has 13 neighbors.
# Point 651 has 19 neighbors.
# Point 652 has 19 neighbors.
# Point 653 has 15 neighbors.
# Point 654 has 19 neighbors.
# Point 655 has 19 neighbors.
# Point 656 has 16 neighbors.
# Point 657 has 19 neighbors.
# Point 658 has 19 neighbors.
# Point 659 has 19 neighbors.
# Point 660 has 19 neighbors.
# Point 661 has 19 neighbors.
# Point 662 has 19 neighbors.
# Point 663 has 18 neighbors.
# Point 664 has 18 neighbors.
# Point 665 has 11 neighbors.
# Point 666 has 19 neighbors.
# Point 667 has 12 neighbors.
# Point 668 has 19 neighbors.
# Point 669 has 19 neighbors.
# Point 670 has 19 neighbors.
# Point 671 has 19 neighbors.
# Point 672 has 19 neighbors.
# Point 673 has 10 neighbors.
# Point 674 has 19 neighbors.
# Point 675 has 19 neighbors.
# Point 676 has 19 neighbors.
# Point 677 has 19 neighbors.
# Point 678 has 18 neighbors.
# Point 679 has 18 neighbors.
# Point 680 has 14 neighbors.
# Point 681 has 19 neighbors.
# Point 682 has 19 neighbors.
# Point 683 has 17 neighbors.
# Point 684 has 19 neighbors.
# Point 685 has 19 neighbors.
# Point 686 has 18 neighbors.
# Point 687 has 19 neighbors.
# Point 688 has 15 neighbors.
# Point 689 has 19 neighbors.
# Point 690 has 19 neighbors.
# Point 691 has 19 neighbors.
# Point 692 has 8 neighbors.
# Point 693 has 19 neighbors.
# Point 694 has 16 neighbors.
# Point 695 has 19 neighbors.
# Point 696 has 17 neighbors.
# Point 697 has 18 neighbors.
# Point 698 has 19 neighbors.
# Point 699 has 19 neighbors.
# Point 700 has 18 neighbors.
# Point 701 has 19 neighbors.
# Point 702 has 19 neighbors.
# Point 703 has 19 neighbors.
# Point 704 has 16 neighbors.
# Point 705 has 19 neighbors.
# Point 706 has 17 neighbors.
# Point 707 has 17 neighbors.
# Point 708 has 12 neighbors.
# Point 709 has 18 neighbors.
# Point 710 has 19 neighbors.
# Point 711 has 19 neighbors.
# Point 712 has 16 neighbors.
# Point 713 has 9 neighbors.
# Point 714 has 19 neighbors.
# Point 715 has 18 neighbors.
# Point 716 has 19 neighbors.
# Point 717 has 19 neighbors.
# Point 718 has 19 neighbors.
# Point 719 has 14 neighbors.
# Point 720 has 13 neighbors.
# Point 721 has 19 neighbors.
# Point 722 has 15 neighbors.
# Point 723 has 18 neighbors.
# Point 724 has 19 neighbors.
# Point 725 has 19 neighbors.
# Point 726 has 19 neighbors.
# Point 727 has 9 neighbors.
# Point 728 has 17 neighbors.
# Point 729 has 19 neighbors.
# Point 730 has 18 neighbors.
# Point 731 has 19 neighbors.
# Point 732 has 16 neighbors.
# Point 733 has 19 neighbors.
# Point 734 has 18 neighbors.
# Point 735 has 16 neighbors.
# Point 736 has 12 neighbors.
# Point 737 has 12 neighbors.
# Point 738 has 19 neighbors.
# Point 739 has 19 neighbors.
# Point 740 has 19 neighbors.
# Point 741 has 19 neighbors.
# Point 742 has 19 neighbors.
# Point 743 has 19 neighbors.
# Point 744 has 19 neighbors.
# Point 745 has 13 neighbors.
# Point 746 has 19 neighbors.
# Point 747 has 18 neighbors.
# Point 748 has 19 neighbors.
# Point 749 has 19 neighbors.
# Point 750 has 12 neighbors.
# Point 751 has 13 neighbors.
# Point 752 has 19 neighbors.
# Point 753 has 16 neighbors.
# Point 754 has 19 neighbors.
# Point 755 has 18 neighbors.
# Point 756 has 19 neighbors.
# Point 757 has 16 neighbors.
# Point 758 has 19 neighbors.
# Point 759 has 19 neighbors.
# Point 760 has 19 neighbors.
# Point 761 has 19 neighbors.
# Point 762 has 12 neighbors.
# Point 763 has 19 neighbors.
# Point 764 has 18 neighbors.
# Point 765 has 19 neighbors.
# Point 766 has 19 neighbors.
# Point 767 has 19 neighbors.
# Point 768 has 19 neighbors.
# Point 769 has 19 neighbors.
# Point 770 has 18 neighbors.
# Point 771 has 19 neighbors.
# Point 772 has 19 neighbors.
# Point 773 has 19 neighbors.
# Point 774 has 18 neighbors.
# Point 775 has 17 neighbors.
# Point 776 has 14 neighbors.
# Point 777 has 11 neighbors.
# Point 778 has 18 neighbors.
# Point 779 has 19 neighbors.
# Point 780 has 19 neighbors.
# Point 781 has 19 neighbors.
# Point 782 has 19 neighbors.
# Point 783 has 13 neighbors.
# Point 784 has 19 neighbors.
# Point 785 has 19 neighbors.
# Point 786 has 19 neighbors.
# Point 787 has 18 neighbors.
# Point 788 has 19 neighbors.
# Point 789 has 13 neighbors.
# Point 790 has 19 neighbors.
# Point 791 has 19 neighbors.
# Point 792 has 19 neighbors.
# Point 793 has 13 neighbors.
# Point 794 has 19 neighbors.
# Point 795 has 19 neighbors.
# Point 796 has 19 neighbors.
# Point 797 has 19 neighbors.
# Point 798 has 10 neighbors.
# Point 799 has 19 neighbors.
# Point 800 has 19 neighbors.
# Point 801 has 19 neighbors.
# Point 802 has 19 neighbors.
# Point 803 has 6 neighbors.
# Point 804 has 19 neighbors.
# Point 805 has 13 neighbors.
# Point 806 has 19 neighbors.
# Point 807 has 19 neighbors.
# Point 808 has 19 neighbors.
# Point 809 has 19 neighbors.
# Point 810 has 19 neighbors.
# Point 811 has 19 neighbors.
# Point 812 has 18 neighbors.
# Point 813 has 19 neighbors.
# Point 814 has 19 neighbors.
# Point 815 has 19 neighbors.
# Point 816 has 19 neighbors.
# Point 817 has 19 neighbors.
# Point 818 has 10 neighbors.
# Point 819 has 19 neighbors.
# Point 820 has 17 neighbors.
# Point 821 has 19 neighbors.
# Point 822 has 11 neighbors.
# Point 823 has 19 neighbors.
# Point 824 has 19 neighbors.
# Point 825 has 19 neighbors.
# Point 826 has 14 neighbors.
# Point 827 has 19 neighbors.
# Point 828 has 19 neighbors.
# Point 829 has 19 neighbors.
# Point 830 has 17 neighbors.
# Point 831 has 19 neighbors.
# Point 832 has 8 neighbors.
# Point 833 has 19 neighbors.
# Point 834 has 19 neighbors.
# Point 835 has 19 neighbors.
# Point 836 has 12 neighbors.
# Point 837 has 13 neighbors.
# Point 838 has 19 neighbors.
# Point 839 has 19 neighbors.
# Point 840 has 10 neighbors.
# Point 841 has 19 neighbors.
# Point 842 has 19 neighbors.
# Point 843 has 8 neighbors.
# Point 844 has 19 neighbors.
# Point 845 has 19 neighbors.
# Point 846 has 19 neighbors.
# Point 847 has 16 neighbors.
# Point 848 has 19 neighbors.
# Point 849 has 16 neighbors.
# Point 850 has 19 neighbors.
# Point 851 has 19 neighbors.
# Point 852 has 19 neighbors.
# Point 853 has 19 neighbors.
# Point 854 has 15 neighbors.
# Point 855 has 19 neighbors.
# Point 856 has 19 neighbors.
# Point 857 has 11 neighbors.
# Point 858 has 18 neighbors.
# Point 859 has 13 neighbors.
# Point 860 has 17 neighbors.
# Point 861 has 19 neighbors.
# Point 862 has 19 neighbors.
# Point 863 has 18 neighbors.
# Point 864 has 19 neighbors.
# Point 865 has 19 neighbors.
# Point 866 has 19 neighbors.
# Point 867 has 19 neighbors.
# Point 868 has 19 neighbors.
# Point 869 has 19 neighbors.
# Point 870 has 19 neighbors.
# Point 871 has 13 neighbors.
# Point 872 has 18 neighbors.
# Point 873 has 19 neighbors.
# Point 874 has 19 neighbors.
# Point 875 has 12 neighbors.
# Point 876 has 19 neighbors.
# Point 877 has 19 neighbors.
# Point 878 has 19 neighbors.
# Point 879 has 19 neighbors.
# Point 880 has 19 neighbors.
# Point 881 has 19 neighbors.
# Point 882 has 19 neighbors.
# Point 883 has 19 neighbors.
# Point 884 has 19 neighbors.
# Point 885 has 19 neighbors.
# Point 886 has 19 neighbors.
# Point 887 has 16 neighbors.
# Point 888 has 19 neighbors.
# Point 889 has 19 neighbors.
# Point 890 has 19 neighbors.
# Point 891 has 17 neighbors.
# Point 892 has 19 neighbors.
# Point 893 has 11 neighbors.
# Point 894 has 19 neighbors.
# Point 895 has 19 neighbors.
# Point 896 has 19 neighbors.
# Point 897 has 19 neighbors.
# Point 898 has 19 neighbors.
# Point 899 has 16 neighbors.
# Point 900 has 13 neighbors.
# Point 901 has 19 neighbors.
# Point 902 has 16 neighbors.
# Point 903 has 19 neighbors.
# Point 904 has 19 neighbors.
# Point 905 has 15 neighbors.
# Point 906 has 19 neighbors.
# Point 907 has 14 neighbors.
# Point 908 has 19 neighbors.
# Point 909 has 19 neighbors.
# Point 910 has 15 neighbors.
# Point 911 has 14 neighbors.
# Point 912 has 8 neighbors.
# Point 913 has 19 neighbors.
# Point 914 has 19 neighbors.
# Point 915 has 19 neighbors.
# Point 916 has 19 neighbors.
# Point 917 has 12 neighbors.
# Point 918 has 19 neighbors.
# Point 919 has 19 neighbors.
# Point 920 has 19 neighbors.
# Point 921 has 19 neighbors.
# Point 922 has 19 neighbors.
# Point 923 has 19 neighbors.
# Point 924 has 19 neighbors.
# Point 925 has 19 neighbors.
# Point 926 has 19 neighbors.
# Point 927 has 19 neighbors.
# Point 928 has 11 neighbors.
# Point 929 has 19 neighbors.
# Point 930 has 19 neighbors.
# Point 931 has 19 neighbors.
# Point 932 has 19 neighbors.
# Point 933 has 19 neighbors.
# Point 934 has 19 neighbors.
# Point 935 has 18 neighbors.
# Point 936 has 19 neighbors.
# Point 937 has 19 neighbors.
# Point 938 has 15 neighbors.
# Point 939 has 19 neighbors.
# Point 940 has 19 neighbors.
# Point 941 has 19 neighbors.
# Point 942 has 19 neighbors.
# Point 943 has 19 neighbors.
# Point 944 has 12 neighbors.
# Point 945 has 19 neighbors.
# Point 946 has 15 neighbors.
# Point 947 has 19 neighbors.
# Point 948 has 16 neighbors.
# Point 949 has 19 neighbors.
# Point 950 has 19 neighbors.
# Point 951 has 19 neighbors.
# Point 952 has 19 neighbors.
# Point 953 has 19 neighbors.
# Point 954 has 19 neighbors.
# Point 955 has 18 neighbors.
# Point 956 has 18 neighbors.
# Point 957 has 18 neighbors.
# Point 958 has 12 neighbors.
# Point 959 has 19 neighbors.
# Point 960 has 19 neighbors.
# Point 961 has 19 neighbors.
# Point 962 has 19 neighbors.
# Point 963 has 18 neighbors.
# Point 964 has 19 neighbors.
# Point 965 has 12 neighbors.
# Point 966 has 19 neighbors.
# Point 967 has 13 neighbors.
# Point 968 has 18 neighbors.
# Point 969 has 6 neighbors.
# Point 970 has 19 neighbors.
# Point 971 has 17 neighbors.
# Point 972 has 19 neighbors.
# Point 973 has 19 neighbors.
# Point 974 has 19 neighbors.
# Point 975 has 19 neighbors.
# Point 976 has 18 neighbors.
# Point 977 has 16 neighbors.
# Point 978 has 15 neighbors.
# Point 979 has 19 neighbors.
# Point 980 has 19 neighbors.
# Point 981 has 19 neighbors.
# Point 982 has 19 neighbors.
# Point 983 has 19 neighbors.
# Point 984 has 16 neighbors.
# Point 985 has 18 neighbors.
# Point 986 has 19 neighbors.
# Point 987 has 19 neighbors.
# Point 988 has 18 neighbors.
# Point 989 has 19 neighbors.
# Point 990 has 19 neighbors.
# Point 991 has 19 neighbors.
# Point 992 has 19 neighbors.
# Point 993 has 19 neighbors.
# Point 994 has 19 neighbors.
# Point 995 has 19 neighbors.
# Point 996 has 15 neighbors.
# Point 997 has 19 neighbors.
# Point 998 has 19 neighbors.
# Point 999 has 19 neighbors.
# Point 1000 has 19 neighbors.
# Point 1001 has 19 neighbors.
# Point 1002 has 19 neighbors.
# Point 1003 has 17 neighbors.
# Point 1004 has 19 neighbors.
# Point 1005 has 18 neighbors.
# Point 1006 has 19 neighbors.
# Point 1007 has 19 neighbors.
# Point 1008 has 19 neighbors.
# Point 1009 has 19 neighbors.
# Point 1010 has 19 neighbors.
# Point 1011 has 19 neighbors.
# Point 1012 has 19 neighbors.
# Point 1013 has 19 neighbors.
# Point 1014 has 19 neighbors.
# Point 1015 has 19 neighbors.
# Point 1016 has 18 neighbors.
# Point 1017 has 19 neighbors.
# Point 1018 has 19 neighbors.
# Point 1019 has 18 neighbors.
# Point 1020 has 19 neighbors.
# Point 1021 has 19 neighbors.
# Point 1022 has 19 neighbors.
# Point 1023 has 19 neighbors.
# Point 1024 has 19 neighbors.
# Point 1025 has 19 neighbors.
# Point 1026 has 19 neighbors.
# Point 1027 has 19 neighbors.
# Point 1028 has 19 neighbors.
# Point 1029 has 17 neighbors.
# Point 1030 has 12 neighbors.
# Point 1031 has 18 neighbors.
# Point 1032 has 19 neighbors.
# Point 1033 has 19 neighbors.
# Point 1034 has 16 neighbors.
# Point 1035 has 19 neighbors.
# Point 1036 has 19 neighbors.
# Point 1037 has 17 neighbors.
# Point 1038 has 17 neighbors.
# Point 1039 has 18 neighbors.
# Point 1040 has 19 neighbors.
# Point 1041 has 12 neighbors.
# Point 1042 has 10 neighbors.
# Point 1043 has 19 neighbors.
# Point 1044 has 19 neighbors.
# Point 1045 has 19 neighbors.
# Point 1046 has 19 neighbors.
# Point 1047 has 19 neighbors.
# Point 1048 has 19 neighbors.
# Point 1049 has 19 neighbors.
# Point 1050 has 16 neighbors.
# Point 1051 has 15 neighbors.
# Point 1052 has 19 neighbors.
# Point 1053 has 19 neighbors.
# Point 1054 has 19 neighbors.
# Point 1055 has 13 neighbors.
# Point 1056 has 19 neighbors.
# Point 1057 has 19 neighbors.
# Point 1058 has 18 neighbors.
# Point 1059 has 19 neighbors.
# Point 1060 has 19 neighbors.
# Point 1061 has 19 neighbors.
# Point 1062 has 19 neighbors.
# Point 1063 has 19 neighbors.
# Point 1064 has 19 neighbors.
# Point 1065 has 19 neighbors.
# Point 1066 has 19 neighbors.
# Point 1067 has 19 neighbors.
# Point 1068 has 19 neighbors.
# Point 1069 has 8 neighbors.
# Point 1070 has 16 neighbors.
# Point 1071 has 19 neighbors.
# Point 1072 has 14 neighbors.
# Point 1073 has 19 neighbors.
# Point 1074 has 19 neighbors.
# Point 1075 has 10 neighbors.
# Point 1076 has 19 neighbors.
# Point 1077 has 19 neighbors.
# Point 1078 has 19 neighbors.
# Point 1079 has 19 neighbors.
# Point 1080 has 11 neighbors.
# Point 1081 has 19 neighbors.
# Point 1082 has 19 neighbors.
# Point 1083 has 17 neighbors.
# Point 1084 has 19 neighbors.
# Point 1085 has 19 neighbors.
# Point 1086 has 19 neighbors.
# Point 1087 has 15 neighbors.
# Point 1088 has 19 neighbors.
# Point 1089 has 17 neighbors.
# Point 1090 has 12 neighbors.
# Point 1091 has 18 neighbors.
# Point 1092 has 17 neighbors.
# Point 1093 has 19 neighbors.
# Point 1094 has 19 neighbors.
# Point 1095 has 19 neighbors.
# Point 1096 has 19 neighbors.
# Point 1097 has 19 neighbors.
# Point 1098 has 18 neighbors.
# Point 1099 has 19 neighbors.
# Point 1100 has 19 neighbors.
# Point 1101 has 18 neighbors.
# Point 1102 has 19 neighbors.
# Point 1103 has 19 neighbors.
# Point 1104 has 19 neighbors.
# Point 1105 has 18 neighbors.
# Point 1106 has 19 neighbors.
# Point 1107 has 19 neighbors.
# Point 1108 has 19 neighbors.
# Point 1109 has 19 neighbors.
# Point 1110 has 17 neighbors.
# Point 1111 has 19 neighbors.
# Point 1112 has 19 neighbors.
# Point 1113 has 11 neighbors.
# Point 1114 has 13 neighbors.
# Point 1115 has 19 neighbors.
# Point 1116 has 19 neighbors.
# Point 1117 has 17 neighbors.
# Point 1118 has 19 neighbors.
# Point 1119 has 19 neighbors.
# Point 1120 has 19 neighbors.
# Point 1121 has 19 neighbors.
# Point 1122 has 19 neighbors.
# Point 1123 has 19 neighbors.
# Point 1124 has 19 neighbors.
# Point 1125 has 19 neighbors.
# Point 1126 has 19 neighbors.
# Point 1127 has 18 neighbors.
# Point 1128 has 19 neighbors.
# Point 1129 has 19 neighbors.
# Point 1130 has 19 neighbors.
# Point 1131 has 17 neighbors.
# Point 1132 has 19 neighbors.
# Point 1133 has 10 neighbors.
# Point 1134 has 19 neighbors.
# Point 1135 has 19 neighbors.
# Point 1136 has 19 neighbors.
# Point 1137 has 19 neighbors.
# Point 1138 has 19 neighbors.
# Point 1139 has 19 neighbors.
# Point 1140 has 19 neighbors.
# Point 1141 has 19 neighbors.
# Point 1142 has 19 neighbors.
# Point 1143 has 19 neighbors.
# Point 1144 has 19 neighbors.
# Point 1145 has 19 neighbors.
# Point 1146 has 19 neighbors.
# Point 1147 has 19 neighbors.
# Point 1148 has 16 neighbors.
# Point 1149 has 19 neighbors.
# Point 1150 has 19 neighbors.
# Point 1151 has 19 neighbors.
# Point 1152 has 19 neighbors.
# Point 1153 has 19 neighbors.
# Point 1154 has 19 neighbors.
# Point 1155 has 19 neighbors.
# Point 1156 has 19 neighbors.
# Point 1157 has 19 neighbors.
# Point 1158 has 17 neighbors.
# Point 1159 has 17 neighbors.
# Point 1160 has 19 neighbors.
# Point 1161 has 19 neighbors.
# Point 1162 has 19 neighbors.
# Point 1163 has 19 neighbors.
# Point 1164 has 13 neighbors.
# Point 1165 has 13 neighbors.
# Point 1166 has 14 neighbors.
# Point 1167 has 12 neighbors.
# Point 1168 has 19 neighbors.
# Point 1169 has 19 neighbors.
# Point 1170 has 19 neighbors.
# Point 1171 has 19 neighbors.
# Point 1172 has 19 neighbors.
# Point 1173 has 11 neighbors.
# Point 1174 has 12 neighbors.
# Point 1175 has 19 neighbors.
# Point 1176 has 19 neighbors.
# Point 1177 has 19 neighbors.
# Point 1178 has 19 neighbors.
# Point 1179 has 12 neighbors.
# Point 1180 has 15 neighbors.
# Point 1181 has 11 neighbors.
# Point 1182 has 18 neighbors.
# Point 1183 has 19 neighbors.
# Point 1184 has 18 neighbors.
# Point 1185 has 19 neighbors.
# Point 1186 has 19 neighbors.
# Point 1187 has 19 neighbors.
# Point 1188 has 10 neighbors.
# Point 1189 has 19 neighbors.
# Point 1190 has 13 neighbors.
# Point 1191 has 19 neighbors.
# Point 1192 has 19 neighbors.
# Point 1193 has 19 neighbors.
# Point 1194 has 19 neighbors.
# Point 1195 has 19 neighbors.
# Point 1196 has 19 neighbors.
# Point 1197 has 19 neighbors.
# Point 1198 has 12 neighbors.
# Point 1199 has 16 neighbors.
# Point 1200 has 19 neighbors.
# Point 1201 has 19 neighbors.
# Point 1202 has 19 neighbors.
# Point 1203 has 19 neighbors.
# Point 1204 has 16 neighbors.
# Point 1205 has 19 neighbors.
# Point 1206 has 19 neighbors.
# Point 1207 has 19 neighbors.
# Point 1208 has 12 neighbors.
# Point 1209 has 17 neighbors.
# Point 1210 has 18 neighbors.
# Point 1211 has 19 neighbors.
# Point 1212 has 19 neighbors.
# Point 1213 has 19 neighbors.
# Point 1214 has 18 neighbors.
# Point 1215 has 19 neighbors.
# Point 1216 has 9 neighbors.
# Point 1217 has 18 neighbors.
# Point 1218 has 13 neighbors.
# Point 1219 has 19 neighbors.
# Point 1220 has 19 neighbors.
# Point 1221 has 19 neighbors.
# Point 1222 has 18 neighbors.
# Point 1223 has 19 neighbors.
# Point 1224 has 19 neighbors.
# Point 1225 has 15 neighbors.
# Point 1226 has 18 neighbors.
# Point 1227 has 19 neighbors.
# Point 1228 has 19 neighbors.
# Point 1229 has 19 neighbors.
# Point 1230 has 11 neighbors.
# Point 1231 has 19 neighbors.
# Point 1232 has 19 neighbors.
# Point 1233 has 19 neighbors.
# Point 1234 has 12 neighbors.
# Point 1235 has 18 neighbors.
# Point 1236 has 17 neighbors.
# Point 1237 has 19 neighbors.
# Point 1238 has 18 neighbors.
# Point 1239 has 19 neighbors.
# Point 1240 has 12 neighbors.
# Point 1241 has 10 neighbors.
# Point 1242 has 19 neighbors.
# Point 1243 has 19 neighbors.
# Point 1244 has 19 neighbors.
# Point 1245 has 19 neighbors.
# Point 1246 has 19 neighbors.
# Point 1247 has 19 neighbors.
# Point 1248 has 16 neighbors.
# Point 1249 has 19 neighbors.
# Point 1250 has 19 neighbors.
# Point 1251 has 19 neighbors.
# Point 1252 has 12 neighbors.
# Point 1253 has 19 neighbors.
# Point 1254 has 19 neighbors.
# Point 1255 has 18 neighbors.
# Point 1256 has 19 neighbors.
# Point 1257 has 19 neighbors.
# Point 1258 has 19 neighbors.
# Point 1259 has 19 neighbors.
# Point 1260 has 19 neighbors.
# Point 1261 has 19 neighbors.
# Point 1262 has 18 neighbors.
# Point 1263 has 19 neighbors.
# Point 1264 has 13 neighbors.
# Point 1265 has 17 neighbors.
# Point 1266 has 19 neighbors.
# Point 1267 has 18 neighbors.
# Point 1268 has 19 neighbors.
# Point 1269 has 19 neighbors.
# Point 1270 has 13 neighbors.
# Point 1271 has 19 neighbors.
# Point 1272 has 19 neighbors.
# Point 1273 has 19 neighbors.
# Point 1274 has 19 neighbors.
# Point 1275 has 19 neighbors.
# Point 1276 has 19 neighbors.
# Point 1277 has 19 neighbors.
# Point 1278 has 19 neighbors.
# Point 1279 has 19 neighbors.
# Point 1280 has 19 neighbors.
# Point 1281 has 19 neighbors.
# Point 1282 has 19 neighbors.
# Point 1283 has 19 neighbors.
# Point 1284 has 19 neighbors.
# Point 1285 has 13 neighbors.
# Point 1286 has 18 neighbors.
# Point 1287 has 9 neighbors.
# Point 1288 has 19 neighbors.
# Point 1289 has 19 neighbors.
# Point 1290 has 10 neighbors.
# Point 1291 has 19 neighbors.
# Point 1292 has 14 neighbors.
# Point 1293 has 19 neighbors.
# Point 1294 has 14 neighbors.
# Point 1295 has 19 neighbors.
# Point 1296 has 19 neighbors.
# Point 1297 has 19 neighbors.
# Point 1298 has 19 neighbors.
# Point 1299 has 19 neighbors.
# Point 1300 has 15 neighbors.
# Point 1301 has 19 neighbors.
# Point 1302 has 19 neighbors.
# Point 1303 has 19 neighbors.
# Point 1304 has 15 neighbors.
# Point 1305 has 19 neighbors.
# Point 1306 has 17 neighbors.
# Point 1307 has 17 neighbors.
# Point 1308 has 16 neighbors.
# Point 1309 has 19 neighbors.
# Point 1310 has 19 neighbors.
# Point 1311 has 15 neighbors.
# Point 1312 has 19 neighbors.
# Point 1313 has 18 neighbors.
# Point 1314 has 19 neighbors.
# Point 1315 has 19 neighbors.
# Point 1316 has 19 neighbors.
# Point 1317 has 18 neighbors.
# Point 1318 has 11 neighbors.
# Point 1319 has 10 neighbors.
# Point 1320 has 19 neighbors.
# Point 1321 has 19 neighbors.
# Point 1322 has 19 neighbors.
# Point 1323 has 13 neighbors.
# Point 1324 has 19 neighbors.
# Point 1325 has 19 neighbors.
# Point 1326 has 19 neighbors.
# Point 1327 has 19 neighbors.
# Point 1328 has 19 neighbors.
# Point 1329 has 19 neighbors.
# Point 1330 has 19 neighbors.
# Point 1331 has 19 neighbors.
# Point 1332 has 19 neighbors.
# Point 1333 has 16 neighbors.
# Point 1334 has 19 neighbors.
# Point 1335 has 19 neighbors.
# Point 1336 has 19 neighbors.
# Point 1337 has 19 neighbors.
# Point 1338 has 18 neighbors.
# Point 1339 has 19 neighbors.
# Point 1340 has 19 neighbors.
# Point 1341 has 19 neighbors.
# Point 1342 has 19 neighbors.
# Point 1343 has 9 neighbors.
# Point 1344 has 19 neighbors.
# Point 1345 has 19 neighbors.
# Point 1346 has 19 neighbors.
# Point 1347 has 19 neighbors.
# Point 1348 has 19 neighbors.
# Point 1349 has 19 neighbors.
# Point 1350 has 19 neighbors.
# Point 1351 has 19 neighbors.
# Point 1352 has 19 neighbors.
# Point 1353 has 19 neighbors.
# Point 1354 has 7 neighbors.
# Point 1355 has 19 neighbors.
# Point 1356 has 19 neighbors.
# Point 1357 has 19 neighbors.
# Point 1358 has 19 neighbors.
# Point 1359 has 19 neighbors.
# Point 1360 has 18 neighbors.
# Point 1361 has 19 neighbors.
# Point 1362 has 19 neighbors.
# Point 1363 has 19 neighbors.
# Point 1364 has 19 neighbors.
# Point 1365 has 19 neighbors.
# Point 1366 has 19 neighbors.
# Point 1367 has 16 neighbors.
# Point 1368 has 19 neighbors.
# Point 1369 has 15 neighbors.
# Point 1370 has 19 neighbors.
# Point 1371 has 19 neighbors.
# Point 1372 has 19 neighbors.
# Point 1373 has 14 neighbors.
# Point 1374 has 16 neighbors.
# Point 1375 has 19 neighbors.
# Point 1376 has 19 neighbors.
# Point 1377 has 19 neighbors.
# Point 1378 has 19 neighbors.
# Point 1379 has 18 neighbors.
# Point 1380 has 19 neighbors.
# Point 1381 has 19 neighbors.
# Point 1382 has 19 neighbors.
# Point 1383 has 19 neighbors.
# Point 1384 has 15 neighbors.
# Point 1385 has 19 neighbors.
# Point 1386 has 19 neighbors.
# Point 1387 has 19 neighbors.
# Point 1388 has 19 neighbors.
# Point 1389 has 19 neighbors.
# Point 1390 has 19 neighbors.
# Point 1391 has 19 neighbors.
# Point 1392 has 19 neighbors.
# Point 1393 has 19 neighbors.
# Point 1394 has 19 neighbors.
# Point 1395 has 19 neighbors.
# Point 1396 has 17 neighbors.
# Point 1397 has 19 neighbors.
# Point 1398 has 19 neighbors.
# Point 1399 has 18 neighbors.
# Point 1400 has 19 neighbors.
# Point 1401 has 14 neighbors.
# Point 1402 has 19 neighbors.
# Point 1403 has 19 neighbors.
# Point 1404 has 19 neighbors.
# Point 1405 has 18 neighbors.
# Point 1406 has 19 neighbors.
# Point 1407 has 19 neighbors.
# Point 1408 has 19 neighbors.
# Point 1409 has 12 neighbors.
# Point 1410 has 19 neighbors.
# Point 1411 has 19 neighbors.
# Point 1412 has 19 neighbors.
# Point 1413 has 19 neighbors.
# Point 1414 has 19 neighbors.
# Point 1415 has 19 neighbors.
# Point 1416 has 17 neighbors.
# Point 1417 has 19 neighbors.
# Point 1418 has 10 neighbors.
# Point 1419 has 19 neighbors.
# Point 1420 has 19 neighbors.
# Point 1421 has 19 neighbors.
# Point 1422 has 19 neighbors.
# Point 1423 has 19 neighbors.
# Point 1424 has 19 neighbors.
# Point 1425 has 18 neighbors.
# Point 1426 has 13 neighbors.
# Point 1427 has 18 neighbors.
# Point 1428 has 15 neighbors.
# Point 1429 has 19 neighbors.
# Point 1430 has 18 neighbors.
# Point 1431 has 19 neighbors.
# Point 1432 has 19 neighbors.
# Point 1433 has 18 neighbors.
# Point 1434 has 19 neighbors.
# Point 1435 has 13 neighbors.
# Point 1436 has 19 neighbors.
# Point 1437 has 19 neighbors.
# Point 1438 has 12 neighbors.
# Point 1439 has 19 neighbors.
# Point 1440 has 19 neighbors.
# Point 1441 has 19 neighbors.
# Point 1442 has 19 neighbors.
# Point 1443 has 19 neighbors.
# Point 1444 has 19 neighbors.
# Point 1445 has 15 neighbors.
# Point 1446 has 19 neighbors.
# Point 1447 has 19 neighbors.
# Point 1448 has 19 neighbors.
# Point 1449 has 16 neighbors.
# Point 1450 has 18 neighbors.
# Point 1451 has 16 neighbors.
# Point 1452 has 19 neighbors.
# Point 1453 has 19 neighbors.
# Point 1454 has 19 neighbors.
# Point 1455 has 19 neighbors.
# Point 1456 has 18 neighbors.
# Point 1457 has 19 neighbors.
# Point 1458 has 19 neighbors.
# Point 1459 has 19 neighbors.
# Point 1460 has 11 neighbors.
# Point 1461 has 19 neighbors.
# Point 1462 has 18 neighbors.
# Point 1463 has 19 neighbors.
# Point 1464 has 19 neighbors.
# Point 1465 has 18 neighbors.
# Point 1466 has 19 neighbors.
# Point 1467 has 19 neighbors.
# Point 1468 has 19 neighbors.
# Point 1469 has 19 neighbors.
# Point 1470 has 19 neighbors.
# Point 1471 has 19 neighbors.
# Point 1472 has 13 neighbors.
# Point 1473 has 19 neighbors.
# Point 1474 has 18 neighbors.
# Point 1475 has 19 neighbors.
# Point 1476 has 18 neighbors.
# Point 1477 has 19 neighbors.
# Point 1478 has 19 neighbors.
# Point 1479 has 19 neighbors.
# Point 1480 has 19 neighbors.
# Point 1481 has 19 neighbors.
# Point 1482 has 19 neighbors.
# Point 1483 has 19 neighbors.
# Point 1484 has 16 neighbors.
# Point 1485 has 16 neighbors.
# Point 1486 has 11 neighbors.
# Point 1487 has 19 neighbors.
# Point 1488 has 12 neighbors.
# Point 1489 has 18 neighbors.
# Point 1490 has 18 neighbors.
# Point 1491 has 19 neighbors.
# Point 1492 has 19 neighbors.
# Point 1493 has 19 neighbors.
# Point 1494 has 19 neighbors.
# Point 1495 has 19 neighbors.
# Point 1496 has 19 neighbors.
# Point 1497 has 19 neighbors.
# Point 1498 has 19 neighbors.
# Point 1499 has 19 neighbors.
# Point 1500 has 17 neighbors.
# Point 1501 has 19 neighbors.
# Point 1502 has 19 neighbors.
# Point 1503 has 19 neighbors.
# Point 1504 has 18 neighbors.
# Point 1505 has 19 neighbors.
# Point 1506 has 18 neighbors.
# Point 1507 has 19 neighbors.
# Point 1508 has 18 neighbors.
# Point 1509 has 19 neighbors.
# Point 1510 has 14 neighbors.
# Point 1511 has 15 neighbors.
# Point 1512 has 19 neighbors.
# Point 1513 has 16 neighbors.
# Point 1514 has 19 neighbors.
# Point 1515 has 19 neighbors.
# Point 1516 has 19 neighbors.
# Point 1517 has 19 neighbors.
# Point 1518 has 19 neighbors.
# Point 1519 has 19 neighbors.
# Point 1520 has 16 neighbors.
# Point 1521 has 18 neighbors.
# Point 1522 has 19 neighbors.
# Point 1523 has 9 neighbors.
# Point 1524 has 19 neighbors.
# Point 1525 has 19 neighbors.
# Point 1526 has 13 neighbors.
# Point 1527 has 19 neighbors.
# Point 1528 has 19 neighbors.
# Point 1529 has 19 neighbors.
# Point 1530 has 19 neighbors.
# Point 1531 has 16 neighbors.
# Point 1532 has 19 neighbors.
# Point 1533 has 15 neighbors.
# Point 1534 has 19 neighbors.
# Point 1535 has 15 neighbors.
# Point 1536 has 19 neighbors.
# Point 1537 has 6 neighbors.
# Point 1538 has 19 neighbors.
# Point 1539 has 19 neighbors.
# Point 1540 has 14 neighbors.
# Point 1541 has 8 neighbors.
# Point 1542 has 19 neighbors.
# Point 1543 has 12 neighbors.
# Point 1544 has 19 neighbors.
# Point 1545 has 16 neighbors.
# Point 1546 has 19 neighbors.
# Point 1547 has 19 neighbors.
# Point 1548 has 19 neighbors.
# Point 1549 has 19 neighbors.
# Point 1550 has 19 neighbors.
# Point 1551 has 18 neighbors.
# Point 1552 has 19 neighbors.
# Point 1553 has 17 neighbors.
# Point 1554 has 19 neighbors.
# Point 1555 has 19 neighbors.
# Point 1556 has 19 neighbors.
# Point 1557 has 19 neighbors.
# Point 1558 has 18 neighbors.
# Point 1559 has 19 neighbors.
# Point 1560 has 16 neighbors.
# Point 1561 has 19 neighbors.
# Point 1562 has 13 neighbors.
# Point 1563 has 14 neighbors.
# Point 1564 has 19 neighbors.
# Point 1565 has 19 neighbors.
# Point 1566 has 19 neighbors.
# Point 1567 has 19 neighbors.
# Point 1568 has 19 neighbors.
# Point 1569 has 19 neighbors.
# Point 1570 has 16 neighbors.
# Point 1571 has 19 neighbors.
# Point 1572 has 19 neighbors.
# Point 1573 has 19 neighbors.
# Point 1574 has 19 neighbors.
# Point 1575 has 19 neighbors.
# Point 1576 has 19 neighbors.
# Point 1577 has 14 neighbors.
# Point 1578 has 13 neighbors.
# Point 1579 has 19 neighbors.
# Point 1580 has 19 neighbors.
# Point 1581 has 19 neighbors.
# Point 1582 has 19 neighbors.
# Point 1583 has 14 neighbors.
# Point 1584 has 19 neighbors.
# Point 1585 has 19 neighbors.
# Point 1586 has 19 neighbors.
# Point 1587 has 19 neighbors.
# Point 1588 has 19 neighbors.
# Point 1589 has 19 neighbors.
# Point 1590 has 11 neighbors.
# Point 1591 has 17 neighbors.
# Point 1592 has 19 neighbors.
# Point 1593 has 19 neighbors.
# Point 1594 has 13 neighbors.
# Point 1595 has 18 neighbors.
# Point 1596 has 11 neighbors.
# Point 1597 has 19 neighbors.
# Point 1598 has 9 neighbors.
# Point 1599 has 15 neighbors.
# Point 1600 has 19 neighbors.
# Point 1601 has 19 neighbors.
# Point 1602 has 19 neighbors.
# Point 1603 has 18 neighbors.
# Point 1604 has 19 neighbors.
# Point 1605 has 19 neighbors.
# Point 1606 has 19 neighbors.
# Point 1607 has 19 neighbors.
# Point 1608 has 19 neighbors.
# Point 1609 has 19 neighbors.
# Point 1610 has 18 neighbors.
# Point 1611 has 9 neighbors.
# Point 1612 has 19 neighbors.
# Point 1613 has 19 neighbors.
# Point 1614 has 19 neighbors.
# Point 1615 has 18 neighbors.
# Point 1616 has 15 neighbors.
# Point 1617 has 8 neighbors.
# Point 1618 has 19 neighbors.
# Point 1619 has 19 neighbors.
# Point 1620 has 12 neighbors.
# Point 1621 has 19 neighbors.
# Point 1622 has 19 neighbors.
# Point 1623 has 19 neighbors.
# Point 1624 has 19 neighbors.
# Point 1625 has 19 neighbors.
# Point 1626 has 19 neighbors.
# Point 1627 has 9 neighbors.
# Point 1628 has 19 neighbors.
# Point 1629 has 16 neighbors.
# Point 1630 has 19 neighbors.
# Point 1631 has 19 neighbors.
# Point 1632 has 10 neighbors.
# Point 1633 has 18 neighbors.
# Point 1634 has 19 neighbors.
# Point 1635 has 19 neighbors.
# Point 1636 has 16 neighbors.
# Point 1637 has 19 neighbors.
# Point 1638 has 19 neighbors.
# Point 1639 has 19 neighbors.
# Point 1640 has 19 neighbors.
# Point 1641 has 19 neighbors.
# Point 1642 has 19 neighbors.
# Point 1643 has 19 neighbors.
# Point 1644 has 19 neighbors.
# Point 1645 has 19 neighbors.
# Point 1646 has 19 neighbors.
# Point 1647 has 17 neighbors.
# Point 1648 has 17 neighbors.
# Point 1649 has 19 neighbors.
# Point 1650 has 19 neighbors.
# Point 1651 has 19 neighbors.
# Point 1652 has 18 neighbors.
# Point 1653 has 19 neighbors.
# Point 1654 has 18 neighbors.
# Point 1655 has 11 neighbors.
# Point 1656 has 19 neighbors.
# Point 1657 has 19 neighbors.
# Point 1658 has 10 neighbors.
# Point 1659 has 19 neighbors.
# Point 1660 has 10 neighbors.
# Point 1661 has 18 neighbors.
# Point 1662 has 19 neighbors.
# Point 1663 has 19 neighbors.
# Point 1664 has 19 neighbors.
# Point 1665 has 19 neighbors.
# Point 1666 has 19 neighbors.
# Point 1667 has 14 neighbors.
# Point 1668 has 19 neighbors.
# Point 1669 has 19 neighbors.
# Point 1670 has 18 neighbors.
# Point 1671 has 19 neighbors.
# Point 1672 has 19 neighbors.
# Point 1673 has 19 neighbors.
# Point 1674 has 19 neighbors.
# Point 1675 has 19 neighbors.
# Point 1676 has 19 neighbors.
# Point 1677 has 19 neighbors.
# Point 1678 has 19 neighbors.
# Point 1679 has 19 neighbors.
# Point 1680 has 19 neighbors.
# Point 1681 has 19 neighbors.
# Point 1682 has 16 neighbors.
# Point 1683 has 13 neighbors.
# Point 1684 has 19 neighbors.
# Point 1685 has 19 neighbors.
# Point 1686 has 19 neighbors.
# Point 1687 has 19 neighbors.
# Point 1688 has 16 neighbors.
# Point 1689 has 16 neighbors.
# Point 1690 has 17 neighbors.
# Point 1691 has 19 neighbors.
# Point 1692 has 16 neighbors.
# Point 1693 has 19 neighbors.
# Point 1694 has 19 neighbors.
# Point 1695 has 18 neighbors.
# Point 1696 has 19 neighbors.
# Point 1697 has 19 neighbors.
# Point 1698 has 19 neighbors.
# Point 1699 has 16 neighbors.
# Point 1700 has 19 neighbors.
# Point 1701 has 19 neighbors.
# Point 1702 has 19 neighbors.
# Point 1703 has 16 neighbors.
# Point 1704 has 19 neighbors.
# Point 1705 has 19 neighbors.
# Point 1706 has 19 neighbors.
# Point 1707 has 19 neighbors.
# Point 1708 has 18 neighbors.
# Point 1709 has 19 neighbors.
# Point 1710 has 19 neighbors.
# Point 1711 has 7 neighbors.
# Point 1712 has 19 neighbors.
# Point 1713 has 17 neighbors.
# Point 1714 has 15 neighbors.
# Point 1715 has 19 neighbors.
# Point 1716 has 10 neighbors.
# Point 1717 has 19 neighbors.
# Point 1718 has 19 neighbors.
# Point 1719 has 19 neighbors.
# Point 1720 has 12 neighbors.
# Point 1721 has 13 neighbors.
# Point 1722 has 15 neighbors.
# Point 1723 has 16 neighbors.
# Point 1724 has 19 neighbors.
# Point 1725 has 19 neighbors.
# Point 1726 has 10 neighbors.
# Point 1727 has 19 neighbors.
# Point 1728 has 19 neighbors.
# Point 1729 has 19 neighbors.
# Point 1730 has 16 neighbors.
# Point 1731 has 19 neighbors.
# Point 1732 has 19 neighbors.
# Point 1733 has 19 neighbors.
# Point 1734 has 19 neighbors.
# Point 1735 has 19 neighbors.
# Point 1736 has 16 neighbors.
# Point 1737 has 16 neighbors.
# Point 1738 has 14 neighbors.
# Point 1739 has 19 neighbors.
# Point 1740 has 19 neighbors.
# Point 1741 has 19 neighbors.
# Point 1742 has 19 neighbors.
# Point 1743 has 19 neighbors.
# Point 1744 has 18 neighbors.
# Point 1745 has 19 neighbors.
# Point 1746 has 19 neighbors.
# Point 1747 has 19 neighbors.
# Point 1748 has 19 neighbors.
# Point 1749 has 19 neighbors.
# Point 1750 has 19 neighbors.
# Point 1751 has 19 neighbors.
# Point 1752 has 19 neighbors.
# Point 1753 has 19 neighbors.
# Point 1754 has 19 neighbors.
# Point 1755 has 17 neighbors.
# Point 1756 has 15 neighbors.
# Point 1757 has 19 neighbors.
# Point 1758 has 19 neighbors.
# Point 1759 has 16 neighbors.
# Point 1760 has 19 neighbors.
# Point 1761 has 19 neighbors.
# Point 1762 has 19 neighbors.
# Point 1763 has 17 neighbors.
# Point 1764 has 19 neighbors.
# Point 1765 has 18 neighbors.
# Point 1766 has 19 neighbors.
# Point 1767 has 19 neighbors.
# Point 1768 has 19 neighbors.
# Point 1769 has 18 neighbors.
# Point 1770 has 19 neighbors.
# Point 1771 has 19 neighbors.
# Point 1772 has 19 neighbors.
# Point 1773 has 19 neighbors.
# Point 1774 has 19 neighbors.
# Point 1775 has 19 neighbors.
# Point 1776 has 19 neighbors.
# Point 1777 has 11 neighbors.
# Point 1778 has 19 neighbors.
# Point 1779 has 18 neighbors.
# Point 1780 has 18 neighbors.
# Point 1781 has 12 neighbors.
# Point 1782 has 19 neighbors.
# Point 1783 has 18 neighbors.
# Point 1784 has 19 neighbors.
# Point 1785 has 17 neighbors.
# Point 1786 has 19 neighbors.
# Point 1787 has 19 neighbors.
# Point 1788 has 19 neighbors.
# Point 1789 has 19 neighbors.
# Point 1790 has 19 neighbors.
# Point 1791 has 12 neighbors.
# Point 1792 has 19 neighbors.
# Point 1793 has 19 neighbors.
# Point 1794 has 19 neighbors.
# Point 1795 has 19 neighbors.
# Point 1796 has 19 neighbors.
# Point 1797 has 17 neighbors.
# Point 1798 has 19 neighbors.
# Point 1799 has 19 neighbors.
# Point 1800 has 17 neighbors.
# Point 1801 has 9 neighbors.
# Point 1802 has 10 neighbors.
# Point 1803 has 19 neighbors.
# Point 1804 has 17 neighbors.
# Point 1805 has 16 neighbors.
# Point 1806 has 19 neighbors.
# Point 1807 has 17 neighbors.
# Point 1808 has 19 neighbors.
# Point 1809 has 19 neighbors.
# Point 1810 has 19 neighbors.
# Point 1811 has 19 neighbors.
# Point 1812 has 19 neighbors.
# Point 1813 has 19 neighbors.
# Point 1814 has 19 neighbors.
# Point 1815 has 18 neighbors.
# Point 1816 has 19 neighbors.
# Point 1817 has 19 neighbors.
# Point 1818 has 19 neighbors.
# Point 1819 has 19 neighbors.
# Point 1820 has 19 neighbors.
# Point 1821 has 13 neighbors.
# Point 1822 has 19 neighbors.
# Point 1823 has 11 neighbors.
# Point 1824 has 17 neighbors.
# Point 1825 has 19 neighbors.
# Point 1826 has 19 neighbors.
# Point 1827 has 19 neighbors.
# Point 1828 has 14 neighbors.
# Point 1829 has 19 neighbors.
# Point 1830 has 19 neighbors.
# Point 1831 has 14 neighbors.
# Point 1832 has 19 neighbors.
# Point 1833 has 19 neighbors.
# Point 1834 has 19 neighbors.
# Point 1835 has 18 neighbors.
# Point 1836 has 19 neighbors.
# Point 1837 has 16 neighbors.
# Point 1838 has 18 neighbors.
# Point 1839 has 19 neighbors.
# Point 1840 has 11 neighbors.
# Point 1841 has 19 neighbors.
# Point 1842 has 19 neighbors.
# Point 1843 has 15 neighbors.
# Point 1844 has 19 neighbors.
# Point 1845 has 19 neighbors.
# Point 1846 has 19 neighbors.
# Point 1847 has 19 neighbors.
# Point 1848 has 19 neighbors.
# Point 1849 has 19 neighbors.
# Point 1850 has 19 neighbors.
# Point 1851 has 19 neighbors.
# Point 1852 has 10 neighbors.
# Point 1853 has 19 neighbors.
# Point 1854 has 18 neighbors.
# Point 1855 has 19 neighbors.
# Point 1856 has 19 neighbors.
# Point 1857 has 15 neighbors.
# Point 1858 has 19 neighbors.
# Point 1859 has 19 neighbors.
# Point 1860 has 18 neighbors.
# Point 1861 has 16 neighbors.
# Point 1862 has 17 neighbors.
# Point 1863 has 17 neighbors.
# Point 1864 has 16 neighbors.
# Point 1865 has 19 neighbors.
# Point 1866 has 16 neighbors.
# Point 1867 has 15 neighbors.
# Point 1868 has 19 neighbors.
# Point 1869 has 19 neighbors.
# Point 1870 has 18 neighbors.
# Point 1871 has 19 neighbors.
# Point 1872 has 19 neighbors.
# Point 1873 has 19 neighbors.
# Point 1874 has 16 neighbors.
# Point 1875 has 19 neighbors.
# Point 1876 has 19 neighbors.
# Point 1877 has 12 neighbors.
# Point 1878 has 18 neighbors.
# Point 1879 has 19 neighbors.
# Point 1880 has 15 neighbors.
# Point 1881 has 17 neighbors.
# Point 1882 has 19 neighbors.
# Point 1883 has 19 neighbors.
# Point 1884 has 19 neighbors.
# Point 1885 has 19 neighbors.
# Point 1886 has 19 neighbors.
# Point 1887 has 19 neighbors.
# Point 1888 has 19 neighbors.
# Point 1889 has 19 neighbors.
# Point 1890 has 19 neighbors.
# Point 1891 has 19 neighbors.
# Point 1892 has 19 neighbors.
# Point 1893 has 19 neighbors.
# Point 1894 has 19 neighbors.
# Point 1895 has 19 neighbors.
# Point 1896 has 19 neighbors.
# Point 1897 has 19 neighbors.
# Point 1898 has 19 neighbors.
# Point 1899 has 19 neighbors.
# Point 1900 has 19 neighbors.
# Point 1901 has 15 neighbors.
# Point 1902 has 14 neighbors.
# Point 1903 has 10 neighbors.
# Point 1904 has 19 neighbors.
# Point 1905 has 19 neighbors.
# Point 1906 has 19 neighbors.
# Point 1907 has 19 neighbors.
# Point 1908 has 19 neighbors.
# Point 1909 has 17 neighbors.
# Point 1910 has 17 neighbors.
# Point 1911 has 19 neighbors.
# Point 1912 has 19 neighbors.
# Point 1913 has 19 neighbors.
# Point 1914 has 19 neighbors.
# Point 1915 has 19 neighbors.
# Point 1916 has 19 neighbors.
# Point 1917 has 13 neighbors.
# Point 1918 has 19 neighbors.
# Point 1919 has 18 neighbors.
# Point 1920 has 11 neighbors.
# Point 1921 has 17 neighbors.
# Point 1922 has 9 neighbors.
# Point 1923 has 19 neighbors.
# Point 1924 has 17 neighbors.
# Point 1925 has 19 neighbors.
# Point 1926 has 18 neighbors.
# Point 1927 has 19 neighbors.
# Point 1928 has 19 neighbors.
# Point 1929 has 19 neighbors.
# Point 1930 has 17 neighbors.
# Point 1931 has 18 neighbors.
# Point 1932 has 19 neighbors.
# Point 1933 has 15 neighbors.
# Point 1934 has 19 neighbors.
# Point 1935 has 12 neighbors.
# Point 1936 has 19 neighbors.
# Point 1937 has 19 neighbors.
# Point 1938 has 14 neighbors.
# Point 1939 has 15 neighbors.
# Point 1940 has 19 neighbors.
# Point 1941 has 19 neighbors.
# Point 1942 has 19 neighbors.
# Point 1943 has 14 neighbors.
# Point 1944 has 19 neighbors.
# Point 1945 has 19 neighbors.
# Point 1946 has 19 neighbors.
# Point 1947 has 18 neighbors.
# Point 1948 has 19 neighbors.
# Point 1949 has 19 neighbors.
# Point 1950 has 19 neighbors.
# Point 1951 has 19 neighbors.
# Point 1952 has 19 neighbors.
# Point 1953 has 12 neighbors.
# Point 1954 has 19 neighbors.
# Point 1955 has 13 neighbors.
# Point 1956 has 17 neighbors.
# Point 1957 has 19 neighbors.
# Point 1958 has 16 neighbors.
# Point 1959 has 19 neighbors.
# Point 1960 has 19 neighbors.
# Point 1961 has 19 neighbors.
# Point 1962 has 19 neighbors.
# Point 1963 has 19 neighbors.
# Point 1964 has 15 neighbors.
# Point 1965 has 18 neighbors.
# Point 1966 has 11 neighbors.
# Point 1967 has 19 neighbors.
# Point 1968 has 19 neighbors.
# Point 1969 has 18 neighbors.
# Point 1970 has 9 neighbors.
# Point 1971 has 19 neighbors.
# Point 1972 has 19 neighbors.
# Point 1973 has 19 neighbors.
# Point 1974 has 19 neighbors.
# Point 1975 has 18 neighbors.
# Point 1976 has 19 neighbors.
# Point 1977 has 19 neighbors.
# Point 1978 has 19 neighbors.
# Point 1979 has 15 neighbors.
# Point 1980 has 19 neighbors.
# Point 1981 has 19 neighbors.
# Point 1982 has 19 neighbors.
# Point 1983 has 19 neighbors.
# Point 1984 has 19 neighbors.
# Point 1985 has 19 neighbors.
# Point 1986 has 15 neighbors.
# Point 1987 has 19 neighbors.
# Point 1988 has 18 neighbors.
# Point 1989 has 19 neighbors.
# Point 1990 has 19 neighbors.
# Point 1991 has 19 neighbors.
# Point 1992 has 19 neighbors.
# Point 1993 has 18 neighbors.
# Point 1994 has 19 neighbors.
# Point 1995 has 19 neighbors.
# Point 1996 has 19 neighbors.
# Point 1997 has 19 neighbors.
# Point 1998 has 13 neighbors.
# Point 1999 has 19 neighbors.
# Point 2000 has 19 neighbors.
# Point 2001 has 19 neighbors.
# Point 2002 has 19 neighbors.
# Point 2003 has 19 neighbors.
# Point 2004 has 19 neighbors.
# Point 2005 has 19 neighbors.
# Point 2006 has 19 neighbors.
# Point 2007 has 19 neighbors.
# Point 2008 has 8 neighbors.
# Point 2009 has 19 neighbors.
# Point 2010 has 19 neighbors.
# Point 2011 has 19 neighbors.
# Point 2012 has 19 neighbors.
# Point 2013 has 12 neighbors.
# Point 2014 has 19 neighbors.
# Point 2015 has 19 neighbors.
# Point 2016 has 17 neighbors.
# Point 2017 has 15 neighbors.
# Point 2018 has 19 neighbors.
# Point 2019 has 17 neighbors.
# Point 2020 has 19 neighbors.
# Point 2021 has 16 neighbors.
# Point 2022 has 19 neighbors.
# Point 2023 has 19 neighbors.
# Point 2024 has 19 neighbors.
# Point 2025 has 13 neighbors.
# Point 2026 has 19 neighbors.
# Point 2027 has 18 neighbors.
# Point 2028 has 19 neighbors.
# Point 2029 has 19 neighbors.
# Point 2030 has 19 neighbors.
# Point 2031 has 19 neighbors.
# Point 2032 has 17 neighbors.
# Point 2033 has 18 neighbors.
# Point 2034 has 19 neighbors.
# Point 2035 has 19 neighbors.
# Point 2036 has 19 neighbors.
# Point 2037 has 19 neighbors.
# Point 2038 has 19 neighbors.
# Point 2039 has 19 neighbors.
# Point 2040 has 19 neighbors.
# Point 2041 has 19 neighbors.
# Point 2042 has 16 neighbors.
# Point 2043 has 19 neighbors.
# Point 2044 has 18 neighbors.
# Point 2045 has 19 neighbors.
# Point 2046 has 19 neighbors.
# Point 2047 has 19 neighbors.
# Point 2048 has 19 neighbors.
# Point 2049 has 19 neighbors.
# Point 2050 has 17 neighbors.
# Point 2051 has 15 neighbors.
# Point 2052 has 19 neighbors.
# Point 2053 has 10 neighbors.
# Point 2054 has 19 neighbors.
# Point 2055 has 13 neighbors.
# Point 2056 has 19 neighbors.
# Point 2057 has 19 neighbors.
# Point 2058 has 19 neighbors.
# Point 2059 has 19 neighbors.
# Point 2060 has 19 neighbors.
# Point 2061 has 19 neighbors.
# Point 2062 has 10 neighbors.
# Point 2063 has 19 neighbors.
# Point 2064 has 18 neighbors.
# Point 2065 has 19 neighbors.
# Point 2066 has 19 neighbors.
# Point 2067 has 15 neighbors.
# Point 2068 has 19 neighbors.
# Point 2069 has 19 neighbors.
# Point 2070 has 13 neighbors.
# Point 2071 has 19 neighbors.
# Point 2072 has 19 neighbors.
# Point 2073 has 19 neighbors.
# Point 2074 has 19 neighbors.
# Point 2075 has 19 neighbors.
# Point 2076 has 14 neighbors.
# Point 2077 has 19 neighbors.
# Point 2078 has 19 neighbors.
# Point 2079 has 19 neighbors.
# Point 2080 has 15 neighbors.
# Point 2081 has 19 neighbors.
# Point 2082 has 19 neighbors.
# Point 2083 has 19 neighbors.
# Point 2084 has 19 neighbors.
# Point 2085 has 19 neighbors.
# Point 2086 has 10 neighbors.
# Point 2087 has 19 neighbors.
# {'S_7': tensor([[   0,    0,    0,  ..., 2087, 2087, 2087],
#          [1141, 1926,  469,  ..., 1793, 1013,  560]])}

# %%
## Make sure I have all the data     

print(f"Total number of spots across all slides: {len(test_spot_table)}")

print(f"The spots in our preprocessing datasets: {len(test_normal_coords[0])}")
# Out:
# Total number of spots across all slides: 2088
# The spots in our preprocessing datasets: 2088

# %%
import torch


torch.save({
    'normal_coords':test_normal_coords,
    'slide_edge_indices': test_slide_edge_indices
}, "test_slide_edge_indices.pt")
